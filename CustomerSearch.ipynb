# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # Загрузка данных

# %%
company = pd.read_excel('./data(xls)/Компании.xlsx')#загружаю основной набор данных

# %%
company.head()
# Out:
#          ID       Наименование Дата регистрации  Код статистики       Отрасль  \
# 0   4283790           033, ООО       2003-10-14      71115178.0  Производство
# 1  12390280        1 БЭЙК, ООО       2019-10-28      42006784.0  Производство
# 2   9603036  1-Я ЛИФТОВАЯ, ООО       2014-11-11      35394691.0  Производство
# 3   5298659    12 СТУЛЬЕВ, ООО       2006-03-29      94037570.0  Производство
# 4   7128967      2020-ЛБК, ООО       2009-07-28      60596246.0  Производство
#
#      Форма собственности  Код причины постановки на учет  \
# 0  Частная собственность                     390601001.0
# 1  Частная собственность                     391401001.0
# 2  Частная собственность                     390601001.0
# 3  Частная собственность                     390601001.0
# 4  Частная собственность                     390601001.0
#
#          Органы власти и государственного управления   Размер компании  \
# 0  Организации, учрежденные юридическими лицами и...  Микропредприятия
# 1  Организации, учрежденные юридическими лицами и...               NaN
# 2  Организации, учрежденные юридическими лицами и...               NaN
# 3  Организации, учрежденные юридическими лицами и...               NaN
# 4  Организации, учрежденные юридическими лицами и...               NaN
#
#    2018, Среднесписочная численность работников  ...  \
# 0                                           1.0  ...
# 1                                           NaN  ...
# 2                                           1.0  ...
# 3                                           1.0  ...
# 4                                           1.0  ...
#
#   2019, Сальдо денежных потоков за отчетный период, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Поступление денежных средств всего, RUB  2019, Платежей всего, RUB  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
#
#    2019, Прибыль от приносящей доход деятельности, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Всего поступило средств, RUB  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    2019, Расходы на целевые мероприятия, RUB  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    2019, Расходы на содержание аппарата управления, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Всего использовано средств, RUB  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    2019, Остаток средств на конец отчетного года, RUB
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 145 columns]

# %%
bank_guarantees = pd.read_excel('./data(xls)/Банковские гарантии.xlsx') #данные о наличии банковских гарантий

# %%
leasing = pd.read_excel('./data(xls)/Лизинг.xlsx') #данные о наличии действующих договоров лизинга

# %%
security_loan = pd.read_excel('./data(xls)/Залоги.xlsx') #данные о зарегестированных залогах(признак того что компания является залогодателем по кредиту)

# %%
staff = pd.read_excel('./data(xls)/Численность.xlsx') #данные о численности сотрудников

# %% [markdown]
# ## Подготовка данных

# %%
data = pd.merge(company, bank_guarantees, how='left') #объединяю исследуемые данные с данными о гарантиях

# %%
data = pd.merge(data, leasing, how='left') #объединяю исследуемые данные с данными  о лизинге

# %%
data = pd.merge(data, security_loan, how='left') #объединяю исследуемые данные с данными  о кредитвании

# %%
data = pd.merge(data, security_loan, how='left') #объединяю исследуемые данные с данными  о кредитвании

# %%
data = pd.merge(data, staff, how='left') #объединяю исследуемые данные с данными  о численности сотрудников

# %%
#сводные данные теперь храняться в "data"
data.head(3)
# Out:
#          ID       Наименование Дата регистрации  Код статистики       Отрасль  \
# 0   4283790           033, ООО       2003-10-14      71115178.0  Производство
# 1  12390280        1 БЭЙК, ООО       2019-10-28      42006784.0  Производство
# 2   9603036  1-Я ЛИФТОВАЯ, ООО       2014-11-11      35394691.0  Производство
#
#      Форма собственности  Код причины постановки на учет  \
# 0  Частная собственность                     390601001.0
# 1  Частная собственность                     391401001.0
# 2  Частная собственность                     390601001.0
#
#          Органы власти и государственного управления   Размер компании  \
# 0  Организации, учрежденные юридическими лицами и...  Микропредприятия
# 1  Организации, учрежденные юридическими лицами и...               NaN
# 2  Организации, учрежденные юридическими лицами и...               NaN
#
#    2018, Среднесписочная численность работников  ...  \
# 0                                           1.0  ...
# 1                                           NaN  ...
# 2                                           1.0  ...
#
#   2019, Всего поступило средств, RUB  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
#
#    2019, Расходы на целевые мероприятия, RUB  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#    2019, Расходы на содержание аппарата управления, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Всего использовано средств, RUB  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#    2019, Остаток средств на конец отчетного года, RUB  БГ  Лизинг  Залоги  \
# 0                                                NaN  NaN     NaN     NaN
# 1                                                NaN  NaN     NaN     NaN
# 2                                                NaN  NaN     NaN     NaN
#
#    численность
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 149 columns]

# %%
data.describe()
# Out:
#                  ID  Код статистики  Код причины постановки на учет  \
# count  1.222700e+04    1.217000e+04                    1.214500e+04
# mean   7.363669e+06    4.774692e+07                    3.909655e+08
# std    3.404972e+06    2.764807e+07                    5.449271e+06
# min    1.536000e+03    4.716000e+04                    3.901010e+08
# 25%    5.049960e+06    2.777519e+07                    3.906010e+08
# 50%    7.886504e+06    4.236241e+07                    3.906010e+08
# 75%    1.002957e+07    7.112371e+07                    3.912010e+08
# max    1.254730e+07    9.971510e+07                    7.708010e+08
#
#        2018, Среднесписочная численность работников  2017, Доходы, RUB  \
# count                                   7860.000000       6.529000e+03
# mean                                       8.708397       3.696273e+07
# std                                       57.392902       2.542989e+08
# min                                        1.000000       0.000000e+00
# 25%                                        1.000000       7.540000e+05
# 50%                                        1.000000       4.821000e+06
# 75%                                        5.000000       2.046200e+07
# max                                     4079.000000       1.062454e+10
#
#        2018, Доходы, RUB  2017, Расходы, RUB  2018, Расходы, RUB  \
# count       6.723000e+03        6.529000e+03        6.723000e+03
# mean        6.765525e+07        3.527823e+07        6.378047e+07
# std         7.662991e+08        2.496199e+08        7.547269e+08
# min        -1.194900e+07        0.000000e+00        0.000000e+00
# 25%         7.355000e+05        7.900000e+05        7.990000e+05
# 50%         5.002000e+06        4.444000e+06        4.695000e+06
# 75%         2.242800e+07        1.891800e+07        2.078800e+07
# max         5.336259e+10        1.061781e+10        5.322594e+10
#
#        2017, Налоги, RUB  2018, Налоги, RUB  ...  \
# count       6.556000e+03       6.916000e+03  ...
# mean        1.362677e+06       5.102139e+06  ...
# std         8.100416e+06       1.360288e+08  ...
# min         0.000000e+00       1.000000e+00  ...
# 25%         5.039400e+04       4.995900e+04  ...
# 50%         1.799070e+05       1.923335e+05  ...
# 75%         6.349650e+05       7.323502e+05  ...
# max         3.210900e+08       1.070500e+10  ...
#
#        2019, Всего поступило средств, RUB  \
# count                        2.800000e+02
# mean                         1.414192e+07
# std                          5.971516e+07
# min                         -2.041000e+06
# 25%                          2.520000e+05
# 50%                          1.130500e+06
# 75%                          4.454750e+06
# max                          6.939350e+08
#
#        2019, Расходы на целевые мероприятия, RUB  \
# count                               1.470000e+02
# mean                                8.093327e+06
# std                                 3.111108e+07
# min                                -6.000000e+03
# 25%                                 1.070000e+05
# 50%                                 4.260000e+05
# 75%                                 2.038000e+06
# max                                 2.043270e+08
#
#        2019, Расходы на содержание аппарата управления, RUB  \
# count                                       2.060000e+02
# mean                                        4.002796e+06
# std                                         2.250313e+07
# min                                        -1.163000e+06
# 25%                                         1.407500e+05
# 50%                                         6.005000e+05
# 75%                                         2.050750e+06
# max                                         3.110270e+08
#
#        2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# count                                       5.100000e+01
# mean                                        6.244314e+05
# std                                         1.190632e+06
# min                                         1.000000e+03
# 25%                                         4.150000e+04
# 50%                                         1.610000e+05
# 75%                                         5.385000e+05
# max                                         6.589000e+06
#
#        2019, Всего использовано средств, RUB  \
# count                           2.840000e+02
# mean                            1.374354e+07
# std                             5.908279e+07
# min                            -4.382000e+06
# 25%                             2.125000e+05
# 50%                             9.745000e+05
# 75%                             4.080250e+06
# max                             7.052140e+08
#
#        2019, Остаток средств на конец отчетного года, RUB     БГ  Лизинг  \
# count                                       2.240000e+02   336.0   502.0
# mean                                        2.559946e+06     1.0     1.0
# std                                         4.291811e+07     0.0     0.0
# min                                        -4.208010e+08     1.0     1.0
# 25%                                         1.000000e+04     1.0     1.0
# 50%                                         9.250000e+04     1.0     1.0
# 75%                                         6.530000e+05     1.0     1.0
# max                                         4.644630e+08     1.0     1.0
#
#        Залоги  численность
# count   383.0   146.000000
# mean      1.0    47.431507
# std       0.0   120.178770
# min       1.0     1.000000
# 25%       1.0     1.000000
# 50%       1.0     7.000000
# 75%       1.0    36.250000
# max       1.0   920.000000
#
# [8 rows x 142 columns]

# %%
pd.isnull(data).sum()
#после объединения данных получил большое количество пропусков в столбцах, которые планирую использовать как данные для предсказания
# Out:
# ID                                                        0
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
#                                                       ...
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                    11891
# Лизинг                                                11725
# Залоги                                                11844
# численность                                           12081
# Length: 149, dtype: int64

# %%
data[['БГ', 'Лизинг', 'Залоги']] = data[['БГ', 'Лизинг', 'Залоги']].fillna(value=0) #обрабатываем пропуски в столбцах,которые будут испоьзоваться при формировании целевых переменных

# %%
pd.isnull(data).sum()
# Out:
# ID                                                        0
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
#                                                       ...
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                        0
# Лизинг                                                    0
# Залоги                                                    0
# численность                                           12081
# Length: 149, dtype: int64

# %%
 #анализирум данные в целевых переменных
    print(data["Лизинг"].value_counts())
    print(data["БГ"].value_counts())
    print(data["Залоги"].value_counts())
# Out:
# 0.0    11725
# 1.0      502
# Name: Лизинг, dtype: int64
# 0.0    11891
# 1.0      336
# Name: БГ, dtype: int64
# 0.0    11844
# 1.0      383
# Name: Залоги, dtype: int64

# %% [markdown]
# ## Подготовка данных для задачи по предсказанию фонда оплаты труда и количества сотрудников:

# %%
#Для удобства работы решил разбить данные на отдельные части для каждой задачи
zp = data[['ID',
           'Дата регистрации',
           'Код статистики',
           'Отрасль',
           'Форма собственности',
           'Налоговый режим',
           '2018, Доходы, RUB',
           '2018, Расходы, RUB',
           '2018, Налоги, RUB',
           '2018, Страховые взносы в ПФР, RUB',
           '2018, Страховые взносы в ФОМС, RUB',
           '2018, Страховые взносы в ФСС, RUB',
           '2018, Основные средства , RUB',
           '2018, Активы  всего, RUB',
           '2018, Собственный капитал, RUB',
           '2018, Выручка, RUB',
           '2018, Управленческие расходы, RUB',
           '2018, Прочие расходы, RUB',
           '2018, Чистая прибыль (убыток), RUB',
           '2018, Оплата труда, RUB',
           '2018, Среднесписочная численность работников'
          ]].copy()

# %%
zp.head(3)
# Out:
#          ID Дата регистрации  Код статистики       Отрасль  \
# 0   4283790       2003-10-14      71115178.0  Производство
# 1  12390280       2019-10-28      42006784.0  Производство
# 2   9603036       2014-11-11      35394691.0  Производство
#
#      Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 0  Частная собственность             УСН          1211000.0
# 1  Частная собственность             NaN                NaN
# 2  Частная собственность             УСН                NaN
#
#    2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 0           1167000.0            16597.0                                NaN
# 1                 NaN                NaN                                NaN
# 2                 NaN                NaN                                NaN
#
#    ...  2018, Страховые взносы в ФСС, RUB  2018, Основные средства , RUB  \
# 0  ...                                NaN                       620000.0
# 1  ...                                NaN                            NaN
# 2  ...                                NaN                            NaN
#
#    2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# 0                  725000.0                        600000.0
# 1                       NaN                             NaN
# 2                       NaN                             NaN
#
#    2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# 0           1211000.0                          1167000.0
# 1                 NaN                                NaN
# 2                 NaN                                NaN
#
#    2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# 0                        NaN                             29000.0
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
#
#    2018, Оплата труда, RUB  2018, Среднесписочная численность работников
# 0                      NaN                                           1.0
# 1                      NaN                                           NaN
# 2                      NaN                                           1.0
#
# [3 rows x 21 columns]

# %%
zp.describe()
# Out:
#                  ID  Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count  1.222700e+04    1.217000e+04       6.723000e+03        6.723000e+03
# mean   7.363669e+06    4.774692e+07       6.765525e+07        6.378047e+07
# std    3.404972e+06    2.764807e+07       7.662991e+08        7.547269e+08
# min    1.536000e+03    4.716000e+04      -1.194900e+07        0.000000e+00
# 25%    5.049960e+06    2.777519e+07       7.355000e+05        7.990000e+05
# 50%    7.886504e+06    4.236241e+07       5.002000e+06        4.695000e+06
# 75%    1.002957e+07    7.112371e+07       2.242800e+07        2.078800e+07
# max    1.254730e+07    9.971510e+07       5.336259e+10        5.322594e+10
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       6.916000e+03                       5.499000e+03
# mean        5.102139e+06                       7.388361e+05
# std         1.360288e+08                       3.978190e+06
# min         1.000000e+00                       0.000000e+00
# 25%         4.995900e+04                       2.965100e+04
# 50%         1.923335e+05                       8.936400e+04
# 75%         7.323502e+05                       2.944060e+05
# max         1.070500e+10                       1.115868e+08
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        4.744000e+03                       4.736000e+03
# mean                         1.751858e+05                       9.021046e+04
# std                          9.998552e+05                       4.713477e+05
# min                          0.000000e+00                       0.000000e+00
# 25%                          6.167000e+03                       3.480000e+03
# 50%                          1.744550e+04                       9.973500e+03
# 75%                          5.636650e+04                       3.213825e+04
# max                          2.868460e+07                       1.089792e+07
#
#        2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# count                   3.200000e+03              7.846000e+03
# mean                    2.299829e+07              5.023655e+07
# std                     1.615269e+08              8.387364e+08
# min                     1.000000e+03              1.000000e+03
# 25%                     1.710000e+05              2.200000e+05
# 50%                     1.086000e+06              2.501000e+06
# 75%                     5.895750e+06              1.492825e+07
# max                     5.718265e+09              7.070885e+10
#
#        2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# count                    7.861000e+03        5.425000e+03
# mean                     1.279608e+07        6.001181e+07
# std                      1.643961e+08        3.976602e+08
# min                     -2.577266e+09        1.000000e+03
# 25%                      1.000000e+04        1.506000e+06
# 50%                      3.160000e+05        6.569000e+06
# 75%                      4.209000e+06        2.688100e+07
# max                      8.765452e+09        1.426563e+10
#
#        2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# count                       1.057000e+03               5.447000e+03
# mean                        1.056397e+07               7.865489e+06
# std                         2.940112e+07               7.143855e+07
# min                        -1.182300e+07              -8.895000e+06
# 25%                         2.790000e+05               2.600000e+04
# 50%                         1.579000e+06               1.210000e+05
# 75%                         8.066000e+06               9.990000e+05
# max                         4.437720e+08               2.404268e+09
#
#        2018, Чистая прибыль (убыток), RUB  2018, Оплата труда, RUB  \
# count                        6.163000e+03             5.980000e+02
# mean                         2.957388e+06             2.301952e+07
# std                          4.580852e+07             6.359598e+07
# min                         -1.494500e+09            -2.861600e+07
# 25%                         -8.500000e+04             3.860000e+05
# 50%                          1.010000e+05             2.495500e+06
# 75%                          1.091500e+06             1.461550e+07
# max                          2.081940e+09             6.265480e+08
#
#        2018, Среднесписочная численность работников
# count                                   7860.000000
# mean                                       8.708397
# std                                       57.392902
# min                                        1.000000
# 25%                                        1.000000
# 50%                                        1.000000
# 75%                                        5.000000
# max                                     4079.000000

# %%
pd.isnull(zp).sum()
# Out:
# ID                                                  0
# Дата регистрации                                   17
# Код статистики                                     57
# Отрасль                                             0
# Форма собственности                                41
# Налоговый режим                                  4482
# 2018, Доходы, RUB                                5504
# 2018, Расходы, RUB                               5504
# 2018, Налоги, RUB                                5311
# 2018, Страховые взносы в ПФР, RUB                6728
# 2018, Страховые взносы в ФОМС, RUB               7483
# 2018, Страховые взносы в ФСС, RUB                7491
# 2018, Основные средства , RUB                    9027
# 2018, Активы  всего, RUB                         4381
# 2018, Собственный капитал, RUB                   4366
# 2018, Выручка, RUB                               6802
# 2018, Управленческие расходы, RUB               11170
# 2018, Прочие расходы, RUB                        6780
# 2018, Чистая прибыль (убыток), RUB               6064
# 2018, Оплата труда, RUB                         11629
# 2018, Среднесписочная численность работников     4367
# dtype: int64

# %% [markdown]
# При анализе пропущенных значений видно что в исходных данных много пропусков в столбце "2018, Оплата труда, RUB" и что данных по среднесписочной численности сотрудников более чем в 10 раз больше.
# Так как мы анализируем оплату труда только по одному региону(в нашей выборке включены только компании Каллининградской области) то для уменьшения количества пропущенных данных попробуем заполнить пропуски в оплате труда по следующему алгоритму:
# 1. Из исходных данных рассчитаем среднюю опату труда на одного сотрудника (добавю отдельный столбец '2018, Средняя оплата труда сотрудника')
# 2. Заполним пропуски в стобце '2018, Средняя оплата труда сотрудника' средними значниями по этому столбцу
# 3. Добавим столбец '2018, ФОТ' с рассчетными значениями произведения количества сотрудников и средней оплаты труда
# 4. Удалим столбец '2018, Средняя оплата труда сотрудника'
# 5. Сравним данные из '2018, ФОТ' с данными в столбце "2018, Оплата труда, RUB" и в случае большой доли совпадения данных, будем использовать его в качестве целевого значения
# 6. Удалим столбец '2018, Средняя оплата труда сотрудника'

# %%
#рассчитываем среднюю оплату труда сотрудника за год
zp['2018, Средняя оплата труда сотрудника'] =  zp['2018, Оплата труда, RUB'] / zp['2018, Среднесписочная численность работников'].astype(float)

# %%
#заполняем пропуски среними значениями по столбцу
zp['2018, Средняя оплата труда сотрудника'] = zp['2018, Средняя оплата труда сотрудника'].fillna(zp['2018, Средняя оплата труда сотрудника'].mean())

# %%
#добавляем столбец с рассчетным фондом оплаты труда
zp['2018, ФОТ'] = zp['2018, Средняя оплата труда сотрудника'] * zp['2018, Среднесписочная численность работников'].astype(float)

# %%
# анализируем количество имеющихся данных в столбце '2018, Оплата труда, RUB'
zp['2018, Оплата труда, RUB'].count()
# Out:
# 598

# %%
# создаем временный столбец для проверки расчетного ФОТ(сверяем рассчетный ФОТ с фактическим)
zp['test'] = zp['2018, ФОТ'] == zp['2018, Оплата труда, RUB']

# %%
#анализируем данные полученные при проверке
zp['test'].value_counts()
# Out:
# False    11721
# True       506
# Name: test, dtype: int64

# %%
#рассчитываю точность расчета
print('рассчитанные данные соответствуют фактическим на', 506/598*100,'%')
# Out:
# рассчитанные данные соответствуют фактическим на 84.61538461538461 %

# %%
#to do: Подумать как в качестве заполнтелей пропусков в столбце '2018, Оплата труда, RUB' исползовать данные из '2018, ФОТ'

# %% [markdown]
# За целевую переменную будем брать рассчитанные значения ФОТ

# %%
#удаляем временные столбцы и столбец с фактическими данными по оплате труда(он будет заменен столбцом с рассчетными значениями)
del zp['2018, Средняя оплата труда сотрудника']
del zp['2018, Оплата труда, RUB']
del zp['test']

# %%
#отсутствие значений в столбце с расходами будем интерпритировать как нулевые расходы
zp['2018, Управленческие расходы, RUB'] = zp['2018, Управленческие расходы, RUB'].fillna(0)

# %%
#проанализируем пропуски после преобразований
pd.isnull(zp).sum()
# Out:
# ID                                                 0
# Дата регистрации                                  17
# Код статистики                                    57
# Отрасль                                            0
# Форма собственности                               41
# Налоговый режим                                 4482
# 2018, Доходы, RUB                               5504
# 2018, Расходы, RUB                              5504
# 2018, Налоги, RUB                               5311
# 2018, Страховые взносы в ПФР, RUB               6728
# 2018, Страховые взносы в ФОМС, RUB              7483
# 2018, Страховые взносы в ФСС, RUB               7491
# 2018, Основные средства , RUB                   9027
# 2018, Активы  всего, RUB                        4381
# 2018, Собственный капитал, RUB                  4366
# 2018, Выручка, RUB                              6802
# 2018, Управленческие расходы, RUB                  0
# 2018, Прочие расходы, RUB                       6780
# 2018, Чистая прибыль (убыток), RUB              6064
# 2018, Среднесписочная численность работников    4367
# 2018, ФОТ                                       4367
# dtype: int64

# %%
del zp['2018, Основные средства , RUB']

# %%
zp = zp.dropna() #удаляем пропущенные значения

# %% [markdown]
# ## Подготовка данных для задачи по классификации клиентов на кредитующихся и не кредитующихся

# %%
# выбираем данные для анализа
cred = data[['ID',
             'Дата регистрации',
             'Код статистики',
             'Отрасль',
             'Форма собственности',
             'Налоговый режим',
             'Код причины постановки на учет',
             '2019, Основные средства , RUB',
             '2019, Долгосрочные финансовые вложения, RUB',
             '2019, Отложенные налоговые активы, RUB',
             '2019, Внеоборотные активы, RUB',
             '2019, Чистые активы, RUB',
             '2019, Запасы, RUB',
             '2019, НДС по приобретенным ценностям , RUB',
             '2019, Дебиторская задолженность, RUB',
             '2019, Краткосрочные финансовые вложения, RUB',
             '2019, Денежные средства и денежные эквиваленты, RUB',
             '2019, Прочие оборотные активы, RUB',
             '2019, Оборотные активы, RUB',
             '2019, Активы  всего, RUB',
             '2019, Уставный капитал , RUB',
             '2019, Добавочный капитал, RUB',
             '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
             '2019, Капитал и резервы, RUB',
             '2019, Собственный оборотный капитал, RUB',
             '2019, Себестоимость продаж, RUB',
             '2019, Валовая прибыль (убыток), RUB',
             '2019, Проценты к получению, RUB',
             '2019, Прочие доходы, RUB',
             '2019, Прибыль (убыток) до налогообложения , RUB',
             '2019, Текущий налог на прибыль, RUB',
             '2019, EBIT, RUB',
             '2019, Поступления от текущих операций, RUB',
             '2019, Поступления от продаж, RUB',
             '2019, Платежи по текущим операциям, RUB',
             '2019, Платежи поставщикам и подрядчикам, RUB',
             '2019, Оплата процентов по долговым обязательствам, RUB',
             '2019, Налог на прибыль, RUB',
             '2019, Сальдо денежных потоков от текущих операций, RUB',
             '2019, Платежи по инвестиционным операциям, RUB',
             '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
             '2019, Поступления от финансовых операций, RUB',
             '2019, Платежи по финансовым операциям, RUB',
             '2019, Сальдо денежных потоков от финансовых операций, RUB',
             '2019, Сальдо денежных потоков за отчетный период, RUB',
             '2019, Поступление денежных средств всего, RUB',
             '2019, Заёмные средства (долгосрочные), RUB',
             '2019, Прочие долгосрочные обязательства, RUB',
             '2019, Долгосрочные обязательства, RUB',
             '2019, Заёмные средства (краткосрочные), RUB',
             '2019, Кредиторская задолженность, RUB',
             '2019, Прочие краткосрочные обязательства, RUB',
             '2019, Краткосрочные обязательства, RUB',
             '2019, Пассивы всего, RUB',
             '2019, Совокупный долг, RUB',
             '2019, Собственный капитал, RUB',
             '2019, Выручка, RUB',
             '2019, Коммерческие расходы, RUB',
             '2019, Управленческие расходы, RUB',
             '2019, Прибыль (убыток) от продажи, RUB',
             '2019, Проценты к уплате, RUB',
             '2019, Прочие расходы, RUB',
             '2019, Чистая прибыль (убыток), RUB',
             '2019, Получение кредитов и займов, RUB',
             '2019, Погашение векселей, возврат кредитов и займов, RUB',
             'Залоги'
          ]].copy()

# %%
cred.head(2)
# Out:
#          ID Дата регистрации  Код статистики       Отрасль  \
# 0   4283790       2003-10-14      71115178.0  Производство
# 1  12390280       2019-10-28      42006784.0  Производство
#
#      Форма собственности Налоговый режим  Код причины постановки на учет  \
# 0  Частная собственность             УСН                     390601001.0
# 1  Частная собственность             NaN                     391401001.0
#
#    2019, Основные средства , RUB  2019, Долгосрочные финансовые вложения, RUB  \
# 0                       651000.0                                          NaN
# 1                            NaN                                          NaN
#
#    2019, Отложенные налоговые активы, RUB  ...  2019, Выручка, RUB  \
# 0                                     NaN  ...            909000.0
# 1                                     NaN  ...                 NaN
#
#    2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# 0                              NaN                            47000.0
# 1                              NaN                                NaN
#
#    2019, Прибыль (убыток) от продажи, RUB  2019, Проценты к уплате, RUB  \
# 0                               -320000.0                           NaN
# 1                                     NaN                           NaN
#
#    2019, Прочие расходы, RUB  2019, Чистая прибыль (убыток), RUB  \
# 0                    47000.0                           -365000.0
# 1                        NaN                                 NaN
#
#    2019, Получение кредитов и займов, RUB  \
# 0                                     NaN
# 1                                     NaN
#
#    2019, Погашение векселей, возврат кредитов и займов, RUB  Залоги
# 0                                                NaN            0.0
# 1                                                NaN            0.0
#
# [2 rows x 66 columns]

# %%
# анализирем признаки с наибольшим количеством пропусков
pd.isnull(cred).sum().nlargest(50)
# Out:
# 2019, Оплата процентов по долговым обязательствам, RUB           12064
# 2019, Платежи по инвестиционным операциям, RUB                   11970
# 2019, Прочие краткосрочные обязательства, RUB                    11956
# 2019, Отложенные налоговые активы, RUB                           11955
# 2019, Прочие долгосрочные обязательства, RUB                     11938
# 2019, Сальдо денежных потоков от инвестиционных операций, RUB    11932
# 2019, Погашение векселей, возврат кредитов и займов, RUB         11925
# 2019, Проценты к получению, RUB                                  11917
# 2019, Добавочный капитал, RUB                                    11890
# 2019, Налог на прибыль, RUB                                      11889
# 2019, Получение кредитов и займов, RUB                           11868
# 2019, Платежи по финансовым операциям, RUB                       11858
# 2019, НДС по приобретенным ценностям , RUB                       11830
# 2019, Поступления от финансовых операций, RUB                    11829
# 2019, Долгосрочные финансовые вложения, RUB                      11768
# 2019, Сальдо денежных потоков от финансовых операций, RUB        11767
# 2019, Краткосрочные финансовые вложения, RUB                     11710
# 2019, Поступления от продаж, RUB                                 11600
# 2019, Прочие оборотные активы, RUB                               11598
# 2019, Проценты к уплате, RUB                                     11589
# 2019, Коммерческие расходы, RUB                                  11580
# 2019, Поступления от текущих операций, RUB                       11506
# 2019, Платежи поставщикам и подрядчикам, RUB                     11504
# 2019, Сальдо денежных потоков за отчетный период, RUB            11472
# 2019, Поступление денежных средств всего, RUB                    11466
# 2019, Сальдо денежных потоков от текущих операций, RUB           11465
# 2019, Платежи по текущим операциям, RUB                          11448
# 2019, Долгосрочные обязательства, RUB                            11433
# 2019, Управленческие расходы, RUB                                11211
# 2019, Внеоборотные активы, RUB                                   10892
# 2019, Валовая прибыль (убыток), RUB                              10543
# 2019, Заёмные средства (долгосрочные), RUB                       10311
# 2019, Краткосрочные обязательства, RUB                           10145
# 2019, Нераспределенная прибыль (непокрытый убыток), RUB          10136
# 2019, Совокупный долг, RUB                                       10100
# 2019, EBIT, RUB                                                   9989
# 2019, Уставный капитал , RUB                                      9943
# 2019, Оборотные активы, RUB                                       9840
# 2019, Заёмные средства (краткосрочные), RUB                       9803
# 2019, Прочие доходы, RUB                                          9294
# 2019, Основные средства , RUB                                     9066
# 2019, Текущий налог на прибыль, RUB                               8504
# 2019, Запасы, RUB                                                 8051
# 2019, Выручка, RUB                                                6963
# 2019, Себестоимость продаж, RUB                                   6924
# 2019, Прочие расходы, RUB                                         6849
# 2019, Прибыль (убыток) от продажи, RUB                            6499
# 2019, Денежные средства и денежные эквиваленты, RUB               6342
# 2019, Прибыль (убыток) до налогообложения , RUB                   6205
# 2019, Чистая прибыль (убыток), RUB                                6196
# dtype: int64

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
cred[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]] = cred[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
pd.isnull(cred).sum() #анализируем количество пропусков после частичного заполнения данных нулевыми значениями
# Out:
# ID                                                             0
# Дата регистрации                                              17
# Код статистики                                                57
# Отрасль                                                        0
# Форма собственности                                           41
#                                                             ...
# 2019, Прочие расходы, RUB                                      0
# 2019, Чистая прибыль (убыток), RUB                          6196
# 2019, Получение кредитов и займов, RUB                         0
# 2019, Погашение векселей, возврат кредитов и займов, RUB       0
# Залоги                                                         0
# Length: 66, dtype: int64

# %%
cred = cred.dropna() #удаляем пропущенные значения

# %%
cred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 0 to 12217
# Data columns (total 66 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   ID                                                             3774 non-null   int64
#  1   Дата регистрации                                               3774 non-null   datetime64[ns]
#  2   Код статистики                                                 3774 non-null   float64
#  3   Отрасль                                                        3774 non-null   object
#  4   Форма собственности                                            3774 non-null   object
#  5   Налоговый режим                                                3774 non-null   object
#  6   Код причины постановки на учет                                 3774 non-null   float64
#  7   2019, Основные средства , RUB                                  3774 non-null   float64
#  8   2019, Долгосрочные финансовые вложения, RUB                    3774 non-null   float64
#  9   2019, Отложенные налоговые активы, RUB                         3774 non-null   float64
#  10  2019, Внеоборотные активы, RUB                                 3774 non-null   float64
#  11  2019, Чистые активы, RUB                                       3774 non-null   float64
#  12  2019, Запасы, RUB                                              3774 non-null   float64
#  13  2019, НДС по приобретенным ценностям , RUB                     3774 non-null   float64
#  14  2019, Дебиторская задолженность, RUB                           3774 non-null   float64
#  15  2019, Краткосрочные финансовые вложения, RUB                   3774 non-null   float64
#  16  2019, Денежные средства и денежные эквиваленты, RUB            3774 non-null   float64
#  17  2019, Прочие оборотные активы, RUB                             3774 non-null   float64
#  18  2019, Оборотные активы, RUB                                    3774 non-null   float64
#  19  2019, Активы  всего, RUB                                       3774 non-null   float64
#  20  2019, Уставный капитал , RUB                                   3774 non-null   float64
#  21  2019, Добавочный капитал, RUB                                  3774 non-null   float64
#  22  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3774 non-null   float64
#  23  2019, Капитал и резервы, RUB                                   3774 non-null   float64
#  24  2019, Собственный оборотный капитал, RUB                       3774 non-null   float64
#  25  2019, Себестоимость продаж, RUB                                3774 non-null   float64
#  26  2019, Валовая прибыль (убыток), RUB                            3774 non-null   float64
#  27  2019, Проценты к получению, RUB                                3774 non-null   float64
#  28  2019, Прочие доходы, RUB                                       3774 non-null   float64
#  29  2019, Прибыль (убыток) до налогообложения , RUB                3774 non-null   float64
#  30  2019, Текущий налог на прибыль, RUB                            3774 non-null   float64
#  31  2019, EBIT, RUB                                                3774 non-null   float64
#  32  2019, Поступления от текущих операций, RUB                     3774 non-null   float64
#  33  2019, Поступления от продаж, RUB                               3774 non-null   float64
#  34  2019, Платежи по текущим операциям, RUB                        3774 non-null   float64
#  35  2019, Платежи поставщикам и подрядчикам, RUB                   3774 non-null   float64
#  36  2019, Оплата процентов по долговым обязательствам, RUB         3774 non-null   float64
#  37  2019, Налог на прибыль, RUB                                    3774 non-null   float64
#  38  2019, Сальдо денежных потоков от текущих операций, RUB         3774 non-null   float64
#  39  2019, Платежи по инвестиционным операциям, RUB                 3774 non-null   float64
#  40  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3774 non-null   float64
#  41  2019, Поступления от финансовых операций, RUB                  3774 non-null   float64
#  42  2019, Платежи по финансовым операциям, RUB                     3774 non-null   float64
#  43  2019, Сальдо денежных потоков от финансовых операций, RUB      3774 non-null   float64
#  44  2019, Сальдо денежных потоков за отчетный период, RUB          3774 non-null   float64
#  45  2019, Поступление денежных средств всего, RUB                  3774 non-null   float64
#  46  2019, Заёмные средства (долгосрочные), RUB                     3774 non-null   float64
#  47  2019, Прочие долгосрочные обязательства, RUB                   3774 non-null   float64
#  48  2019, Долгосрочные обязательства, RUB                          3774 non-null   float64
#  49  2019, Заёмные средства (краткосрочные), RUB                    3774 non-null   float64
#  50  2019, Кредиторская задолженность, RUB                          3774 non-null   float64
#  51  2019, Прочие краткосрочные обязательства, RUB                  3774 non-null   float64
#  52  2019, Краткосрочные обязательства, RUB                         3774 non-null   float64
#  53  2019, Пассивы всего, RUB                                       3774 non-null   float64
#  54  2019, Совокупный долг, RUB                                     3774 non-null   float64
#  55  2019, Собственный капитал, RUB                                 3774 non-null   float64
#  56  2019, Выручка, RUB                                             3774 non-null   float64
#  57  2019, Коммерческие расходы, RUB                                3774 non-null   float64
#  58  2019, Управленческие расходы, RUB                              3774 non-null   float64
#  59  2019, Прибыль (убыток) от продажи, RUB                         3774 non-null   float64
#  60  2019, Проценты к уплате, RUB                                   3774 non-null   float64
#  61  2019, Прочие расходы, RUB                                      3774 non-null   float64
#  62  2019, Чистая прибыль (убыток), RUB                             3774 non-null   float64
#  63  2019, Получение кредитов и займов, RUB                         3774 non-null   float64
#  64  2019, Погашение векселей, возврат кредитов и займов, RUB       3774 non-null   float64
#  65  Залоги                                                         3774 non-null   float64
# dtypes: datetime64[ns](1), float64(61), int64(1), object(3)
# memory usage: 1.9+ MB

# %%
cred.corr()
# Out:
#                                                           ID  Код статистики  \
# ID                                                  1.000000       -0.399750
# Код статистики                                     -0.399750        1.000000
# Код причины постановки на учет                      0.002363       -0.019545
# 2019, Основные средства , RUB                      -0.063227        0.032946
# 2019, Долгосрочные финансовые вложения, RUB        -0.009766        0.020267
# ...                                                      ...             ...
# 2019, Прочие расходы, RUB                          -0.002476        0.008844
# 2019, Чистая прибыль (убыток), RUB                 -0.000452        0.005996
# 2019, Получение кредитов и займов, RUB              0.000796        0.008077
# 2019, Погашение векселей, возврат кредитов и за...  0.007239        0.003224
# Залоги                                             -0.099197        0.068211
#
#                                                     Код причины постановки на учет  \
# ID                                                                        0.002363
# Код статистики                                                           -0.019545
# Код причины постановки на учет                                            1.000000
# 2019, Основные средства , RUB                                             0.009840
# 2019, Долгосрочные финансовые вложения, RUB                               0.016911
# ...                                                                            ...
# 2019, Прочие расходы, RUB                                                 0.034230
# 2019, Чистая прибыль (убыток), RUB                                        0.029260
# 2019, Получение кредитов и займов, RUB                                   -0.011391
# 2019, Погашение векселей, возврат кредитов и за...                       -0.017948
# Залоги                                                                   -0.006027
#
#                                                     2019, Основные средства , RUB  \
# ID                                                                      -0.063227
# Код статистики                                                           0.032946
# Код причины постановки на учет                                           0.009840
# 2019, Основные средства , RUB                                            1.000000
# 2019, Долгосрочные финансовые вложения, RUB                              0.045771
# ...                                                                           ...
# 2019, Прочие расходы, RUB                                                0.010947
# 2019, Чистая прибыль (убыток), RUB                                       0.017812
# 2019, Получение кредитов и займов, RUB                                   0.200966
# 2019, Погашение векселей, возврат кредитов и за...                       0.148168
# Залоги                                                                   0.091228
#
#                                                     2019, Долгосрочные финансовые вложения, RUB  \
# ID                                                                                    -0.009766
# Код статистики                                                                         0.020267
# Код причины постановки на учет                                                         0.016911
# 2019, Основные средства , RUB                                                          0.045771
# 2019, Долгосрочные финансовые вложения, RUB                                            1.000000
# ...                                                                                         ...
# 2019, Прочие расходы, RUB                                                              0.016757
# 2019, Чистая прибыль (убыток), RUB                                                     0.014741
# 2019, Получение кредитов и займов, RUB                                                 0.084299
# 2019, Погашение векселей, возврат кредитов и за...                                     0.066012
# Залоги                                                                                -0.003647
#
#                                                     2019, Отложенные налоговые активы, RUB  \
# ID                                                                                0.023867
# Код статистики                                                                   -0.003212
# Код причины постановки на учет                                                   -0.011327
# 2019, Основные средства , RUB                                                    -0.004375
# 2019, Долгосрочные финансовые вложения, RUB                                      -0.001587
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.003215
# 2019, Чистая прибыль (убыток), RUB                                               -0.007032
# 2019, Получение кредитов и займов, RUB                                            0.026314
# 2019, Погашение векселей, возврат кредитов и за...                                0.023146
# Залоги                                                                            0.002824
#
#                                                     2019, Внеоборотные активы, RUB  \
# ID                                                                       -0.022050
# Код статистики                                                            0.015473
# Код причины постановки на учет                                            0.010378
# 2019, Основные средства , RUB                                             0.710150
# 2019, Долгосрочные финансовые вложения, RUB                               0.365460
# ...                                                                            ...
# 2019, Прочие расходы, RUB                                                 0.010373
# 2019, Чистая прибыль (убыток), RUB                                        0.016227
# 2019, Получение кредитов и займов, RUB                                    0.202314
# 2019, Погашение векселей, возврат кредитов и за...                        0.148389
# Залоги                                                                    0.016559
#
#                                                     2019, Чистые активы, RUB  \
# ID                                                                 -0.087155
# Код статистики                                                      0.030378
# Код причины постановки на учет                                     -0.011001
# 2019, Основные средства , RUB                                       0.409259
# 2019, Долгосрочные финансовые вложения, RUB                         0.097176
# ...                                                                      ...
# 2019, Прочие расходы, RUB                                           0.007668
# 2019, Чистая прибыль (убыток), RUB                                  0.068274
# 2019, Получение кредитов и займов, RUB                              0.048442
# 2019, Погашение векселей, возврат кредитов и за...                  0.045107
# Залоги                                                              0.080199
#
#                                                     2019, Запасы, RUB  \
# ID                                                          -0.070176
# Код статистики                                               0.022029
# Код причины постановки на учет                               0.002328
# 2019, Основные средства , RUB                                0.131290
# 2019, Долгосрочные финансовые вложения, RUB                  0.033685
# ...                                                               ...
# 2019, Прочие расходы, RUB                                    0.010308
# 2019, Чистая прибыль (убыток), RUB                           0.013121
# 2019, Получение кредитов и займов, RUB                       0.209856
# 2019, Погашение векселей, возврат кредитов и за...           0.200832
# Залоги                                                       0.098826
#
#                                                     2019, НДС по приобретенным ценностям , RUB  \
# ID                                                                                   -0.018008
# Код статистики                                                                        0.018220
# Код причины постановки на учет                                                       -0.021628
# 2019, Основные средства , RUB                                                         0.095988
# 2019, Долгосрочные финансовые вложения, RUB                                          -0.002275
# ...                                                                                        ...
# 2019, Прочие расходы, RUB                                                             0.003918
# 2019, Чистая прибыль (убыток), RUB                                                    0.001988
# 2019, Получение кредитов и займов, RUB                                                0.203943
# 2019, Погашение векселей, возврат кредитов и за...                                    0.247407
# Залоги                                                                                0.077518
#
#                                                     ...  2019, Выручка, RUB  \
# ID                                                  ...            0.002102
# Код статистики                                      ...            0.001745
# Код причины постановки на учет                      ...            0.035330
# 2019, Основные средства , RUB                       ...            0.012960
# 2019, Долгосрочные финансовые вложения, RUB         ...            0.005089
# ...                                                 ...                 ...
# 2019, Прочие расходы, RUB                           ...            0.984060
# 2019, Чистая прибыль (убыток), RUB                  ...            0.964884
# 2019, Получение кредитов и займов, RUB              ...            0.024294
# 2019, Погашение векселей, возврат кредитов и за...  ...            0.025969
# Залоги                                              ...            0.006733
#
#                                                     2019, Коммерческие расходы, RUB  \
# ID                                                                        -0.039341
# Код статистики                                                             0.008707
# Код причины постановки на учет                                            -0.023253
# 2019, Основные средства , RUB                                              0.053941
# 2019, Долгосрочные финансовые вложения, RUB                                0.047480
# ...                                                                             ...
# 2019, Прочие расходы, RUB                                                  0.009467
# 2019, Чистая прибыль (убыток), RUB                                         0.001162
# 2019, Получение кредитов и займов, RUB                                     0.189932
# 2019, Погашение векселей, возврат кредитов и за...                         0.218307
# Залоги                                                                     0.104574
#
#                                                     2019, Управленческие расходы, RUB  \
# ID                                                                          -0.047196
# Код статистики                                                               0.016059
# Код причины постановки на учет                                               0.024817
# 2019, Основные средства , RUB                                                0.168706
# 2019, Долгосрочные финансовые вложения, RUB                                  0.035887
# ...                                                                               ...
# 2019, Прочие расходы, RUB                                                    0.007986
# 2019, Чистая прибыль (убыток), RUB                                           0.005240
# 2019, Получение кредитов и займов, RUB                                       0.140348
# 2019, Погашение векселей, возврат кредитов и за...                           0.148337
# Залоги                                                                       0.077085
#
#                                                     2019, Прибыль (убыток) от продажи, RUB  \
# ID                                                                                0.000738
# Код статистики                                                                    0.003043
# Код причины постановки на учет                                                    0.031364
# 2019, Основные средства , RUB                                                     0.016476
# 2019, Долгосрочные финансовые вложения, RUB                                       0.013245
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.990443
# 2019, Чистая прибыль (убыток), RUB                                                0.992732
# 2019, Получение кредитов и займов, RUB                                            0.003874
# 2019, Погашение векселей, возврат кредитов и за...                                0.003565
# Залоги                                                                            0.001733
#
#                                                     2019, Проценты к уплате, RUB  \
# ID                                                                     -0.039040
# Код статистики                                                          0.033618
# Код причины постановки на учет                                         -0.025058
# 2019, Основные средства , RUB                                           0.252900
# 2019, Долгосрочные финансовые вложения, RUB                             0.089861
# ...                                                                          ...
# 2019, Прочие расходы, RUB                                               0.010938
# 2019, Чистая прибыль (убыток), RUB                                      0.007154
# 2019, Получение кредитов и займов, RUB                                  0.490697
# 2019, Погашение векселей, возврат кредитов и за...                      0.471778
# Залоги                                                                  0.191125
#
#                                                     2019, Прочие расходы, RUB  \
# ID                                                                  -0.002476
# Код статистики                                                       0.008844
# Код причины постановки на учет                                       0.034230
# 2019, Основные средства , RUB                                        0.010947
# 2019, Долгосрочные финансовые вложения, RUB                          0.016757
# ...                                                                       ...
# 2019, Прочие расходы, RUB                                            1.000000
# 2019, Чистая прибыль (убыток), RUB                                   0.986053
# 2019, Получение кредитов и займов, RUB                               0.004693
# 2019, Погашение векселей, возврат кредитов и за...                   0.005443
# Залоги                                                               0.001374
#
#                                                     2019, Чистая прибыль (убыток), RUB  \
# ID                                                                           -0.000452
# Код статистики                                                                0.005996
# Код причины постановки на учет                                                0.029260
# 2019, Основные средства , RUB                                                 0.017812
# 2019, Долгосрочные финансовые вложения, RUB                                   0.014741
# ...                                                                                ...
# 2019, Прочие расходы, RUB                                                     0.986053
# 2019, Чистая прибыль (убыток), RUB                                            1.000000
# 2019, Получение кредитов и займов, RUB                                        0.003548
# 2019, Погашение векселей, возврат кредитов и за...                            0.003832
# Залоги                                                                        0.000115
#
#                                                     2019, Получение кредитов и займов, RUB  \
# ID                                                                                0.000796
# Код статистики                                                                    0.008077
# Код причины постановки на учет                                                   -0.011391
# 2019, Основные средства , RUB                                                     0.200966
# 2019, Долгосрочные финансовые вложения, RUB                                       0.084299
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.004693
# 2019, Чистая прибыль (убыток), RUB                                                0.003548
# 2019, Получение кредитов и займов, RUB                                            1.000000
# 2019, Погашение векселей, возврат кредитов и за...                                0.950820
# Залоги                                                                            0.127575
#
#                                                     2019, Погашение векселей, возврат кредитов и займов, RUB  \
# ID                                                                                           0.007239
# Код статистики                                                                               0.003224
# Код причины постановки на учет                                                              -0.017948
# 2019, Основные средства , RUB                                                                0.148168
# 2019, Долгосрочные финансовые вложения, RUB                                                  0.066012
# ...                                                                                               ...
# 2019, Прочие расходы, RUB                                                                    0.005443
# 2019, Чистая прибыль (убыток), RUB                                                           0.003832
# 2019, Получение кредитов и займов, RUB                                                       0.950820
# 2019, Погашение векселей, возврат кредитов и за...                                           1.000000
# Залоги                                                                                       0.130575
#
#                                                       Залоги
# ID                                                 -0.099197
# Код статистики                                      0.068211
# Код причины постановки на учет                     -0.006027
# 2019, Основные средства , RUB                       0.091228
# 2019, Долгосрочные финансовые вложения, RUB        -0.003647
# ...                                                      ...
# 2019, Прочие расходы, RUB                           0.001374
# 2019, Чистая прибыль (убыток), RUB                  0.000115
# 2019, Получение кредитов и займов, RUB              0.127575
# 2019, Погашение векселей, возврат кредитов и за...  0.130575
# Залоги                                              1.000000
#
# [62 rows x 62 columns]

# %% [markdown]
# ## Подготовка данных для задачи по классификации на компании используюзие банковские гарантии

# %%
# Для удобства работы решил разбить данные на отдельные части для каждой задачи
# данные для предказания наличия гарантий
bg = data[['ID',
           'Дата регистрации',
           'Код статистики',
           'Отрасль',
           'Форма собственности',
           'Налоговый режим',
           'Код причины постановки на учет',
           '2019, Основные средства , RUB',
           '2019, Долгосрочные финансовые вложения, RUB',
           '2019, Отложенные налоговые активы, RUB',
           '2019, Внеоборотные активы, RUB',
           '2019, Чистые активы, RUB',
           '2019, Запасы, RUB',
           '2019, НДС по приобретенным ценностям , RUB',
           '2019, Дебиторская задолженность, RUB',
           '2019, Краткосрочные финансовые вложения, RUB',
           '2019, Денежные средства и денежные эквиваленты, RUB',
           '2019, Прочие оборотные активы, RUB',
           '2019, Оборотные активы, RUB',
           '2019, Активы  всего, RUB',
           '2019, Уставный капитал , RUB',
           '2019, Добавочный капитал, RUB',
           '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
           '2019, Капитал и резервы, RUB',
           '2019, Собственный оборотный капитал, RUB',
           '2019, Себестоимость продаж, RUB',
           '2019, Валовая прибыль (убыток), RUB',
           '2019, Проценты к получению, RUB',
           '2019, Прочие доходы, RUB',
           '2019, Прибыль (убыток) до налогообложения , RUB',
           '2019, Текущий налог на прибыль, RUB',
           '2019, EBIT, RUB',
           '2019, Поступления от текущих операций, RUB',
           '2019, Поступления от продаж, RUB',
           '2019, Платежи по текущим операциям, RUB',
           '2019, Платежи поставщикам и подрядчикам, RUB',
           '2019, Оплата процентов по долговым обязательствам, RUB',
           '2019, Налог на прибыль, RUB',
           '2019, Сальдо денежных потоков от текущих операций, RUB',
           '2019, Платежи по инвестиционным операциям, RUB',
           '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
           '2019, Поступления от финансовых операций, RUB',
           '2019, Платежи по финансовым операциям, RUB',
           '2019, Сальдо денежных потоков от финансовых операций, RUB',
           '2019, Сальдо денежных потоков за отчетный период, RUB',
           '2019, Поступление денежных средств всего, RUB',
           '2019, Заёмные средства (долгосрочные), RUB',
           '2019, Прочие долгосрочные обязательства, RUB',
           '2019, Долгосрочные обязательства, RUB',
           '2019, Заёмные средства (краткосрочные), RUB',
           '2019, Кредиторская задолженность, RUB',
           '2019, Прочие краткосрочные обязательства, RUB',
           '2019, Краткосрочные обязательства, RUB',
           '2019, Пассивы всего, RUB',
           '2019, Совокупный долг, RUB',
           '2019, Собственный капитал, RUB',
           '2019, Выручка, RUB',
           '2019, Коммерческие расходы, RUB',
           '2019, Управленческие расходы, RUB',
           '2019, Прибыль (убыток) от продажи, RUB',
           '2019, Проценты к уплате, RUB',
           '2019, Прочие расходы, RUB',
           '2019, Чистая прибыль (убыток), RUB',
           '2019, Получение кредитов и займов, RUB',
           '2019, Погашение векселей, возврат кредитов и займов, RUB',
           'БГ'
          ]].copy()

# %%
bg.head(3)
# Out:
#          ID Дата регистрации  Код статистики       Отрасль  \
# 0   4283790       2003-10-14      71115178.0  Производство
# 1  12390280       2019-10-28      42006784.0  Производство
# 2   9603036       2014-11-11      35394691.0  Производство
#
#      Форма собственности Налоговый режим  Код причины постановки на учет  \
# 0  Частная собственность             УСН                     390601001.0
# 1  Частная собственность             NaN                     391401001.0
# 2  Частная собственность             УСН                     390601001.0
#
#    2019, Основные средства , RUB  2019, Долгосрочные финансовые вложения, RUB  \
# 0                       651000.0                                          NaN
# 1                            NaN                                          NaN
# 2                            NaN                                          NaN
#
#    2019, Отложенные налоговые активы, RUB  ...  2019, Выручка, RUB  \
# 0                                     NaN  ...            909000.0
# 1                                     NaN  ...                 NaN
# 2                                     NaN  ...                 NaN
#
#    2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# 0                              NaN                            47000.0
# 1                              NaN                                NaN
# 2                              NaN                                NaN
#
#    2019, Прибыль (убыток) от продажи, RUB  2019, Проценты к уплате, RUB  \
# 0                               -320000.0                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
#
#    2019, Прочие расходы, RUB  2019, Чистая прибыль (убыток), RUB  \
# 0                    47000.0                           -365000.0
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
#
#    2019, Получение кредитов и займов, RUB  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#    2019, Погашение векселей, возврат кредитов и займов, RUB   БГ
# 0                                                NaN         0.0
# 1                                                NaN         0.0
# 2                                                NaN         0.0
#
# [3 rows x 66 columns]

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
bg[['2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',     
    '2019, Дебиторская задолженность, RUB',    
    '2019, Краткосрочные финансовые вложения, RUB',   
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',          
    '2019, Активы  всего, RUB',  
    '2019, Уставный капитал , RUB',           
    '2019, Добавочный капитал, RUB',           
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',          
    '2019, Капитал и резервы, RUB',           
    '2019, Собственный оборотный капитал, RUB',           
    '2019, Себестоимость продаж, RUB',         
    '2019, Валовая прибыль (убыток), RUB',         
    '2019, Проценты к получению, RUB',        
    '2019, Прочие доходы, RUB',      
    '2019, Прибыль (убыток) до налогообложения , RUB',      
    '2019, Текущий налог на прибыль, RUB',         
    '2019, EBIT, RUB',     
    '2019, Поступления от текущих операций, RUB',         
    '2019, Поступления от продаж, RUB',       
    '2019, Платежи по текущим операциям, RUB',         
    '2019, Платежи поставщикам и подрядчикам, RUB',          
    '2019, Оплата процентов по долговым обязательствам, RUB',          
    '2019, Налог на прибыль, RUB',           
    '2019, Сальдо денежных потоков от текущих операций, RUB',       
    '2019, Платежи по инвестиционным операциям, RUB',          
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',         
    '2019, Поступления от финансовых операций, RUB',          
    '2019, Платежи по финансовым операциям, RUB',         
    '2019, Сальдо денежных потоков от финансовых операций, RUB',        
    '2019, Сальдо денежных потоков за отчетный период, RUB',          
    '2019, Поступление денежных средств всего, RUB'
]] = bg[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',     
    '2019, Дебиторская задолженность, RUB',    
    '2019, Краткосрочные финансовые вложения, RUB',   
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',          
    '2019, Активы  всего, RUB',  
    '2019, Уставный капитал , RUB',           
    '2019, Добавочный капитал, RUB',           
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',          
    '2019, Капитал и резервы, RUB',           
    '2019, Собственный оборотный капитал, RUB',           
    '2019, Себестоимость продаж, RUB',         
    '2019, Валовая прибыль (убыток), RUB',         
    '2019, Проценты к получению, RUB',        
    '2019, Прочие доходы, RUB',      
    '2019, Прибыль (убыток) до налогообложения , RUB',      
    '2019, Текущий налог на прибыль, RUB',         
    '2019, EBIT, RUB',     
    '2019, Поступления от текущих операций, RUB',         
    '2019, Поступления от продаж, RUB',       
    '2019, Платежи по текущим операциям, RUB',         
    '2019, Платежи поставщикам и подрядчикам, RUB',          
    '2019, Оплата процентов по долговым обязательствам, RUB',          
    '2019, Налог на прибыль, RUB',           
    '2019, Сальдо денежных потоков от текущих операций, RUB',       
    '2019, Платежи по инвестиционным операциям, RUB',          
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',         
    '2019, Поступления от финансовых операций, RUB',          
    '2019, Платежи по финансовым операциям, RUB',         
    '2019, Сальдо денежных потоков от финансовых операций, RUB',        
    '2019, Сальдо денежных потоков за отчетный период, RUB',          
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
bg = bg.dropna() #удаляем пропущенные значения

# %%
bg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 0 to 12217
# Data columns (total 66 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   ID                                                             3774 non-null   int64
#  1   Дата регистрации                                               3774 non-null   datetime64[ns]
#  2   Код статистики                                                 3774 non-null   float64
#  3   Отрасль                                                        3774 non-null   object
#  4   Форма собственности                                            3774 non-null   object
#  5   Налоговый режим                                                3774 non-null   object
#  6   Код причины постановки на учет                                 3774 non-null   float64
#  7   2019, Основные средства , RUB                                  3774 non-null   float64
#  8   2019, Долгосрочные финансовые вложения, RUB                    3774 non-null   float64
#  9   2019, Отложенные налоговые активы, RUB                         3774 non-null   float64
#  10  2019, Внеоборотные активы, RUB                                 3774 non-null   float64
#  11  2019, Чистые активы, RUB                                       3774 non-null   float64
#  12  2019, Запасы, RUB                                              3774 non-null   float64
#  13  2019, НДС по приобретенным ценностям , RUB                     3774 non-null   float64
#  14  2019, Дебиторская задолженность, RUB                           3774 non-null   float64
#  15  2019, Краткосрочные финансовые вложения, RUB                   3774 non-null   float64
#  16  2019, Денежные средства и денежные эквиваленты, RUB            3774 non-null   float64
#  17  2019, Прочие оборотные активы, RUB                             3774 non-null   float64
#  18  2019, Оборотные активы, RUB                                    3774 non-null   float64
#  19  2019, Активы  всего, RUB                                       3774 non-null   float64
#  20  2019, Уставный капитал , RUB                                   3774 non-null   float64
#  21  2019, Добавочный капитал, RUB                                  3774 non-null   float64
#  22  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3774 non-null   float64
#  23  2019, Капитал и резервы, RUB                                   3774 non-null   float64
#  24  2019, Собственный оборотный капитал, RUB                       3774 non-null   float64
#  25  2019, Себестоимость продаж, RUB                                3774 non-null   float64
#  26  2019, Валовая прибыль (убыток), RUB                            3774 non-null   float64
#  27  2019, Проценты к получению, RUB                                3774 non-null   float64
#  28  2019, Прочие доходы, RUB                                       3774 non-null   float64
#  29  2019, Прибыль (убыток) до налогообложения , RUB                3774 non-null   float64
#  30  2019, Текущий налог на прибыль, RUB                            3774 non-null   float64
#  31  2019, EBIT, RUB                                                3774 non-null   float64
#  32  2019, Поступления от текущих операций, RUB                     3774 non-null   float64
#  33  2019, Поступления от продаж, RUB                               3774 non-null   float64
#  34  2019, Платежи по текущим операциям, RUB                        3774 non-null   float64
#  35  2019, Платежи поставщикам и подрядчикам, RUB                   3774 non-null   float64
#  36  2019, Оплата процентов по долговым обязательствам, RUB         3774 non-null   float64
#  37  2019, Налог на прибыль, RUB                                    3774 non-null   float64
#  38  2019, Сальдо денежных потоков от текущих операций, RUB         3774 non-null   float64
#  39  2019, Платежи по инвестиционным операциям, RUB                 3774 non-null   float64
#  40  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3774 non-null   float64
#  41  2019, Поступления от финансовых операций, RUB                  3774 non-null   float64
#  42  2019, Платежи по финансовым операциям, RUB                     3774 non-null   float64
#  43  2019, Сальдо денежных потоков от финансовых операций, RUB      3774 non-null   float64
#  44  2019, Сальдо денежных потоков за отчетный период, RUB          3774 non-null   float64
#  45  2019, Поступление денежных средств всего, RUB                  3774 non-null   float64
#  46  2019, Заёмные средства (долгосрочные), RUB                     3774 non-null   float64
#  47  2019, Прочие долгосрочные обязательства, RUB                   3774 non-null   float64
#  48  2019, Долгосрочные обязательства, RUB                          3774 non-null   float64
#  49  2019, Заёмные средства (краткосрочные), RUB                    3774 non-null   float64
#  50  2019, Кредиторская задолженность, RUB                          3774 non-null   float64
#  51  2019, Прочие краткосрочные обязательства, RUB                  3774 non-null   float64
#  52  2019, Краткосрочные обязательства, RUB                         3774 non-null   float64
#  53  2019, Пассивы всего, RUB                                       3774 non-null   float64
#  54  2019, Совокупный долг, RUB                                     3774 non-null   float64
#  55  2019, Собственный капитал, RUB                                 3774 non-null   float64
#  56  2019, Выручка, RUB                                             3774 non-null   float64
#  57  2019, Коммерческие расходы, RUB                                3774 non-null   float64
#  58  2019, Управленческие расходы, RUB                              3774 non-null   float64
#  59  2019, Прибыль (убыток) от продажи, RUB                         3774 non-null   float64
#  60  2019, Проценты к уплате, RUB                                   3774 non-null   float64
#  61  2019, Прочие расходы, RUB                                      3774 non-null   float64
#  62  2019, Чистая прибыль (убыток), RUB                             3774 non-null   float64
#  63  2019, Получение кредитов и займов, RUB                         3774 non-null   float64
#  64  2019, Погашение векселей, возврат кредитов и займов, RUB       3774 non-null   float64
#  65  БГ                                                             3774 non-null   float64
# dtypes: datetime64[ns](1), float64(61), int64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Подготовка данных для задачи по классификации на компании пользующиеся услугами лизинга

# %%
# Для удобства работы решил разбить данные на отдельные части для каждой задачи
# данные для предсказания наличи у компании лизинга
lg = data[['ID',
           'Дата регистрации',
           'Код статистики',          
           'Отрасль',     
           'Форма собственности',      
           'Налоговый режим',
           'Код причины постановки на учет',
           '2018, Налоги, RUB',
           '2018, Налог на имущество, RUB',
           '2018, Транспортный налог, RUB',
           '2018, Активы  всего, RUB',
           '2018, Выручка, RUB',
           '2018, Основные средства , RUB',
           '2019, Основные средства , RUB',
           '2019, Долгосрочные финансовые вложения, RUB',
           '2019, Отложенные налоговые активы, RUB',
           '2019, Внеоборотные активы, RUB',
           '2019, Чистые активы, RUB',
           '2019, Запасы, RUB',
           '2019, НДС по приобретенным ценностям , RUB',
           '2019, Дебиторская задолженность, RUB',
           '2019, Краткосрочные финансовые вложения, RUB',
           '2019, Денежные средства и денежные эквиваленты, RUB',
           '2019, Прочие оборотные активы, RUB',
           '2019, Оборотные активы, RUB',
           '2019, Активы  всего, RUB',
           '2019, Уставный капитал , RUB',
           '2019, Добавочный капитал, RUB',
           '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
           '2019, Капитал и резервы, RUB',
           '2019, Собственный оборотный капитал, RUB',
           '2019, Себестоимость продаж, RUB',
           '2019, Валовая прибыль (убыток), RUB',
           '2019, Проценты к получению, RUB',
           '2019, Прочие доходы, RUB',
           '2019, Прибыль (убыток) до налогообложения , RUB',
           '2019, Текущий налог на прибыль, RUB',
           '2019, EBIT, RUB',
           '2019, Поступления от текущих операций, RUB',
           '2019, Поступления от продаж, RUB',
           '2019, Платежи по текущим операциям, RUB',
           '2019, Платежи поставщикам и подрядчикам, RUB',
           '2019, Оплата процентов по долговым обязательствам, RUB',
           '2019, Налог на прибыль, RUB',
           '2019, Сальдо денежных потоков от текущих операций, RUB',
           '2019, Платежи по инвестиционным операциям, RUB',
           '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
           '2019, Поступления от финансовых операций, RUB',
           '2019, Платежи по финансовым операциям, RUB',
           '2019, Сальдо денежных потоков от финансовых операций, RUB',
           '2019, Сальдо денежных потоков за отчетный период, RUB',
           '2019, Поступление денежных средств всего, RUB',
           '2019, Заёмные средства (долгосрочные), RUB',             
           '2019, Прочие долгосрочные обязательства, RUB',             
           '2019, Долгосрочные обязательства, RUB',             
           '2019, Заёмные средства (краткосрочные), RUB',             
           '2019, Кредиторская задолженность, RUB',             
           '2019, Прочие краткосрочные обязательства, RUB',            
           '2019, Краткосрочные обязательства, RUB',            
           '2019, Пассивы всего, RUB',          
           '2019, Совокупный долг, RUB',             
           '2019, Собственный капитал, RUB',            
           '2019, Выручка, RUB',             
           '2019, Коммерческие расходы, RUB',            
           '2019, Управленческие расходы, RUB',            
           '2019, Прибыль (убыток) от продажи, RUB',             
           '2019, Проценты к уплате, RUB',            
           '2019, Прочие расходы, RUB',            
           '2019, Чистая прибыль (убыток), RUB',           
           '2019, Получение кредитов и займов, RUB',             
           '2019, Погашение векселей, возврат кредитов и займов, RUB',            
           'Лизинг'
          ]].copy()

# %%
pd.isnull(lg).sum() #анализируем количество пропусков после частичного заполнения данных нулевыми значениями
# Out:
# ID                                                              0
# Дата регистрации                                               17
# Код статистики                                                 57
# Отрасль                                                         0
# Форма собственности                                            41
#                                                             ...
# 2019, Прочие расходы, RUB                                    6849
# 2019, Чистая прибыль (убыток), RUB                           6196
# 2019, Получение кредитов и займов, RUB                      11868
# 2019, Погашение векселей, возврат кредитов и займов, RUB    11925
# Лизинг                                                          0
# Length: 72, dtype: int64

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
lg[['2018, Налоги, RUB',
    '2018, Основные средства , RUB',
    '2018, Налог на имущество, RUB',
    '2018, Транспортный налог, RUB',         
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]] = lg[[
    '2018, Налоги, RUB',
    '2018, Основные средства , RUB',
    '2018, Налог на имущество, RUB',
    '2018, Транспортный налог, RUB',         
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
lg = lg.dropna() #удаляем пропущенные значения

# %%
lg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3216 entries, 0 to 12217
# Data columns (total 72 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   ID                                                             3216 non-null   int64
#  1   Дата регистрации                                               3216 non-null   datetime64[ns]
#  2   Код статистики                                                 3216 non-null   float64
#  3   Отрасль                                                        3216 non-null   object
#  4   Форма собственности                                            3216 non-null   object
#  5   Налоговый режим                                                3216 non-null   object
#  6   Код причины постановки на учет                                 3216 non-null   float64
#  7   2018, Налоги, RUB                                              3216 non-null   float64
#  8   2018, Налог на имущество, RUB                                  3216 non-null   float64
#  9   2018, Транспортный налог, RUB                                  3216 non-null   float64
#  10  2018, Активы  всего, RUB                                       3216 non-null   float64
#  11  2018, Выручка, RUB                                             3216 non-null   float64
#  12  2018, Основные средства , RUB                                  3216 non-null   float64
#  13  2019, Основные средства , RUB                                  3216 non-null   float64
#  14  2019, Долгосрочные финансовые вложения, RUB                    3216 non-null   float64
#  15  2019, Отложенные налоговые активы, RUB                         3216 non-null   float64
#  16  2019, Внеоборотные активы, RUB                                 3216 non-null   float64
#  17  2019, Чистые активы, RUB                                       3216 non-null   float64
#  18  2019, Запасы, RUB                                              3216 non-null   float64
#  19  2019, НДС по приобретенным ценностям , RUB                     3216 non-null   float64
#  20  2019, Дебиторская задолженность, RUB                           3216 non-null   float64
#  21  2019, Краткосрочные финансовые вложения, RUB                   3216 non-null   float64
#  22  2019, Денежные средства и денежные эквиваленты, RUB            3216 non-null   float64
#  23  2019, Прочие оборотные активы, RUB                             3216 non-null   float64
#  24  2019, Оборотные активы, RUB                                    3216 non-null   float64
#  25  2019, Активы  всего, RUB                                       3216 non-null   float64
#  26  2019, Уставный капитал , RUB                                   3216 non-null   float64
#  27  2019, Добавочный капитал, RUB                                  3216 non-null   float64
#  28  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3216 non-null   float64
#  29  2019, Капитал и резервы, RUB                                   3216 non-null   float64
#  30  2019, Собственный оборотный капитал, RUB                       3216 non-null   float64
#  31  2019, Себестоимость продаж, RUB                                3216 non-null   float64
#  32  2019, Валовая прибыль (убыток), RUB                            3216 non-null   float64
#  33  2019, Проценты к получению, RUB                                3216 non-null   float64
#  34  2019, Прочие доходы, RUB                                       3216 non-null   float64
#  35  2019, Прибыль (убыток) до налогообложения , RUB                3216 non-null   float64
#  36  2019, Текущий налог на прибыль, RUB                            3216 non-null   float64
#  37  2019, EBIT, RUB                                                3216 non-null   float64
#  38  2019, Поступления от текущих операций, RUB                     3216 non-null   float64
#  39  2019, Поступления от продаж, RUB                               3216 non-null   float64
#  40  2019, Платежи по текущим операциям, RUB                        3216 non-null   float64
#  41  2019, Платежи поставщикам и подрядчикам, RUB                   3216 non-null   float64
#  42  2019, Оплата процентов по долговым обязательствам, RUB         3216 non-null   float64
#  43  2019, Налог на прибыль, RUB                                    3216 non-null   float64
#  44  2019, Сальдо денежных потоков от текущих операций, RUB         3216 non-null   float64
#  45  2019, Платежи по инвестиционным операциям, RUB                 3216 non-null   float64
#  46  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3216 non-null   float64
#  47  2019, Поступления от финансовых операций, RUB                  3216 non-null   float64
#  48  2019, Платежи по финансовым операциям, RUB                     3216 non-null   float64
#  49  2019, Сальдо денежных потоков от финансовых операций, RUB      3216 non-null   float64
#  50  2019, Сальдо денежных потоков за отчетный период, RUB          3216 non-null   float64
#  51  2019, Поступление денежных средств всего, RUB                  3216 non-null   float64
#  52  2019, Заёмные средства (долгосрочные), RUB                     3216 non-null   float64
#  53  2019, Прочие долгосрочные обязательства, RUB                   3216 non-null   float64
#  54  2019, Долгосрочные обязательства, RUB                          3216 non-null   float64
#  55  2019, Заёмные средства (краткосрочные), RUB                    3216 non-null   float64
#  56  2019, Кредиторская задолженность, RUB                          3216 non-null   float64
#  57  2019, Прочие краткосрочные обязательства, RUB                  3216 non-null   float64
#  58  2019, Краткосрочные обязательства, RUB                         3216 non-null   float64
#  59  2019, Пассивы всего, RUB                                       3216 non-null   float64
#  60  2019, Совокупный долг, RUB                                     3216 non-null   float64
#  61  2019, Собственный капитал, RUB                                 3216 non-null   float64
#  62  2019, Выручка, RUB                                             3216 non-null   float64
#  63  2019, Коммерческие расходы, RUB                                3216 non-null   float64
#  64  2019, Управленческие расходы, RUB                              3216 non-null   float64
#  65  2019, Прибыль (убыток) от продажи, RUB                         3216 non-null   float64
#  66  2019, Проценты к уплате, RUB                                   3216 non-null   float64
#  67  2019, Прочие расходы, RUB                                      3216 non-null   float64
#  68  2019, Чистая прибыль (убыток), RUB                             3216 non-null   float64
#  69  2019, Получение кредитов и займов, RUB                         3216 non-null   float64
#  70  2019, Погашение векселей, возврат кредитов и займов, RUB       3216 non-null   float64
#  71  Лизинг                                                         3216 non-null   float64
# dtypes: datetime64[ns](1), float64(67), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# #  Задача 1

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 1

# %% [markdown]
# Задача поиска потенциальных клиентов для банка с целью продажи услуги "Зарплатный проект"(суть услуги -компания заключает с банком договор по которому заработная плата выплачивается на банковские карты данного банка). Для банка данный сервис интересен как минимум по 2 причинам: получение новых клиентов -физических лиц(держателей карт, сотрудников компаний), получение доходов от услуги(коммисионные платежи, доходы от пассивов).
# Необходимо построить модель по предсказанию объемов фонда оплаты труда(ФОТ)

# %%
zp.head()
# Out:
#          ID Дата регистрации  Код статистики       Отрасль  \
# 9    889841       1998-07-01      48748392.0  Производство
# 30  4061478       2001-05-17      56107052.0  Производство
# 31  9259386       2014-04-07      32759979.0  Производство
# 36  8699220       2013-01-17      16646709.0  Производство
# 59   937638       1998-10-23      48755966.0  Производство
#
#       Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 9   Частная собственность             УСН         73499000.0
# 30  Частная собственность             УСН         39984000.0
# 31  Частная собственность             УСН         10374000.0
# 36  Частная собственность             УСН          4919000.0
# 59  Частная собственность             УСН           813000.0
#
#     2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 9           69853000.0          1437425.0                           863696.0
# 30          47328000.0          1453480.0                           694124.0
# 31           4453000.0           705754.0                           158791.0
# 36           4192000.0           222746.0                           129314.0
# 59            841000.0           132064.0                            96849.0
#
#     ...  2018, Страховые взносы в ФСС, RUB  2018, Основные средства , RUB  \
# 9   ...                           113900.0                       945000.0
# 30  ...                            91498.0                      5071000.0
# 31  ...                            20932.0                       853000.0
# 36  ...                            16965.0                      1015000.0
# 59  ...                            12763.0                        34000.0
#
#     2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# 9                173043000.0                      23437000.0
# 30                40077000.0                      34713000.0
# 31                 7704000.0                       7490000.0
# 36                 2441000.0                        973000.0
# 59                 1331000.0                       1330000.0
#
#     2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# 9           70617000.0                          1520000.0
# 30          38949000.0                          4197000.0
# 31          10234000.0                                0.0
# 36           4917000.0                                0.0
# 59            772000.0                                0.0
#
#     2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# 9                   3378000.0                           2710000.0
# 30                  6781000.0                          -7718000.0
# 31                   268000.0                           5516000.0
# 36                   110000.0                            684000.0
# 59                    20000.0                            -36000.0
#
#     2018, Среднесписочная численность работников     2018, ФОТ
# 9                                           30.0  3.033000e+06
# 30                                          20.0  2.611000e+06
# 31                                           8.0  3.245411e+06
# 36                                           6.0  2.434058e+06
# 59                                           1.0  4.056763e+05
#
# [5 rows x 21 columns]

# %%
zp.describe()
# Out:
#                  ID  Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count  1.214000e+03    1.214000e+03       1.214000e+03        1.214000e+03
# mean   6.667380e+06    5.037605e+07       3.422790e+07        3.069468e+07
# std    3.154154e+06    2.949526e+07       6.441813e+07        5.971212e+07
# min    5.562000e+03    4.716000e+04       2.800000e+04        1.100000e+04
# 25%    4.627090e+06    2.541472e+07       4.136250e+06        3.667750e+06
# 50%    7.052184e+06    5.609773e+07       1.327550e+07        1.234800e+07
# 75%    9.019407e+06    7.612492e+07       3.984675e+07        3.572950e+07
# max    1.202043e+07    9.889218e+07       9.741350e+08        9.114010e+08
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       1.214000e+03                       1.214000e+03
# mean        1.169414e+06                       4.422581e+05
# std         2.135548e+06                       8.418562e+05
# min         8.550000e+03                       1.438000e+03
# 25%         1.786662e+05                       5.718975e+04
# 50%         4.410775e+05                       1.517465e+05
# 75%         1.168198e+06                       4.331360e+05
# max         1.965756e+07                       8.624314e+06
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        1.214000e+03                       1.214000e+03
# mean                         1.014395e+05                       5.785749e+04
# std                          2.172727e+05                       1.229597e+05
# min                          0.000000e+00                       0.000000e+00
# 25%                          1.255100e+04                       6.966250e+03
# 50%                          3.356950e+04                       1.915500e+04
# 75%                          9.421025e+04                       5.375475e+04
# max                          3.433002e+06                       1.948714e+06
#
#        2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# count                   1.214000e+03              1.214000e+03
# mean                    8.660600e+06              3.326471e+07
# std                     3.977940e+07              7.139988e+07
# min                     1.000000e+03              1.000000e+04
# 25%                     2.102500e+05              3.347500e+06
# 50%                     1.025000e+06              1.066350e+07
# 75%                     4.766500e+06              3.287750e+07
# max                     8.516010e+08              1.330080e+09
#
#        2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# count                    1.214000e+03        1.214000e+03
# mean                     1.364070e+07        3.135811e+07
# std                      3.311925e+07        5.942954e+07
# min                     -1.573660e+08        1.900000e+04
# 25%                      6.152500e+05        3.798000e+06
# 50%                      4.259500e+06        1.252850e+07
# 75%                      1.531000e+07        3.707900e+07
# max                      3.879670e+08        9.158050e+08
#
#        2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# count                       1.214000e+03               1.214000e+03
# mean                        1.257013e+06               3.308826e+06
# std                         6.528679e+06               1.114448e+07
# min                         0.000000e+00               1.000000e+03
# 25%                         0.000000e+00               7.200000e+04
# 50%                         0.000000e+00               3.070000e+05
# 75%                         0.000000e+00               1.591250e+06
# max                         7.983300e+07               1.448910e+08
#
#        2018, Чистая прибыль (убыток), RUB  \
# count                        1.214000e+03
# mean                         3.196860e+06
# std                          1.221950e+07
# min                         -8.075300e+07
# 25%                         -1.010000e+05
# 50%                          6.440000e+05
# 75%                          3.438500e+06
# max                          1.856900e+08
#
#        2018, Среднесписочная численность работников     2018, ФОТ
# count                                   1214.000000  1.214000e+03
# mean                                       9.607908  3.741328e+06
# std                                       13.709486  5.326077e+06
# min                                        1.000000  2.300000e+04
# 25%                                        2.000000  8.113527e+05
# 50%                                        4.500000  1.622705e+06
# 75%                                       11.000000  4.056763e+06
# max                                       89.000000  3.448249e+07

# %%
zp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1214 entries, 9 to 12207
# Data columns (total 21 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   ID                                            1214 non-null   int64
#  1   Дата регистрации                              1214 non-null   datetime64[ns]
#  2   Код статистики                                1214 non-null   float64
#  3   Отрасль                                       1214 non-null   object
#  4   Форма собственности                           1214 non-null   object
#  5   Налоговый режим                               1214 non-null   object
#  6   2018, Доходы, RUB                             1214 non-null   float64
#  7   2018, Расходы, RUB                            1214 non-null   float64
#  8   2018, Налоги, RUB                             1214 non-null   float64
#  9   2018, Страховые взносы в ПФР, RUB             1214 non-null   float64
#  10  2018, Страховые взносы в ФОМС, RUB            1214 non-null   float64
#  11  2018, Страховые взносы в ФСС, RUB             1214 non-null   float64
#  12  2018, Основные средства , RUB                 1214 non-null   float64
#  13  2018, Активы  всего, RUB                      1214 non-null   float64
#  14  2018, Собственный капитал, RUB                1214 non-null   float64
#  15  2018, Выручка, RUB                            1214 non-null   float64
#  16  2018, Управленческие расходы, RUB             1214 non-null   float64
#  17  2018, Прочие расходы, RUB                     1214 non-null   float64
#  18  2018, Чистая прибыль (убыток), RUB            1214 non-null   float64
#  19  2018, Среднесписочная численность работников  1214 non-null   float64
#  20  2018, ФОТ                                     1214 non-null   float64
# dtypes: datetime64[ns](1), float64(16), int64(1), object(3)
# memory usage: 208.7+ KB

# %% [markdown]
# # Задача 2

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 2

# %% [markdown]
# Задача поиска потенциальных клиентов для банка для привлечения на услуги "Зарплатный проект" и услуги по страхованию сотрудников.
# Суть услуги "Зарплатный роект"- компания заключает с банком договор по которому заработная плата выплачивается на банковские карты данного банка). Для банка данный сервис интересен как минимум по 2 причинам: получение новых клиентов -физических лиц(держателей карт, сотрудников компаний), получение доходов от услуги(коммисионные платежи, доходы от пассивов).
# Под услугами страхования в данной задаче подразумеваются услуги корплративного страхования, такие как Добровольное медицинское страхование, страхование от несчастных случаев и болезней.
# Необходимо построить модель по предсказанию среднесписочной численности работников

# %%
zp.head()
# Out:
#           ID Дата регистрации  Код статистики       Отрасль  \
# 9     889841       1998-07-01      48748392.0  Производство
# 13  11837132       2018-03-05      26713625.0  Производство
# 30   4061478       2001-05-17      56107052.0  Производство
# 31   9259386       2014-04-07      32759979.0  Производство
# 36   8699220       2013-01-17      16646709.0  Производство
#
#       Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 9   Частная собственность             УСН         73499000.0
# 13  Частная собственность             УСН           161000.0
# 30  Частная собственность             УСН         39984000.0
# 31  Частная собственность             УСН         10374000.0
# 36  Частная собственность             УСН          4919000.0
#
#     2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 9           69853000.0          1437425.0                           863696.0
# 13           2140000.0           131775.0                            96976.0
# 30          47328000.0          1453480.0                           694124.0
# 31           4453000.0           705754.0                           158791.0
# 36           4192000.0           222746.0                           129314.0
#
#     2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# 9                             200551.0                           113900.0
# 13                             22481.0                            12318.0
# 30                            160911.0                            91498.0
# 31                             35945.0                            20932.0
# 36                             29977.0                            16965.0
#
#     2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# 9                173043000.0                      23437000.0
# 13                   96000.0                      -1972000.0
# 30                40077000.0                      34713000.0
# 31                 7704000.0                       7490000.0
# 36                 2441000.0                        973000.0
#
#     2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# 9           70617000.0                          1520000.0
# 13            160000.0                                0.0
# 30          38949000.0                          4197000.0
# 31          10234000.0                                0.0
# 36           4917000.0                                0.0
#
#     2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# 9                   3378000.0                           2710000.0
# 13                    43000.0                          -1981000.0
# 30                  6781000.0                          -7718000.0
# 31                   268000.0                           5516000.0
# 36                   110000.0                            684000.0
#
#     2018, Среднесписочная численность работников     2018, ФОТ
# 9                                           30.0  3.033000e+06
# 13                                           4.0  1.622705e+06
# 30                                          20.0  2.611000e+06
# 31                                           8.0  3.245411e+06
# 36                                           6.0  2.434058e+06

# %% [markdown]
# ## Решение

# %%
#удалим ФОТ -целевая переменная в другой задаче
del zp['2018, ФОТ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/snap/Anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018, ФОТ'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-145-2035f7cb702b> in <module>
#       1 #удалим ФОТ -целевая переменная в другой задаче
# ----> 2 del zp['2018, ФОТ']
#
# ~/snap/Anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~/snap/Anaconda/lib/python3.6/site-packages/pandas/core/internals/managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/snap/Anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2018, ФОТ'

# %%
zp['Дата регистрации'] = zp['Дата регистрации'].dt.year

# %%
#выведем информацию о количестве данных
zp.shape
# Out:
# (2329, 19)

# %%
#получим иформацию о данных
zp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 9 to 12217
# Data columns (total 32 columns):
#  #   Column                                                                       Non-Null Count  Dtype
# ---  ------                                                                       --------------  -----
#  0   ID                                                                           2329 non-null   int64
#  1   Дата регистрации                                                             2329 non-null   int64
#  2   Код статистики                                                               2329 non-null   float64
#  3   2018, Доходы, RUB                                                            2329 non-null   float64
#  4   2018, Расходы, RUB                                                           2329 non-null   float64
#  5   2018, Налоги, RUB                                                            2329 non-null   float64
#  6   2018, Страховые взносы в ПФР, RUB                                            2329 non-null   float64
#  7   2018, Страховые взносы в ФОМС, RUB                                           2329 non-null   float64
#  8   2018, Страховые взносы в ФСС, RUB                                            2329 non-null   float64
#  9   2018, Активы  всего, RUB                                                     2329 non-null   float64
#  10  2018, Собственный капитал, RUB                                               2329 non-null   float64
#  11  2018, Выручка, RUB                                                           2329 non-null   float64
#  12  2018, Управленческие расходы, RUB                                            2329 non-null   float64
#  13  2018, Прочие расходы, RUB                                                    2329 non-null   float64
#  14  2018, Чистая прибыль (убыток), RUB                                           2329 non-null   float64
#  15  2018, Среднесписочная численность работников                                 2329 non-null   float64
#  16  Отрасль_Производство                                                         2329 non-null   uint8
#  17  Отрасль_Строительство                                                        2329 non-null   uint8
#  18  Отрасль_Торговля                                                             2329 non-null   uint8
#  19  Отрасль_Транспорт                                                            2329 non-null   uint8
#  20  Отрасль_Услуги                                                               2329 non-null   uint8
#  21  Форма собственности_Иная смешанная российская собственность                  2329 non-null   uint8
#  22  Форма собственности_Муниципальная собственность                              2329 non-null   uint8
#  23  Форма собственности_Смешанная иностранная собственность                      2329 non-null   uint8
#  24  Форма собственности_Собственность иностранных граждан и лиц без гражданства  2329 non-null   uint8
#  25  Форма собственности_Собственность общественных объединений                   2329 non-null   uint8
#  26  Форма собственности_Совместная частная и иностранная собственность           2329 non-null   uint8
#  27  Форма собственности_Федеральная собственность                                2329 non-null   uint8
#  28  Форма собственности_Частная собственность                                    2329 non-null   uint8
#  29  Налоговый режим_ЕНВД                                                         2329 non-null   uint8
#  30  Налоговый режим_УСН                                                          2329 non-null   uint8
#  31  Налоговый режим_УСН, ЕНВД                                                    2329 non-null   uint8
# dtypes: float64(14), int64(2), uint8(16)
# memory usage: 345.7 KB

# %%
#выведем информацию о количестве столбцов в разрезе типов данных
zp.dtypes.value_counts()
# Out:
# uint8             16
# float64           14
# int64              1
# datetime64[ns]     1
# dtype: int64

# %%
zp.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Отрасль                5
# Форма собственности    8
# Налоговый режим        3
# dtype: int64

# %%
# one-hot encoding категориальных признаков
zp = pd.get_dummies(zp)


print('Размер данных: ', zp.shape)
# Out:
# Размер данных:  (2329, 32)

# %%
zp.hist(figsize=(20, 30), layout=(11,3), bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fd174e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48f731b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fbee0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fc80668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fcb5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fc32208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48fc5d7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dee7da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dee7dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48de56908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48de09eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48ddc64a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48ddf9a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48ddb7048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dd685f8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dd18ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dcd4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dc86748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dcb6cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dc752e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dc25898>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dbd8e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48db96438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48db449e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48db79f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48db37588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48dae7b38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48daa4128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48da546d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48da07c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa48d9c3278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48d9f5828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa48d9a9dd8>]],
#       dtype=object)

# %%
#построим матрицу корреляции
plt.subplots(figsize=(10,10))
sns.heatmap(zp.corr(), square=True)
plt.show()

# %%
#отобразим зависимость численности сотрудников от взносов в ФОМС
zp.plot(x='2018, Страховые взносы в ФОМС, RUB', y='2018, Среднесписочная численность работников', style='o')  
plt.title('Взносы в ФОМС vs Численность')  
plt.xlabel('Взносы в ФОМС')  
plt.ylabel('Численность')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
sns.distplot(zp["2018, Среднесписочная численность работников"])

# %%
X = zp.copy().drop(["2018, Среднесписочная численность работников"], axis=1)

# %%
y = zp["2018, Среднесписочная численность работников"]

# %%
X = np.array(X)

# %%
from sklearn import preprocessing
# нормализуем данные
X_scaled = preprocessing.normalize(X)
print(X_scaled)
# Out:
# [[4.05468781e-03 9.10417282e-06 2.22129022e-01 ... 0.00000000e+00
#   4.55664305e-09 0.00000000e+00]
#  [4.02191451e-01 6.85657934e-05 9.07651582e-01 ... 0.00000000e+00
#   3.39771028e-08 0.00000000e+00]
#  [3.79442642e-02 1.86942962e-05 5.24178834e-01 ... 0.00000000e+00
#   9.34247685e-09 0.00000000e+00]
#  ...
#  [7.00983443e-02 2.19775111e-05 9.21848970e-01 ... 0.00000000e+00
#   1.09449757e-08 0.00000000e+00]
#  [5.40236863e-01 1.27307863e-04 6.81347758e-01 ... 0.00000000e+00
#   6.32742856e-08 0.00000000e+00]
#  [5.61895178e-02 2.12783675e-05 9.97335956e-01 ... 0.00000000e+00
#   1.06073617e-08 0.00000000e+00]]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.15, random_state=42)

# %%
import sklearn.linear_model as lm

# %%
# создаем пустую модель
skm = lm.LinearRegression()
# запускаем расчет параметров для указанных данных
skm.fit(X_train, y_train)
# Out:
# 249.4114463175303 [ 1.20677193e-07 -1.24750155e-01 -7.02038830e-09 -9.27534369e-08
#   2.50722180e-08  5.75002883e-08  1.30735638e-05 -4.97137232e-05
#   8.32100137e-05  4.13924463e-10  1.59117142e-08  8.32310382e-08
#   8.24692940e-08  4.86953758e-08  1.98149165e-08  8.15758363e-01
#  -6.12635710e-01 -4.45297696e-01  4.74798725e-01 -2.32623683e-01
#  -1.63571363e+00 -7.70800153e+00  2.47326289e+00  3.35751920e+00
#  -1.79159913e-01  1.72706665e+00 -1.12160324e+00  3.08662959e+00
#  -1.01255943e+00 -4.53404555e-01  1.46596399e+00]

# %% [markdown]
# # Задача 3

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3774 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о  финансовых показателях компани за 2019 год.

# %%
#to do: добавить ссылки с описанием фин показателей

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Задача поиска потенциалных клиентов банка для привлечение на услуги кредитование и имущественное страхование.
# Необходимо построить модель по предсказанию наличия действующего договора залога.
# Логика задачи: если компания предоставляла что-то в залог по кредитованию, то можно сделать вывод что в компании есть практика использования заёмных средств и они пользуются кредитами(потенциал по сотрудничеству в будущем либо по рефинансированию кредита). Данные клиенты интересны банку для кредитования поскольку у них имеется имущество, которое они предоставляют в залог (т. е. это потенциальные клиенты, которые готовы минимизировать риски банка, предоставив залог по кредиту).
# Дополнительно результаты этой модели могут быть использованы для привлечения новых корпоративных клиентов на сервисы страхования имущества(компания преоставляет залог, в 90% случаев этот залог необходимо страховать)

# %%
cred.head(3)
# Out:
#           ID Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 5   10527024       2016-04-07       1811746.0  Производство
# 13  11837132       2018-03-05      26713625.0  Производство
#
#       Форма собственности Налоговый режим  Код причины постановки на учет  \
# 0   Частная собственность             УСН                     390601001.0
# 5   Частная собственность             УСН                     390601001.0
# 13  Частная собственность             УСН                     390601001.0
#
#     2019, Основные средства , RUB  \
# 0                        651000.0
# 5                         36000.0
# 13                            0.0
#
#     2019, Долгосрочные финансовые вложения, RUB  \
# 0                                           0.0
# 5                                           0.0
# 13                                          0.0
#
#     2019, Отложенные налоговые активы, RUB  ...  2019, Выручка, RUB  \
# 0                                      0.0  ...            909000.0
# 5                                      0.0  ...            366000.0
# 13                                     0.0  ...           7348000.0
#
#     2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# 0                               0.0                            47000.0
# 5                               0.0                                0.0
# 13                              0.0                                0.0
#
#     2019, Прибыль (убыток) от продажи, RUB  2019, Проценты к уплате, RUB  \
# 0                                -320000.0                           0.0
# 5                                -854000.0                           0.0
# 13                               1006000.0                           0.0
#
#     2019, Прочие расходы, RUB  2019, Чистая прибыль (убыток), RUB  \
# 0                     47000.0                           -365000.0
# 5                     20000.0                           -874000.0
# 13                    27000.0                            922000.0
#
#     2019, Получение кредитов и займов, RUB  \
# 0                                      0.0
# 5                                      0.0
# 13                                     0.0
#
#     2019, Погашение векселей, возврат кредитов и займов, RUB  Залоги
# 0                                                 0.0            0.0
# 5                                                 0.0            0.0
# 13                                                0.0            0.0
#
# [3 rows x 66 columns]

# %%
#проверяем насколько сбалансированны данные
print(cred["Залоги"].value_counts())
sns.barplot(cred["Залоги"].value_counts().index, cred["Залоги"].value_counts().values)
# Out:
# 0.0    3585
# 1.0     189
# Name: Залоги, dtype: int64

# %% [markdown]
# # Задача 4

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3774 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о финансовых показателях компани за 2019 год.

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Задача поиска потенциальных клиентов банка для реализации услуг по продаже банковских гарантий.
#
# Суть услуги "Банковская гарантия" - банк проводит проверку своего клиента (ЮЛ либо ИП) и предоставляет за него "поручительство" перед его контрагентом. Существует много видов гарантий, наиболее распространены гарантии исполнения обязательств по договору по которым банк гарантирует что его клиент выполнит свои обязательства по контракту, в случае неисполнения клиентом банка своих обязательств по договору банк оплачивает контрагенту своего клиента сумму указанную в банковской гарантии(происходит раскрытие гарантии).
# В случае раскрытия гарантии у клиента банка возникает обязательство по возврату средств в адрес банка(т. е. при раскрытии гарантии для компании банковскаягарантия превращается в кредит).
#
# Как правила по банковским гарантиям предусмотрено 2 вида плат - плата за выдачу гарантии и процент, который клиент уплачивает при раскрытии гарантии.
# Для банка банковские гарантии интересны как источник некредитных комиссий.
#
# Компании, которые используют банковские гарантии как правило нуждаются в них постоянно, поэтому признак наличия банковских гарантий говорит о высокой вероятности в потребности в гарантиях в будующем.
#
# Построить модель классификации клиентов по признаку "БГ" (определить компании, которые пользуются гарантиями).

# %%
bg.head(3)
# Out:
#           ID Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 5   10527024       2016-04-07       1811746.0  Производство
# 13  11837132       2018-03-05      26713625.0  Производство
#
#       Форма собственности Налоговый режим  Код причины постановки на учет  \
# 0   Частная собственность             УСН                     390601001.0
# 5   Частная собственность             УСН                     390601001.0
# 13  Частная собственность             УСН                     390601001.0
#
#     2019, Основные средства , RUB  \
# 0                        651000.0
# 5                         36000.0
# 13                            0.0
#
#     2019, Долгосрочные финансовые вложения, RUB  \
# 0                                           0.0
# 5                                           0.0
# 13                                          0.0
#
#     2019, Отложенные налоговые активы, RUB  ...  2019, Выручка, RUB  \
# 0                                      0.0  ...            909000.0
# 5                                      0.0  ...            366000.0
# 13                                     0.0  ...           7348000.0
#
#     2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# 0                               0.0                            47000.0
# 5                               0.0                                0.0
# 13                              0.0                                0.0
#
#     2019, Прибыль (убыток) от продажи, RUB  2019, Проценты к уплате, RUB  \
# 0                                -320000.0                           0.0
# 5                                -854000.0                           0.0
# 13                               1006000.0                           0.0
#
#     2019, Прочие расходы, RUB  2019, Чистая прибыль (убыток), RUB  \
# 0                     47000.0                           -365000.0
# 5                     20000.0                           -874000.0
# 13                    27000.0                            922000.0
#
#     2019, Получение кредитов и займов, RUB  \
# 0                                      0.0
# 5                                      0.0
# 13                                     0.0
#
#     2019, Погашение векселей, возврат кредитов и займов, RUB   БГ
# 0                                                 0.0         0.0
# 5                                                 0.0         0.0
# 13                                                0.0         0.0
#
# [3 rows x 66 columns]

# %%
#проверяем насколько сбалансированны данные
print(bg["БГ"].value_counts())
sns.barplot(bg["БГ"].value_counts().index, bg["БГ"].value_counts().values)
# Out:
# 0.0    3595
# 1.0     179
# Name: БГ, dtype: int64

# %% [markdown]
# # Задача 5

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3216 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о финансовых показателях компани за 2019 год и фин показателях за 2018 год.

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Поиск потенциальных клиентов банка для заключения договоров лизинга.
# Построить модель классификации на клиентов использующих лизинг и на компании не пользующиеся лизингом.

# %%
lg.head(3)
# Out:
#           ID Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 5   10527024       2016-04-07       1811746.0  Производство
# 13  11837132       2018-03-05      26713625.0  Производство
#
#       Форма собственности Налоговый режим  Код причины постановки на учет  \
# 0   Частная собственность             УСН                     390601001.0
# 5   Частная собственность             УСН                     390601001.0
# 13  Частная собственность             УСН                     390601001.0
#
#     2018, Налоги, RUB  2018, Налог на имущество, RUB  \
# 0             16597.0                            0.0
# 5              5667.0                            0.0
# 13           131775.0                            0.0
#
#     2018, Транспортный налог, RUB  ...  2019, Выручка, RUB  \
# 0                             0.0  ...            909000.0
# 5                             0.0  ...            366000.0
# 13                            0.0  ...           7348000.0
#
#     2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# 0                               0.0                            47000.0
# 5                               0.0                                0.0
# 13                              0.0                                0.0
#
#     2019, Прибыль (убыток) от продажи, RUB  2019, Проценты к уплате, RUB  \
# 0                                -320000.0                           0.0
# 5                                -854000.0                           0.0
# 13                               1006000.0                           0.0
#
#     2019, Прочие расходы, RUB  2019, Чистая прибыль (убыток), RUB  \
# 0                     47000.0                           -365000.0
# 5                     20000.0                           -874000.0
# 13                    27000.0                            922000.0
#
#     2019, Получение кредитов и займов, RUB  \
# 0                                      0.0
# 5                                      0.0
# 13                                     0.0
#
#     2019, Погашение векселей, возврат кредитов и займов, RUB  Лизинг
# 0                                                 0.0            0.0
# 5                                                 0.0            0.0
# 13                                                0.0            0.0
#
# [3 rows x 72 columns]

# %%
#проверяем насколько сбалансированны данные
print(lg["Лизинг"].value_counts())
sns.barplot(lg["Лизинг"].value_counts().index, lg["Лизинг"].value_counts().values)
# Out:
# 0.0    3035
# 1.0     181
# Name: Лизинг, dtype: int64
