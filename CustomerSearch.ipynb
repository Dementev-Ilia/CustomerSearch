# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %% [markdown]
# # Загрузка данных

# %%
company = pd.read_excel('./data(xls)/Компании.xlsx')#загружаю основной набор данных

# %%
company.head()
# Out:
#          ID       Наименование Дата регистрации  Код статистики       Отрасль  \
# 0   4283790           033, ООО       2003-10-14      71115178.0  Производство
# 1  12390280        1 БЭЙК, ООО       2019-10-28      42006784.0  Производство
# 2   9603036  1-Я ЛИФТОВАЯ, ООО       2014-11-11      35394691.0  Производство
# 3   5298659    12 СТУЛЬЕВ, ООО       2006-03-29      94037570.0  Производство
# 4   7128967      2020-ЛБК, ООО       2009-07-28      60596246.0  Производство
#
#      Форма собственности  Код причины постановки на учет  \
# 0  Частная собственность                     390601001.0
# 1  Частная собственность                     391401001.0
# 2  Частная собственность                     390601001.0
# 3  Частная собственность                     390601001.0
# 4  Частная собственность                     390601001.0
#
#          Органы власти и государственного управления   Размер компании  \
# 0  Организации, учрежденные юридическими лицами и...  Микропредприятия
# 1  Организации, учрежденные юридическими лицами и...               NaN
# 2  Организации, учрежденные юридическими лицами и...               NaN
# 3  Организации, учрежденные юридическими лицами и...               NaN
# 4  Организации, учрежденные юридическими лицами и...               NaN
#
#    2018, Среднесписочная численность работников  ...  \
# 0                                           1.0  ...
# 1                                           NaN  ...
# 2                                           1.0  ...
# 3                                           1.0  ...
# 4                                           1.0  ...
#
#   2019, Сальдо денежных потоков за отчетный период, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Поступление денежных средств всего, RUB  2019, Платежей всего, RUB  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
#
#    2019, Прибыль от приносящей доход деятельности, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Всего поступило средств, RUB  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    2019, Расходы на целевые мероприятия, RUB  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    2019, Расходы на содержание аппарата управления, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    2019, Всего использовано средств, RUB  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    2019, Остаток средств на конец отчетного года, RUB
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 145 columns]

# %%
bank_guarantees = pd.read_excel('./data(xls)/Банковские гарантии.xlsx') #данные о наличии банковских гарантий

# %%
leasing = pd.read_excel('./data(xls)/Лизинг.xlsx') #данные о наличии действующих договоров лизинга

# %%
security_loan = pd.read_excel('./data(xls)/Залоги.xlsx') #данные о зарегестированных залогах(признак того что компания является залогодателем по кредиту)

# %%
staff = pd.read_excel('./data(xls)/Численность.xlsx') #данные о численности сотрудников

# %% [markdown]
# ## Подготовка данных

# %%
data = pd.merge(company, bank_guarantees, how='left') #объединяю исследуемые данные с данными о гарантиях

# %%
data = pd.merge(data, leasing, how='left') #объединяю исследуемые данные с данными  о лизинге

# %%
data = pd.merge(data, security_loan, how='left') #объединяю исследуемые данные с данными  о кредитвании

# %%
data = pd.merge(data, security_loan, how='left') #объединяю исследуемые данные с данными  о кредитвании

# %%
data = pd.merge(data, staff, how='left') #объединяю исследуемые данные с данными  о численности сотрудников

# %%
data = data.set_index(['ID'])

# %%
#сводные данные теперь храняться в "data"
data.head(3)
# Out:
#                Наименование Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790            033, ООО       2003-10-14      71115178.0  Производство
# 12390280        1 БЭЙК, ООО       2019-10-28      42006784.0  Производство
# 9603036   1-Я ЛИФТОВАЯ, ООО       2014-11-11      35394691.0  Производство
#
#             Форма собственности  Код причины постановки на учет  \
# ID
# 4283790   Частная собственность                     390601001.0
# 12390280  Частная собственность                     391401001.0
# 9603036   Частная собственность                     390601001.0
#
#                 Органы власти и государственного управления   Размер компании  \
# ID
# 4283790   Организации, учрежденные юридическими лицами и...  Микропредприятия
# 12390280  Организации, учрежденные юридическими лицами и...               NaN
# 9603036   Организации, учрежденные юридическими лицами и...               NaN
#
#           2018, Среднесписочная численность работников Налоговый режим  ...  \
# ID                                                                      ...
# 4283790                                            1.0             УСН  ...
# 12390280                                           NaN             NaN  ...
# 9603036                                            1.0             УСН  ...
#
#           2019, Всего поступило средств, RUB  \
# ID
# 4283790                                  NaN
# 12390280                                 NaN
# 9603036                                  NaN
#
#           2019, Расходы на целевые мероприятия, RUB  \
# ID
# 4283790                                         NaN
# 12390280                                        NaN
# 9603036                                         NaN
#
#           2019, Расходы на содержание аппарата управления, RUB  \
# ID
# 4283790                                                 NaN
# 12390280                                                NaN
# 9603036                                                 NaN
#
#           2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# ID
# 4283790                                                 NaN
# 12390280                                                NaN
# 9603036                                                 NaN
#
#           2019, Всего использовано средств, RUB  \
# ID
# 4283790                                     NaN
# 12390280                                    NaN
# 9603036                                     NaN
#
#           2019, Остаток средств на конец отчетного года, RUB  БГ  Лизинг  \
# ID
# 4283790                                                 NaN  NaN     NaN
# 12390280                                                NaN  NaN     NaN
# 9603036                                                 NaN  NaN     NaN
#
#           Залоги  численность
# ID
# 4283790      NaN          NaN
# 12390280     NaN          NaN
# 9603036      NaN          NaN
#
# [3 rows x 148 columns]

# %%
data.describe()
# Out:
#        Код статистики  Код причины постановки на учет  \
# count    1.217000e+04                    1.214500e+04
# mean     4.774692e+07                    3.909655e+08
# std      2.764807e+07                    5.449271e+06
# min      4.716000e+04                    3.901010e+08
# 25%      2.777519e+07                    3.906010e+08
# 50%      4.236241e+07                    3.906010e+08
# 75%      7.112371e+07                    3.912010e+08
# max      9.971510e+07                    7.708010e+08
#
#        2018, Среднесписочная численность работников  2017, Доходы, RUB  \
# count                                   7860.000000       6.529000e+03
# mean                                       8.708397       3.696273e+07
# std                                       57.392902       2.542989e+08
# min                                        1.000000       0.000000e+00
# 25%                                        1.000000       7.540000e+05
# 50%                                        1.000000       4.821000e+06
# 75%                                        5.000000       2.046200e+07
# max                                     4079.000000       1.062454e+10
#
#        2018, Доходы, RUB  2017, Расходы, RUB  2018, Расходы, RUB  \
# count       6.723000e+03        6.529000e+03        6.723000e+03
# mean        6.765525e+07        3.527823e+07        6.378047e+07
# std         7.662991e+08        2.496199e+08        7.547269e+08
# min        -1.194900e+07        0.000000e+00        0.000000e+00
# 25%         7.355000e+05        7.900000e+05        7.990000e+05
# 50%         5.002000e+06        4.444000e+06        4.695000e+06
# 75%         2.242800e+07        1.891800e+07        2.078800e+07
# max         5.336259e+10        1.061781e+10        5.322594e+10
#
#        2017, Налоги, RUB  2018, Налоги, RUB  2017, Налог на имущество, RUB  \
# count       6.556000e+03       6.916000e+03                   4.750000e+02
# mean        1.362677e+06       5.102139e+06                   3.164902e+05
# std         8.100416e+06       1.360288e+08                   1.526846e+06
# min         0.000000e+00       1.000000e+00                   0.000000e+00
# 25%         5.039400e+04       4.995900e+04                   7.277000e+03
# 50%         1.799070e+05       1.923335e+05                   4.623700e+04
# 75%         6.349650e+05       7.323502e+05                   1.999995e+05
# max         3.210900e+08       1.070500e+10                   3.014846e+07
#
#        ...  2019, Всего поступило средств, RUB  \
# count  ...                        2.800000e+02
# mean   ...                        1.414192e+07
# std    ...                        5.971516e+07
# min    ...                       -2.041000e+06
# 25%    ...                        2.520000e+05
# 50%    ...                        1.130500e+06
# 75%    ...                        4.454750e+06
# max    ...                        6.939350e+08
#
#        2019, Расходы на целевые мероприятия, RUB  \
# count                               1.470000e+02
# mean                                8.093327e+06
# std                                 3.111108e+07
# min                                -6.000000e+03
# 25%                                 1.070000e+05
# 50%                                 4.260000e+05
# 75%                                 2.038000e+06
# max                                 2.043270e+08
#
#        2019, Расходы на содержание аппарата управления, RUB  \
# count                                       2.060000e+02
# mean                                        4.002796e+06
# std                                         2.250313e+07
# min                                        -1.163000e+06
# 25%                                         1.407500e+05
# 50%                                         6.005000e+05
# 75%                                         2.050750e+06
# max                                         3.110270e+08
#
#        2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# count                                       5.100000e+01
# mean                                        6.244314e+05
# std                                         1.190632e+06
# min                                         1.000000e+03
# 25%                                         4.150000e+04
# 50%                                         1.610000e+05
# 75%                                         5.385000e+05
# max                                         6.589000e+06
#
#        2019, Всего использовано средств, RUB  \
# count                           2.840000e+02
# mean                            1.374354e+07
# std                             5.908279e+07
# min                            -4.382000e+06
# 25%                             2.125000e+05
# 50%                             9.745000e+05
# 75%                             4.080250e+06
# max                             7.052140e+08
#
#        2019, Остаток средств на конец отчетного года, RUB     БГ  Лизинг  \
# count                                       2.240000e+02   336.0   502.0
# mean                                        2.559946e+06     1.0     1.0
# std                                         4.291811e+07     0.0     0.0
# min                                        -4.208010e+08     1.0     1.0
# 25%                                         1.000000e+04     1.0     1.0
# 50%                                         9.250000e+04     1.0     1.0
# 75%                                         6.530000e+05     1.0     1.0
# max                                         4.644630e+08     1.0     1.0
#
#        Залоги  численность
# count   383.0   146.000000
# mean      1.0    47.431507
# std       0.0   120.178770
# min       1.0     1.000000
# 25%       1.0     1.000000
# 50%       1.0     7.000000
# 75%       1.0    36.250000
# max       1.0   920.000000
#
# [8 rows x 141 columns]

# %%
pd.isnull(data).sum()
#после объединения данных получил большое количество пропусков в столбцах, которые планирую использовать как данные для предсказания
# Out:
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
# Форма собственности                                      41
#                                                       ...
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                    11891
# Лизинг                                                11725
# Залоги                                                11844
# численность                                           12081
# Length: 148, dtype: int64

# %%
data[['БГ', 'Лизинг', 'Залоги']] = data[['БГ', 'Лизинг', 'Залоги']].fillna(value=0) #обрабатываем пропуски в столбцах,которые будут испоьзоваться при формировании целевых переменных

# %%
pd.isnull(data).sum()
# Out:
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
# Форма собственности                                      41
#                                                       ...
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                        0
# Лизинг                                                    0
# Залоги                                                    0
# численность                                           12081
# Length: 148, dtype: int64

# %%
 #анализирум данные в целевых переменных
    print(data["Лизинг"].value_counts())
    print(data["БГ"].value_counts())
    print(data["Залоги"].value_counts())
# Out:
# 0.0    11725
# 1.0      502
# Name: Лизинг, dtype: int64
# 0.0    11891
# 1.0      336
# Name: БГ, dtype: int64
# 0.0    11844
# 1.0      383
# Name: Залоги, dtype: int64

# %% [markdown]
# ## Подготовка данных для задачи по предсказанию фонда оплаты труда и количества сотрудников:

# %%
#Для удобства работы решил разбить данные на отдельные части для каждой задачи
zp = data[['Дата регистрации',
           'Код статистики',
           'Отрасль',
           'Форма собственности',
           'Налоговый режим',
           '2018, Доходы, RUB',
           '2018, Расходы, RUB',
           '2018, Налоги, RUB',
           '2018, Страховые взносы в ПФР, RUB',
           '2018, Страховые взносы в ФОМС, RUB',
           '2018, Страховые взносы в ФСС, RUB',
           '2018, Основные средства , RUB',
           '2018, Активы  всего, RUB',
           '2018, Собственный капитал, RUB',
           '2018, Выручка, RUB',
           '2018, Управленческие расходы, RUB',
           '2018, Прочие расходы, RUB',
           '2018, Чистая прибыль (убыток), RUB',
           '2018, Оплата труда, RUB',
           '2018, Среднесписочная численность работников'
          ]].copy()

# %%
zp.head(3)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 12390280       2019-10-28      42006784.0  Производство
# 9603036        2014-11-11      35394691.0  Производство
#
#             Форма собственности Налоговый режим  2018, Доходы, RUB  \
# ID
# 4283790   Частная собственность             УСН          1211000.0
# 12390280  Частная собственность             NaN                NaN
# 9603036   Частная собственность             УСН                NaN
#
#           2018, Расходы, RUB  2018, Налоги, RUB  \
# ID
# 4283790            1167000.0            16597.0
# 12390280                 NaN                NaN
# 9603036                  NaN                NaN
#
#           2018, Страховые взносы в ПФР, RUB  \
# ID
# 4283790                                 NaN
# 12390280                                NaN
# 9603036                                 NaN
#
#           2018, Страховые взносы в ФОМС, RUB  \
# ID
# 4283790                                  NaN
# 12390280                                 NaN
# 9603036                                  NaN
#
#           2018, Страховые взносы в ФСС, RUB  2018, Основные средства , RUB  \
# ID
# 4283790                                 NaN                       620000.0
# 12390280                                NaN                            NaN
# 9603036                                 NaN                            NaN
#
#           2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# ID
# 4283790                   725000.0                        600000.0
# 12390280                       NaN                             NaN
# 9603036                        NaN                             NaN
#
#           2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# ID
# 4283790            1211000.0                          1167000.0
# 12390280                 NaN                                NaN
# 9603036                  NaN                                NaN
#
#           2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                         NaN                             29000.0
# 12390280                        NaN                                 NaN
# 9603036                         NaN                                 NaN
#
#           2018, Оплата труда, RUB  \
# ID
# 4283790                       NaN
# 12390280                      NaN
# 9603036                       NaN
#
#           2018, Среднесписочная численность работников
# ID
# 4283790                                            1.0
# 12390280                                           NaN
# 9603036                                            1.0

# %%
zp.describe()
# Out:
#        Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count    1.217000e+04       6.723000e+03        6.723000e+03
# mean     4.774692e+07       6.765525e+07        6.378047e+07
# std      2.764807e+07       7.662991e+08        7.547269e+08
# min      4.716000e+04      -1.194900e+07        0.000000e+00
# 25%      2.777519e+07       7.355000e+05        7.990000e+05
# 50%      4.236241e+07       5.002000e+06        4.695000e+06
# 75%      7.112371e+07       2.242800e+07        2.078800e+07
# max      9.971510e+07       5.336259e+10        5.322594e+10
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       6.916000e+03                       5.499000e+03
# mean        5.102139e+06                       7.388361e+05
# std         1.360288e+08                       3.978190e+06
# min         1.000000e+00                       0.000000e+00
# 25%         4.995900e+04                       2.965100e+04
# 50%         1.923335e+05                       8.936400e+04
# 75%         7.323502e+05                       2.944060e+05
# max         1.070500e+10                       1.115868e+08
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        4.744000e+03                       4.736000e+03
# mean                         1.751858e+05                       9.021046e+04
# std                          9.998552e+05                       4.713477e+05
# min                          0.000000e+00                       0.000000e+00
# 25%                          6.167000e+03                       3.480000e+03
# 50%                          1.744550e+04                       9.973500e+03
# 75%                          5.636650e+04                       3.213825e+04
# max                          2.868460e+07                       1.089792e+07
#
#        2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# count                   3.200000e+03              7.846000e+03
# mean                    2.299829e+07              5.023655e+07
# std                     1.615269e+08              8.387364e+08
# min                     1.000000e+03              1.000000e+03
# 25%                     1.710000e+05              2.200000e+05
# 50%                     1.086000e+06              2.501000e+06
# 75%                     5.895750e+06              1.492825e+07
# max                     5.718265e+09              7.070885e+10
#
#        2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# count                    7.861000e+03        5.425000e+03
# mean                     1.279608e+07        6.001181e+07
# std                      1.643961e+08        3.976602e+08
# min                     -2.577266e+09        1.000000e+03
# 25%                      1.000000e+04        1.506000e+06
# 50%                      3.160000e+05        6.569000e+06
# 75%                      4.209000e+06        2.688100e+07
# max                      8.765452e+09        1.426563e+10
#
#        2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# count                       1.057000e+03               5.447000e+03
# mean                        1.056397e+07               7.865489e+06
# std                         2.940112e+07               7.143855e+07
# min                        -1.182300e+07              -8.895000e+06
# 25%                         2.790000e+05               2.600000e+04
# 50%                         1.579000e+06               1.210000e+05
# 75%                         8.066000e+06               9.990000e+05
# max                         4.437720e+08               2.404268e+09
#
#        2018, Чистая прибыль (убыток), RUB  2018, Оплата труда, RUB  \
# count                        6.163000e+03             5.980000e+02
# mean                         2.957388e+06             2.301952e+07
# std                          4.580852e+07             6.359598e+07
# min                         -1.494500e+09            -2.861600e+07
# 25%                         -8.500000e+04             3.860000e+05
# 50%                          1.010000e+05             2.495500e+06
# 75%                          1.091500e+06             1.461550e+07
# max                          2.081940e+09             6.265480e+08
#
#        2018, Среднесписочная численность работников
# count                                   7860.000000
# mean                                       8.708397
# std                                       57.392902
# min                                        1.000000
# 25%                                        1.000000
# 50%                                        1.000000
# 75%                                        5.000000
# max                                     4079.000000

# %%
pd.isnull(zp).sum()
# Out:
# Дата регистрации                                   17
# Код статистики                                     57
# Отрасль                                             0
# Форма собственности                                41
# Налоговый режим                                  4482
# 2018, Доходы, RUB                                5504
# 2018, Расходы, RUB                               5504
# 2018, Налоги, RUB                                5311
# 2018, Страховые взносы в ПФР, RUB                6728
# 2018, Страховые взносы в ФОМС, RUB               7483
# 2018, Страховые взносы в ФСС, RUB                7491
# 2018, Основные средства , RUB                    9027
# 2018, Активы  всего, RUB                         4381
# 2018, Собственный капитал, RUB                   4366
# 2018, Выручка, RUB                               6802
# 2018, Управленческие расходы, RUB               11170
# 2018, Прочие расходы, RUB                        6780
# 2018, Чистая прибыль (убыток), RUB               6064
# 2018, Оплата труда, RUB                         11629
# 2018, Среднесписочная численность работников     4367
# dtype: int64

# %% [markdown]
# При анализе пропущенных значений видно что в исходных данных много пропусков в столбце "2018, Оплата труда, RUB" и что данных по среднесписочной численности сотрудников более чем в 10 раз больше.
# Так как мы анализируем оплату труда только по одному региону(в нашей выборке включены только компании Каллининградской области) то для уменьшения количества пропущенных данных попробуем заполнить пропуски в оплате труда по следующему алгоритму:
# 1. Из исходных данных рассчитаем среднюю опату труда на одного сотрудника (добавю отдельный столбец '2018, Средняя оплата труда сотрудника')
# 2. Заполним пропуски в стобце '2018, Средняя оплата труда сотрудника' средними значниями по этому столбцу
# 3. Добавим столбец '2018, ФОТ' с рассчетными значениями произведения количества сотрудников и средней оплаты труда
# 4. Удалим столбец '2018, Средняя оплата труда сотрудника'
# 5. Сравним данные из '2018, ФОТ' с данными в столбце "2018, Оплата труда, RUB" и в случае большой доли совпадения данных, будем использовать его в качестве целевого значения
# 6. Удалим столбец '2018, Средняя оплата труда сотрудника'

# %%
#рассчитываем среднюю оплату труда сотрудника за год
zp['2018, Средняя оплата труда сотрудника'] =  zp['2018, Оплата труда, RUB'] / zp['2018, Среднесписочная численность работников'].astype(float)

# %%
#заполняем пропуски среними значениями по столбцу
zp['2018, Средняя оплата труда сотрудника'] = zp['2018, Средняя оплата труда сотрудника'].fillna(zp['2018, Средняя оплата труда сотрудника'].mean())

# %%
#добавляем столбец с рассчетным фондом оплаты труда
zp['2018, ФОТ'] = zp['2018, Средняя оплата труда сотрудника'] * zp['2018, Среднесписочная численность работников'].astype(float)

# %%
# анализируем количество имеющихся данных в столбце '2018, Оплата труда, RUB'
zp['2018, Оплата труда, RUB'].count()
# Out:
# 598

# %%
# создаем временный столбец для проверки расчетного ФОТ(сверяем рассчетный ФОТ с фактическим)
zp['test'] = zp['2018, ФОТ'] == zp['2018, Оплата труда, RUB']

# %%
#анализируем данные полученные при проверке
zp['test'].value_counts()
# Out:
# False    11721
# True       506
# Name: test, dtype: int64

# %%
#рассчитываю точность расчета
print('рассчитанные данные соответствуют фактическим на', 506/598*100,'%')
# Out:
# рассчитанные данные соответствуют фактическим на 84.61538461538461 %

# %%
#to do: Подумать как в качестве заполнтелей пропусков в столбце '2018, Оплата труда, RUB' исползовать данные из '2018, ФОТ'

# %% [markdown]
# За целевую переменную будем брать рассчитанные значения ФОТ

# %%
#удаляем временные столбцы и столбец с фактическими данными по оплате труда(он будет заменен столбцом с рассчетными значениями)
del zp['2018, Средняя оплата труда сотрудника']
del zp['2018, Оплата труда, RUB']
del zp['test']

# %%
#отсутствие значений в столбце с расходами будем интерпритировать как нулевые расходы
zp['2018, Управленческие расходы, RUB'] = zp['2018, Управленческие расходы, RUB'].fillna(0)

# %%
#проанализируем пропуски после преобразований
pd.isnull(zp).sum()
# Out:
# Дата регистрации                                  17
# Код статистики                                    57
# Отрасль                                            0
# Форма собственности                               41
# Налоговый режим                                 4482
# 2018, Доходы, RUB                               5504
# 2018, Расходы, RUB                              5504
# 2018, Налоги, RUB                               5311
# 2018, Страховые взносы в ПФР, RUB               6728
# 2018, Страховые взносы в ФОМС, RUB              7483
# 2018, Страховые взносы в ФСС, RUB               7491
# 2018, Основные средства , RUB                   9027
# 2018, Активы  всего, RUB                        4381
# 2018, Собственный капитал, RUB                  4366
# 2018, Выручка, RUB                              6802
# 2018, Управленческие расходы, RUB                  0
# 2018, Прочие расходы, RUB                       6780
# 2018, Чистая прибыль (убыток), RUB              6064
# 2018, Среднесписочная численность работников    4367
# 2018, ФОТ                                       4367
# dtype: int64

# %%
del zp['2018, Основные средства , RUB']

# %%
zp = zp.dropna() #удаляем пропущенные значения

# %% [markdown]
# ## Подготовка данных для задачи по классификации клиентов на кредитующихся и не кредитующихся

# %%
# выбираем данные для анализа
cred = data[['Дата регистрации',
             'Код статистики',
             'Отрасль',
             'Форма собственности',
             'Налоговый режим',
             'Код причины постановки на учет',
             '2019, Основные средства , RUB',
             '2019, Долгосрочные финансовые вложения, RUB',
             '2019, Отложенные налоговые активы, RUB',
             '2019, Внеоборотные активы, RUB',
             '2019, Чистые активы, RUB',
             '2019, Запасы, RUB',
             '2019, НДС по приобретенным ценностям , RUB',
             '2019, Дебиторская задолженность, RUB',
             '2019, Краткосрочные финансовые вложения, RUB',
             '2019, Денежные средства и денежные эквиваленты, RUB',
             '2019, Прочие оборотные активы, RUB',
             '2019, Оборотные активы, RUB',
             '2019, Активы  всего, RUB',
             '2019, Уставный капитал , RUB',
             '2019, Добавочный капитал, RUB',
             '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
             '2019, Капитал и резервы, RUB',
             '2019, Собственный оборотный капитал, RUB',
             '2019, Себестоимость продаж, RUB',
             '2019, Валовая прибыль (убыток), RUB',
             '2019, Проценты к получению, RUB',
             '2019, Прочие доходы, RUB',
             '2019, Прибыль (убыток) до налогообложения , RUB',
             '2019, Текущий налог на прибыль, RUB',
             '2019, EBIT, RUB',
             '2019, Поступления от текущих операций, RUB',
             '2019, Поступления от продаж, RUB',
             '2019, Платежи по текущим операциям, RUB',
             '2019, Платежи поставщикам и подрядчикам, RUB',
             '2019, Оплата процентов по долговым обязательствам, RUB',
             '2019, Налог на прибыль, RUB',
             '2019, Сальдо денежных потоков от текущих операций, RUB',
             '2019, Платежи по инвестиционным операциям, RUB',
             '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
             '2019, Поступления от финансовых операций, RUB',
             '2019, Платежи по финансовым операциям, RUB',
             '2019, Сальдо денежных потоков от финансовых операций, RUB',
             '2019, Сальдо денежных потоков за отчетный период, RUB',
             '2019, Поступление денежных средств всего, RUB',
             '2019, Заёмные средства (долгосрочные), RUB',
             '2019, Прочие долгосрочные обязательства, RUB',
             '2019, Долгосрочные обязательства, RUB',
             '2019, Заёмные средства (краткосрочные), RUB',
             '2019, Кредиторская задолженность, RUB',
             '2019, Прочие краткосрочные обязательства, RUB',
             '2019, Краткосрочные обязательства, RUB',
             '2019, Пассивы всего, RUB',
             '2019, Совокупный долг, RUB',
             '2019, Собственный капитал, RUB',
             '2019, Выручка, RUB',
             '2019, Коммерческие расходы, RUB',
             '2019, Управленческие расходы, RUB',
             '2019, Прибыль (убыток) от продажи, RUB',
             '2019, Проценты к уплате, RUB',
             '2019, Прочие расходы, RUB',
             '2019, Чистая прибыль (убыток), RUB',
             '2019, Получение кредитов и займов, RUB',
             '2019, Погашение векселей, возврат кредитов и займов, RUB',
             'Залоги'
          ]].copy()

# %%
cred.head(2)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 12390280       2019-10-28      42006784.0  Производство
#
#             Форма собственности Налоговый режим  \
# ID
# 4283790   Частная собственность             УСН
# 12390280  Частная собственность             NaN
#
#           Код причины постановки на учет  2019, Основные средства , RUB  \
# ID
# 4283790                      390601001.0                       651000.0
# 12390280                     391401001.0                            NaN
#
#           2019, Долгосрочные финансовые вложения, RUB  \
# ID
# 4283790                                           NaN
# 12390280                                          NaN
#
#           2019, Отложенные налоговые активы, RUB  \
# ID
# 4283790                                      NaN
# 12390280                                     NaN
#
#           2019, Внеоборотные активы, RUB  ...  2019, Выручка, RUB  \
# ID                                        ...
# 4283790                         651000.0  ...            909000.0
# 12390280                             NaN  ...                 NaN
#
#           2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# ID
# 4283790                               NaN                            47000.0
# 12390280                              NaN                                NaN
#
#           2019, Прибыль (убыток) от продажи, RUB  \
# ID
# 4283790                                -320000.0
# 12390280                                     NaN
#
#           2019, Проценты к уплате, RUB  2019, Прочие расходы, RUB  \
# ID
# 4283790                            NaN                    47000.0
# 12390280                           NaN                        NaN
#
#           2019, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                            -365000.0
# 12390280                                 NaN
#
#           2019, Получение кредитов и займов, RUB  \
# ID
# 4283790                                      NaN
# 12390280                                     NaN
#
#           2019, Погашение векселей, возврат кредитов и займов, RUB  Залоги
# ID
# 4283790                                                 NaN            0.0
# 12390280                                                NaN            0.0
#
# [2 rows x 65 columns]

# %%
# анализирем признаки с наибольшим количеством пропусков
pd.isnull(cred).sum().nlargest(50)
# Out:
# 2019, Оплата процентов по долговым обязательствам, RUB           12064
# 2019, Платежи по инвестиционным операциям, RUB                   11970
# 2019, Прочие краткосрочные обязательства, RUB                    11956
# 2019, Отложенные налоговые активы, RUB                           11955
# 2019, Прочие долгосрочные обязательства, RUB                     11938
# 2019, Сальдо денежных потоков от инвестиционных операций, RUB    11932
# 2019, Погашение векселей, возврат кредитов и займов, RUB         11925
# 2019, Проценты к получению, RUB                                  11917
# 2019, Добавочный капитал, RUB                                    11890
# 2019, Налог на прибыль, RUB                                      11889
# 2019, Получение кредитов и займов, RUB                           11868
# 2019, Платежи по финансовым операциям, RUB                       11858
# 2019, НДС по приобретенным ценностям , RUB                       11830
# 2019, Поступления от финансовых операций, RUB                    11829
# 2019, Долгосрочные финансовые вложения, RUB                      11768
# 2019, Сальдо денежных потоков от финансовых операций, RUB        11767
# 2019, Краткосрочные финансовые вложения, RUB                     11710
# 2019, Поступления от продаж, RUB                                 11600
# 2019, Прочие оборотные активы, RUB                               11598
# 2019, Проценты к уплате, RUB                                     11589
# 2019, Коммерческие расходы, RUB                                  11580
# 2019, Поступления от текущих операций, RUB                       11506
# 2019, Платежи поставщикам и подрядчикам, RUB                     11504
# 2019, Сальдо денежных потоков за отчетный период, RUB            11472
# 2019, Поступление денежных средств всего, RUB                    11466
# 2019, Сальдо денежных потоков от текущих операций, RUB           11465
# 2019, Платежи по текущим операциям, RUB                          11448
# 2019, Долгосрочные обязательства, RUB                            11433
# 2019, Управленческие расходы, RUB                                11211
# 2019, Внеоборотные активы, RUB                                   10892
# 2019, Валовая прибыль (убыток), RUB                              10543
# 2019, Заёмные средства (долгосрочные), RUB                       10311
# 2019, Краткосрочные обязательства, RUB                           10145
# 2019, Нераспределенная прибыль (непокрытый убыток), RUB          10136
# 2019, Совокупный долг, RUB                                       10100
# 2019, EBIT, RUB                                                   9989
# 2019, Уставный капитал , RUB                                      9943
# 2019, Оборотные активы, RUB                                       9840
# 2019, Заёмные средства (краткосрочные), RUB                       9803
# 2019, Прочие доходы, RUB                                          9294
# 2019, Основные средства , RUB                                     9066
# 2019, Текущий налог на прибыль, RUB                               8504
# 2019, Запасы, RUB                                                 8051
# 2019, Выручка, RUB                                                6963
# 2019, Себестоимость продаж, RUB                                   6924
# 2019, Прочие расходы, RUB                                         6849
# 2019, Прибыль (убыток) от продажи, RUB                            6499
# 2019, Денежные средства и денежные эквиваленты, RUB               6342
# 2019, Прибыль (убыток) до налогообложения , RUB                   6205
# 2019, Чистая прибыль (убыток), RUB                                6196
# dtype: int64

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
cred[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]] = cred[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
pd.isnull(cred).sum() #анализируем количество пропусков после частичного заполнения данных нулевыми значениями
# Out:
# Дата регистрации                                              17
# Код статистики                                                57
# Отрасль                                                        0
# Форма собственности                                           41
# Налоговый режим                                             4482
#                                                             ...
# 2019, Прочие расходы, RUB                                      0
# 2019, Чистая прибыль (убыток), RUB                          6196
# 2019, Получение кредитов и займов, RUB                         0
# 2019, Погашение векселей, возврат кредитов и займов, RUB       0
# Залоги                                                         0
# Length: 65, dtype: int64

# %%
cred = cred.dropna() #удаляем пропущенные значения

# %%
cred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 4283790 to 5297219
# Data columns (total 65 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Дата регистрации                                               3774 non-null   datetime64[ns]
#  1   Код статистики                                                 3774 non-null   float64
#  2   Отрасль                                                        3774 non-null   object
#  3   Форма собственности                                            3774 non-null   object
#  4   Налоговый режим                                                3774 non-null   object
#  5   Код причины постановки на учет                                 3774 non-null   float64
#  6   2019, Основные средства , RUB                                  3774 non-null   float64
#  7   2019, Долгосрочные финансовые вложения, RUB                    3774 non-null   float64
#  8   2019, Отложенные налоговые активы, RUB                         3774 non-null   float64
#  9   2019, Внеоборотные активы, RUB                                 3774 non-null   float64
#  10  2019, Чистые активы, RUB                                       3774 non-null   float64
#  11  2019, Запасы, RUB                                              3774 non-null   float64
#  12  2019, НДС по приобретенным ценностям , RUB                     3774 non-null   float64
#  13  2019, Дебиторская задолженность, RUB                           3774 non-null   float64
#  14  2019, Краткосрочные финансовые вложения, RUB                   3774 non-null   float64
#  15  2019, Денежные средства и денежные эквиваленты, RUB            3774 non-null   float64
#  16  2019, Прочие оборотные активы, RUB                             3774 non-null   float64
#  17  2019, Оборотные активы, RUB                                    3774 non-null   float64
#  18  2019, Активы  всего, RUB                                       3774 non-null   float64
#  19  2019, Уставный капитал , RUB                                   3774 non-null   float64
#  20  2019, Добавочный капитал, RUB                                  3774 non-null   float64
#  21  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3774 non-null   float64
#  22  2019, Капитал и резервы, RUB                                   3774 non-null   float64
#  23  2019, Собственный оборотный капитал, RUB                       3774 non-null   float64
#  24  2019, Себестоимость продаж, RUB                                3774 non-null   float64
#  25  2019, Валовая прибыль (убыток), RUB                            3774 non-null   float64
#  26  2019, Проценты к получению, RUB                                3774 non-null   float64
#  27  2019, Прочие доходы, RUB                                       3774 non-null   float64
#  28  2019, Прибыль (убыток) до налогообложения , RUB                3774 non-null   float64
#  29  2019, Текущий налог на прибыль, RUB                            3774 non-null   float64
#  30  2019, EBIT, RUB                                                3774 non-null   float64
#  31  2019, Поступления от текущих операций, RUB                     3774 non-null   float64
#  32  2019, Поступления от продаж, RUB                               3774 non-null   float64
#  33  2019, Платежи по текущим операциям, RUB                        3774 non-null   float64
#  34  2019, Платежи поставщикам и подрядчикам, RUB                   3774 non-null   float64
#  35  2019, Оплата процентов по долговым обязательствам, RUB         3774 non-null   float64
#  36  2019, Налог на прибыль, RUB                                    3774 non-null   float64
#  37  2019, Сальдо денежных потоков от текущих операций, RUB         3774 non-null   float64
#  38  2019, Платежи по инвестиционным операциям, RUB                 3774 non-null   float64
#  39  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3774 non-null   float64
#  40  2019, Поступления от финансовых операций, RUB                  3774 non-null   float64
#  41  2019, Платежи по финансовым операциям, RUB                     3774 non-null   float64
#  42  2019, Сальдо денежных потоков от финансовых операций, RUB      3774 non-null   float64
#  43  2019, Сальдо денежных потоков за отчетный период, RUB          3774 non-null   float64
#  44  2019, Поступление денежных средств всего, RUB                  3774 non-null   float64
#  45  2019, Заёмные средства (долгосрочные), RUB                     3774 non-null   float64
#  46  2019, Прочие долгосрочные обязательства, RUB                   3774 non-null   float64
#  47  2019, Долгосрочные обязательства, RUB                          3774 non-null   float64
#  48  2019, Заёмные средства (краткосрочные), RUB                    3774 non-null   float64
#  49  2019, Кредиторская задолженность, RUB                          3774 non-null   float64
#  50  2019, Прочие краткосрочные обязательства, RUB                  3774 non-null   float64
#  51  2019, Краткосрочные обязательства, RUB                         3774 non-null   float64
#  52  2019, Пассивы всего, RUB                                       3774 non-null   float64
#  53  2019, Совокупный долг, RUB                                     3774 non-null   float64
#  54  2019, Собственный капитал, RUB                                 3774 non-null   float64
#  55  2019, Выручка, RUB                                             3774 non-null   float64
#  56  2019, Коммерческие расходы, RUB                                3774 non-null   float64
#  57  2019, Управленческие расходы, RUB                              3774 non-null   float64
#  58  2019, Прибыль (убыток) от продажи, RUB                         3774 non-null   float64
#  59  2019, Проценты к уплате, RUB                                   3774 non-null   float64
#  60  2019, Прочие расходы, RUB                                      3774 non-null   float64
#  61  2019, Чистая прибыль (убыток), RUB                             3774 non-null   float64
#  62  2019, Получение кредитов и займов, RUB                         3774 non-null   float64
#  63  2019, Погашение векселей, возврат кредитов и займов, RUB       3774 non-null   float64
#  64  Залоги                                                         3774 non-null   float64
# dtypes: datetime64[ns](1), float64(61), object(3)
# memory usage: 1.9+ MB

# %%
cred.corr()
# Out:
#                                                     Код статистики  \
# Код статистики                                            1.000000
# Код причины постановки на учет                           -0.019545
# 2019, Основные средства , RUB                             0.032946
# 2019, Долгосрочные финансовые вложения, RUB               0.020267
# 2019, Отложенные налоговые активы, RUB                   -0.003212
# ...                                                            ...
# 2019, Прочие расходы, RUB                                 0.008844
# 2019, Чистая прибыль (убыток), RUB                        0.005996
# 2019, Получение кредитов и займов, RUB                    0.008077
# 2019, Погашение векселей, возврат кредитов и за...        0.003224
# Залоги                                                    0.068211
#
#                                                     Код причины постановки на учет  \
# Код статистики                                                           -0.019545
# Код причины постановки на учет                                            1.000000
# 2019, Основные средства , RUB                                             0.009840
# 2019, Долгосрочные финансовые вложения, RUB                               0.016911
# 2019, Отложенные налоговые активы, RUB                                   -0.011327
# ...                                                                            ...
# 2019, Прочие расходы, RUB                                                 0.034230
# 2019, Чистая прибыль (убыток), RUB                                        0.029260
# 2019, Получение кредитов и займов, RUB                                   -0.011391
# 2019, Погашение векселей, возврат кредитов и за...                       -0.017948
# Залоги                                                                   -0.006027
#
#                                                     2019, Основные средства , RUB  \
# Код статистики                                                           0.032946
# Код причины постановки на учет                                           0.009840
# 2019, Основные средства , RUB                                            1.000000
# 2019, Долгосрочные финансовые вложения, RUB                              0.045771
# 2019, Отложенные налоговые активы, RUB                                  -0.004375
# ...                                                                           ...
# 2019, Прочие расходы, RUB                                                0.010947
# 2019, Чистая прибыль (убыток), RUB                                       0.017812
# 2019, Получение кредитов и займов, RUB                                   0.200966
# 2019, Погашение векселей, возврат кредитов и за...                       0.148168
# Залоги                                                                   0.091228
#
#                                                     2019, Долгосрочные финансовые вложения, RUB  \
# Код статистики                                                                         0.020267
# Код причины постановки на учет                                                         0.016911
# 2019, Основные средства , RUB                                                          0.045771
# 2019, Долгосрочные финансовые вложения, RUB                                            1.000000
# 2019, Отложенные налоговые активы, RUB                                                -0.001587
# ...                                                                                         ...
# 2019, Прочие расходы, RUB                                                              0.016757
# 2019, Чистая прибыль (убыток), RUB                                                     0.014741
# 2019, Получение кредитов и займов, RUB                                                 0.084299
# 2019, Погашение векселей, возврат кредитов и за...                                     0.066012
# Залоги                                                                                -0.003647
#
#                                                     2019, Отложенные налоговые активы, RUB  \
# Код статистики                                                                   -0.003212
# Код причины постановки на учет                                                   -0.011327
# 2019, Основные средства , RUB                                                    -0.004375
# 2019, Долгосрочные финансовые вложения, RUB                                      -0.001587
# 2019, Отложенные налоговые активы, RUB                                            1.000000
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.003215
# 2019, Чистая прибыль (убыток), RUB                                               -0.007032
# 2019, Получение кредитов и займов, RUB                                            0.026314
# 2019, Погашение векселей, возврат кредитов и за...                                0.023146
# Залоги                                                                            0.002824
#
#                                                     2019, Внеоборотные активы, RUB  \
# Код статистики                                                            0.015473
# Код причины постановки на учет                                            0.010378
# 2019, Основные средства , RUB                                             0.710150
# 2019, Долгосрочные финансовые вложения, RUB                               0.365460
# 2019, Отложенные налоговые активы, RUB                                    0.138481
# ...                                                                            ...
# 2019, Прочие расходы, RUB                                                 0.010373
# 2019, Чистая прибыль (убыток), RUB                                        0.016227
# 2019, Получение кредитов и займов, RUB                                    0.202314
# 2019, Погашение векселей, возврат кредитов и за...                        0.148389
# Залоги                                                                    0.016559
#
#                                                     2019, Чистые активы, RUB  \
# Код статистики                                                      0.030378
# Код причины постановки на учет                                     -0.011001
# 2019, Основные средства , RUB                                       0.409259
# 2019, Долгосрочные финансовые вложения, RUB                         0.097176
# 2019, Отложенные налоговые активы, RUB                             -0.023807
# ...                                                                      ...
# 2019, Прочие расходы, RUB                                           0.007668
# 2019, Чистая прибыль (убыток), RUB                                  0.068274
# 2019, Получение кредитов и займов, RUB                              0.048442
# 2019, Погашение векселей, возврат кредитов и за...                  0.045107
# Залоги                                                              0.080199
#
#                                                     2019, Запасы, RUB  \
# Код статистики                                               0.022029
# Код причины постановки на учет                               0.002328
# 2019, Основные средства , RUB                                0.131290
# 2019, Долгосрочные финансовые вложения, RUB                  0.033685
# 2019, Отложенные налоговые активы, RUB                       0.038062
# ...                                                               ...
# 2019, Прочие расходы, RUB                                    0.010308
# 2019, Чистая прибыль (убыток), RUB                           0.013121
# 2019, Получение кредитов и займов, RUB                       0.209856
# 2019, Погашение векселей, возврат кредитов и за...           0.200832
# Залоги                                                       0.098826
#
#                                                     2019, НДС по приобретенным ценностям , RUB  \
# Код статистики                                                                        0.018220
# Код причины постановки на учет                                                       -0.021628
# 2019, Основные средства , RUB                                                         0.095988
# 2019, Долгосрочные финансовые вложения, RUB                                          -0.002275
# 2019, Отложенные налоговые активы, RUB                                                0.088218
# ...                                                                                        ...
# 2019, Прочие расходы, RUB                                                             0.003918
# 2019, Чистая прибыль (убыток), RUB                                                    0.001988
# 2019, Получение кредитов и займов, RUB                                                0.203943
# 2019, Погашение векселей, возврат кредитов и за...                                    0.247407
# Залоги                                                                                0.077518
#
#                                                     2019, Дебиторская задолженность, RUB  \
# Код статистики                                                                  0.030265
# Код причины постановки на учет                                                  0.009794
# 2019, Основные средства , RUB                                                   0.148031
# 2019, Долгосрочные финансовые вложения, RUB                                     0.274303
# 2019, Отложенные налоговые активы, RUB                                          0.000314
# ...                                                                                  ...
# 2019, Прочие расходы, RUB                                                       0.032076
# 2019, Чистая прибыль (убыток), RUB                                              0.030133
# 2019, Получение кредитов и займов, RUB                                          0.051097
# 2019, Погашение векселей, возврат кредитов и за...                              0.043512
# Залоги                                                                          0.026329
#
#                                                     ...  2019, Выручка, RUB  \
# Код статистики                                      ...            0.001745
# Код причины постановки на учет                      ...            0.035330
# 2019, Основные средства , RUB                       ...            0.012960
# 2019, Долгосрочные финансовые вложения, RUB         ...            0.005089
# 2019, Отложенные налоговые активы, RUB              ...            0.002442
# ...                                                 ...                 ...
# 2019, Прочие расходы, RUB                           ...            0.984060
# 2019, Чистая прибыль (убыток), RUB                  ...            0.964884
# 2019, Получение кредитов и займов, RUB              ...            0.024294
# 2019, Погашение векселей, возврат кредитов и за...  ...            0.025969
# Залоги                                              ...            0.006733
#
#                                                     2019, Коммерческие расходы, RUB  \
# Код статистики                                                             0.008707
# Код причины постановки на учет                                            -0.023253
# 2019, Основные средства , RUB                                              0.053941
# 2019, Долгосрочные финансовые вложения, RUB                                0.047480
# 2019, Отложенные налоговые активы, RUB                                     0.038438
# ...                                                                             ...
# 2019, Прочие расходы, RUB                                                  0.009467
# 2019, Чистая прибыль (убыток), RUB                                         0.001162
# 2019, Получение кредитов и займов, RUB                                     0.189932
# 2019, Погашение векселей, возврат кредитов и за...                         0.218307
# Залоги                                                                     0.104574
#
#                                                     2019, Управленческие расходы, RUB  \
# Код статистики                                                               0.016059
# Код причины постановки на учет                                               0.024817
# 2019, Основные средства , RUB                                                0.168706
# 2019, Долгосрочные финансовые вложения, RUB                                  0.035887
# 2019, Отложенные налоговые активы, RUB                                       0.050933
# ...                                                                               ...
# 2019, Прочие расходы, RUB                                                    0.007986
# 2019, Чистая прибыль (убыток), RUB                                           0.005240
# 2019, Получение кредитов и займов, RUB                                       0.140348
# 2019, Погашение векселей, возврат кредитов и за...                           0.148337
# Залоги                                                                       0.077085
#
#                                                     2019, Прибыль (убыток) от продажи, RUB  \
# Код статистики                                                                    0.003043
# Код причины постановки на учет                                                    0.031364
# 2019, Основные средства , RUB                                                     0.016476
# 2019, Долгосрочные финансовые вложения, RUB                                       0.013245
# 2019, Отложенные налоговые активы, RUB                                           -0.005784
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.990443
# 2019, Чистая прибыль (убыток), RUB                                                0.992732
# 2019, Получение кредитов и займов, RUB                                            0.003874
# 2019, Погашение векселей, возврат кредитов и за...                                0.003565
# Залоги                                                                            0.001733
#
#                                                     2019, Проценты к уплате, RUB  \
# Код статистики                                                          0.033618
# Код причины постановки на учет                                         -0.025058
# 2019, Основные средства , RUB                                           0.252900
# 2019, Долгосрочные финансовые вложения, RUB                             0.089861
# 2019, Отложенные налоговые активы, RUB                                  0.072559
# ...                                                                          ...
# 2019, Прочие расходы, RUB                                               0.010938
# 2019, Чистая прибыль (убыток), RUB                                      0.007154
# 2019, Получение кредитов и займов, RUB                                  0.490697
# 2019, Погашение векселей, возврат кредитов и за...                      0.471778
# Залоги                                                                  0.191125
#
#                                                     2019, Прочие расходы, RUB  \
# Код статистики                                                       0.008844
# Код причины постановки на учет                                       0.034230
# 2019, Основные средства , RUB                                        0.010947
# 2019, Долгосрочные финансовые вложения, RUB                          0.016757
# 2019, Отложенные налоговые активы, RUB                               0.003215
# ...                                                                       ...
# 2019, Прочие расходы, RUB                                            1.000000
# 2019, Чистая прибыль (убыток), RUB                                   0.986053
# 2019, Получение кредитов и займов, RUB                               0.004693
# 2019, Погашение векселей, возврат кредитов и за...                   0.005443
# Залоги                                                               0.001374
#
#                                                     2019, Чистая прибыль (убыток), RUB  \
# Код статистики                                                                0.005996
# Код причины постановки на учет                                                0.029260
# 2019, Основные средства , RUB                                                 0.017812
# 2019, Долгосрочные финансовые вложения, RUB                                   0.014741
# 2019, Отложенные налоговые активы, RUB                                       -0.007032
# ...                                                                                ...
# 2019, Прочие расходы, RUB                                                     0.986053
# 2019, Чистая прибыль (убыток), RUB                                            1.000000
# 2019, Получение кредитов и займов, RUB                                        0.003548
# 2019, Погашение векселей, возврат кредитов и за...                            0.003832
# Залоги                                                                        0.000115
#
#                                                     2019, Получение кредитов и займов, RUB  \
# Код статистики                                                                    0.008077
# Код причины постановки на учет                                                   -0.011391
# 2019, Основные средства , RUB                                                     0.200966
# 2019, Долгосрочные финансовые вложения, RUB                                       0.084299
# 2019, Отложенные налоговые активы, RUB                                            0.026314
# ...                                                                                    ...
# 2019, Прочие расходы, RUB                                                         0.004693
# 2019, Чистая прибыль (убыток), RUB                                                0.003548
# 2019, Получение кредитов и займов, RUB                                            1.000000
# 2019, Погашение векселей, возврат кредитов и за...                                0.950820
# Залоги                                                                            0.127575
#
#                                                     2019, Погашение векселей, возврат кредитов и займов, RUB  \
# Код статистики                                                                               0.003224
# Код причины постановки на учет                                                              -0.017948
# 2019, Основные средства , RUB                                                                0.148168
# 2019, Долгосрочные финансовые вложения, RUB                                                  0.066012
# 2019, Отложенные налоговые активы, RUB                                                       0.023146
# ...                                                                                               ...
# 2019, Прочие расходы, RUB                                                                    0.005443
# 2019, Чистая прибыль (убыток), RUB                                                           0.003832
# 2019, Получение кредитов и займов, RUB                                                       0.950820
# 2019, Погашение векселей, возврат кредитов и за...                                           1.000000
# Залоги                                                                                       0.130575
#
#                                                       Залоги
# Код статистики                                      0.068211
# Код причины постановки на учет                     -0.006027
# 2019, Основные средства , RUB                       0.091228
# 2019, Долгосрочные финансовые вложения, RUB        -0.003647
# 2019, Отложенные налоговые активы, RUB              0.002824
# ...                                                      ...
# 2019, Прочие расходы, RUB                           0.001374
# 2019, Чистая прибыль (убыток), RUB                  0.000115
# 2019, Получение кредитов и займов, RUB              0.127575
# 2019, Погашение векселей, возврат кредитов и за...  0.130575
# Залоги                                              1.000000
#
# [61 rows x 61 columns]

# %% [markdown]
# ## Подготовка данных для задачи по классификации на компании используюзие банковские гарантии

# %%
# Для удобства работы решил разбить данные на отдельные части для каждой задачи
# данные для предказания наличия гарантий
bg = data[['Дата регистрации',
           'Код статистики',
           'Отрасль',
           'Форма собственности',
           'Налоговый режим',
           'Код причины постановки на учет',
           '2019, Основные средства , RUB',
           '2019, Долгосрочные финансовые вложения, RUB',
           '2019, Отложенные налоговые активы, RUB',
           '2019, Внеоборотные активы, RUB',
           '2019, Чистые активы, RUB',
           '2019, Запасы, RUB',
           '2019, НДС по приобретенным ценностям , RUB',
           '2019, Дебиторская задолженность, RUB',
           '2019, Краткосрочные финансовые вложения, RUB',
           '2019, Денежные средства и денежные эквиваленты, RUB',
           '2019, Прочие оборотные активы, RUB',
           '2019, Оборотные активы, RUB',
           '2019, Активы  всего, RUB',
           '2019, Уставный капитал , RUB',
           '2019, Добавочный капитал, RUB',
           '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
           '2019, Капитал и резервы, RUB',
           '2019, Собственный оборотный капитал, RUB',
           '2019, Себестоимость продаж, RUB',
           '2019, Валовая прибыль (убыток), RUB',
           '2019, Проценты к получению, RUB',
           '2019, Прочие доходы, RUB',
           '2019, Прибыль (убыток) до налогообложения , RUB',
           '2019, Текущий налог на прибыль, RUB',
           '2019, EBIT, RUB',
           '2019, Поступления от текущих операций, RUB',
           '2019, Поступления от продаж, RUB',
           '2019, Платежи по текущим операциям, RUB',
           '2019, Платежи поставщикам и подрядчикам, RUB',
           '2019, Оплата процентов по долговым обязательствам, RUB',
           '2019, Налог на прибыль, RUB',
           '2019, Сальдо денежных потоков от текущих операций, RUB',
           '2019, Платежи по инвестиционным операциям, RUB',
           '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
           '2019, Поступления от финансовых операций, RUB',
           '2019, Платежи по финансовым операциям, RUB',
           '2019, Сальдо денежных потоков от финансовых операций, RUB',
           '2019, Сальдо денежных потоков за отчетный период, RUB',
           '2019, Поступление денежных средств всего, RUB',
           '2019, Заёмные средства (долгосрочные), RUB',
           '2019, Прочие долгосрочные обязательства, RUB',
           '2019, Долгосрочные обязательства, RUB',
           '2019, Заёмные средства (краткосрочные), RUB',
           '2019, Кредиторская задолженность, RUB',
           '2019, Прочие краткосрочные обязательства, RUB',
           '2019, Краткосрочные обязательства, RUB',
           '2019, Пассивы всего, RUB',
           '2019, Совокупный долг, RUB',
           '2019, Собственный капитал, RUB',
           '2019, Выручка, RUB',
           '2019, Коммерческие расходы, RUB',
           '2019, Управленческие расходы, RUB',
           '2019, Прибыль (убыток) от продажи, RUB',
           '2019, Проценты к уплате, RUB',
           '2019, Прочие расходы, RUB',
           '2019, Чистая прибыль (убыток), RUB',
           '2019, Получение кредитов и займов, RUB',
           '2019, Погашение векселей, возврат кредитов и займов, RUB',
           'БГ'
          ]].copy()

# %%
bg.head(3)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 12390280       2019-10-28      42006784.0  Производство
# 9603036        2014-11-11      35394691.0  Производство
#
#             Форма собственности Налоговый режим  \
# ID
# 4283790   Частная собственность             УСН
# 12390280  Частная собственность             NaN
# 9603036   Частная собственность             УСН
#
#           Код причины постановки на учет  2019, Основные средства , RUB  \
# ID
# 4283790                      390601001.0                       651000.0
# 12390280                     391401001.0                            NaN
# 9603036                      390601001.0                            NaN
#
#           2019, Долгосрочные финансовые вложения, RUB  \
# ID
# 4283790                                           NaN
# 12390280                                          NaN
# 9603036                                           NaN
#
#           2019, Отложенные налоговые активы, RUB  \
# ID
# 4283790                                      NaN
# 12390280                                     NaN
# 9603036                                      NaN
#
#           2019, Внеоборотные активы, RUB  ...  2019, Выручка, RUB  \
# ID                                        ...
# 4283790                         651000.0  ...            909000.0
# 12390280                             NaN  ...                 NaN
# 9603036                              NaN  ...                 NaN
#
#           2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# ID
# 4283790                               NaN                            47000.0
# 12390280                              NaN                                NaN
# 9603036                               NaN                                NaN
#
#           2019, Прибыль (убыток) от продажи, RUB  \
# ID
# 4283790                                -320000.0
# 12390280                                     NaN
# 9603036                                      NaN
#
#           2019, Проценты к уплате, RUB  2019, Прочие расходы, RUB  \
# ID
# 4283790                            NaN                    47000.0
# 12390280                           NaN                        NaN
# 9603036                            NaN                        NaN
#
#           2019, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                            -365000.0
# 12390280                                 NaN
# 9603036                                  NaN
#
#           2019, Получение кредитов и займов, RUB  \
# ID
# 4283790                                      NaN
# 12390280                                     NaN
# 9603036                                      NaN
#
#           2019, Погашение векселей, возврат кредитов и займов, RUB   БГ
# ID
# 4283790                                                 NaN         0.0
# 12390280                                                NaN         0.0
# 9603036                                                 NaN         0.0
#
# [3 rows x 65 columns]

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
bg[['2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',     
    '2019, Дебиторская задолженность, RUB',    
    '2019, Краткосрочные финансовые вложения, RUB',   
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',          
    '2019, Активы  всего, RUB',  
    '2019, Уставный капитал , RUB',           
    '2019, Добавочный капитал, RUB',           
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',          
    '2019, Капитал и резервы, RUB',           
    '2019, Собственный оборотный капитал, RUB',           
    '2019, Себестоимость продаж, RUB',         
    '2019, Валовая прибыль (убыток), RUB',         
    '2019, Проценты к получению, RUB',        
    '2019, Прочие доходы, RUB',      
    '2019, Прибыль (убыток) до налогообложения , RUB',      
    '2019, Текущий налог на прибыль, RUB',         
    '2019, EBIT, RUB',     
    '2019, Поступления от текущих операций, RUB',         
    '2019, Поступления от продаж, RUB',       
    '2019, Платежи по текущим операциям, RUB',         
    '2019, Платежи поставщикам и подрядчикам, RUB',          
    '2019, Оплата процентов по долговым обязательствам, RUB',          
    '2019, Налог на прибыль, RUB',           
    '2019, Сальдо денежных потоков от текущих операций, RUB',       
    '2019, Платежи по инвестиционным операциям, RUB',          
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',         
    '2019, Поступления от финансовых операций, RUB',          
    '2019, Платежи по финансовым операциям, RUB',         
    '2019, Сальдо денежных потоков от финансовых операций, RUB',        
    '2019, Сальдо денежных потоков за отчетный период, RUB',          
    '2019, Поступление денежных средств всего, RUB'
]] = bg[[
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',     
    '2019, Дебиторская задолженность, RUB',    
    '2019, Краткосрочные финансовые вложения, RUB',   
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',          
    '2019, Активы  всего, RUB',  
    '2019, Уставный капитал , RUB',           
    '2019, Добавочный капитал, RUB',           
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',          
    '2019, Капитал и резервы, RUB',           
    '2019, Собственный оборотный капитал, RUB',           
    '2019, Себестоимость продаж, RUB',         
    '2019, Валовая прибыль (убыток), RUB',         
    '2019, Проценты к получению, RUB',        
    '2019, Прочие доходы, RUB',      
    '2019, Прибыль (убыток) до налогообложения , RUB',      
    '2019, Текущий налог на прибыль, RUB',         
    '2019, EBIT, RUB',     
    '2019, Поступления от текущих операций, RUB',         
    '2019, Поступления от продаж, RUB',       
    '2019, Платежи по текущим операциям, RUB',         
    '2019, Платежи поставщикам и подрядчикам, RUB',          
    '2019, Оплата процентов по долговым обязательствам, RUB',          
    '2019, Налог на прибыль, RUB',           
    '2019, Сальдо денежных потоков от текущих операций, RUB',       
    '2019, Платежи по инвестиционным операциям, RUB',          
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',         
    '2019, Поступления от финансовых операций, RUB',          
    '2019, Платежи по финансовым операциям, RUB',         
    '2019, Сальдо денежных потоков от финансовых операций, RUB',        
    '2019, Сальдо денежных потоков за отчетный период, RUB',          
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
bg = bg.dropna() #удаляем пропущенные значения

# %%
bg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3774 entries, 4283790 to 5297219
# Data columns (total 65 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Дата регистрации                                               3774 non-null   datetime64[ns]
#  1   Код статистики                                                 3774 non-null   float64
#  2   Отрасль                                                        3774 non-null   object
#  3   Форма собственности                                            3774 non-null   object
#  4   Налоговый режим                                                3774 non-null   object
#  5   Код причины постановки на учет                                 3774 non-null   float64
#  6   2019, Основные средства , RUB                                  3774 non-null   float64
#  7   2019, Долгосрочные финансовые вложения, RUB                    3774 non-null   float64
#  8   2019, Отложенные налоговые активы, RUB                         3774 non-null   float64
#  9   2019, Внеоборотные активы, RUB                                 3774 non-null   float64
#  10  2019, Чистые активы, RUB                                       3774 non-null   float64
#  11  2019, Запасы, RUB                                              3774 non-null   float64
#  12  2019, НДС по приобретенным ценностям , RUB                     3774 non-null   float64
#  13  2019, Дебиторская задолженность, RUB                           3774 non-null   float64
#  14  2019, Краткосрочные финансовые вложения, RUB                   3774 non-null   float64
#  15  2019, Денежные средства и денежные эквиваленты, RUB            3774 non-null   float64
#  16  2019, Прочие оборотные активы, RUB                             3774 non-null   float64
#  17  2019, Оборотные активы, RUB                                    3774 non-null   float64
#  18  2019, Активы  всего, RUB                                       3774 non-null   float64
#  19  2019, Уставный капитал , RUB                                   3774 non-null   float64
#  20  2019, Добавочный капитал, RUB                                  3774 non-null   float64
#  21  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3774 non-null   float64
#  22  2019, Капитал и резервы, RUB                                   3774 non-null   float64
#  23  2019, Собственный оборотный капитал, RUB                       3774 non-null   float64
#  24  2019, Себестоимость продаж, RUB                                3774 non-null   float64
#  25  2019, Валовая прибыль (убыток), RUB                            3774 non-null   float64
#  26  2019, Проценты к получению, RUB                                3774 non-null   float64
#  27  2019, Прочие доходы, RUB                                       3774 non-null   float64
#  28  2019, Прибыль (убыток) до налогообложения , RUB                3774 non-null   float64
#  29  2019, Текущий налог на прибыль, RUB                            3774 non-null   float64
#  30  2019, EBIT, RUB                                                3774 non-null   float64
#  31  2019, Поступления от текущих операций, RUB                     3774 non-null   float64
#  32  2019, Поступления от продаж, RUB                               3774 non-null   float64
#  33  2019, Платежи по текущим операциям, RUB                        3774 non-null   float64
#  34  2019, Платежи поставщикам и подрядчикам, RUB                   3774 non-null   float64
#  35  2019, Оплата процентов по долговым обязательствам, RUB         3774 non-null   float64
#  36  2019, Налог на прибыль, RUB                                    3774 non-null   float64
#  37  2019, Сальдо денежных потоков от текущих операций, RUB         3774 non-null   float64
#  38  2019, Платежи по инвестиционным операциям, RUB                 3774 non-null   float64
#  39  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3774 non-null   float64
#  40  2019, Поступления от финансовых операций, RUB                  3774 non-null   float64
#  41  2019, Платежи по финансовым операциям, RUB                     3774 non-null   float64
#  42  2019, Сальдо денежных потоков от финансовых операций, RUB      3774 non-null   float64
#  43  2019, Сальдо денежных потоков за отчетный период, RUB          3774 non-null   float64
#  44  2019, Поступление денежных средств всего, RUB                  3774 non-null   float64
#  45  2019, Заёмные средства (долгосрочные), RUB                     3774 non-null   float64
#  46  2019, Прочие долгосрочные обязательства, RUB                   3774 non-null   float64
#  47  2019, Долгосрочные обязательства, RUB                          3774 non-null   float64
#  48  2019, Заёмные средства (краткосрочные), RUB                    3774 non-null   float64
#  49  2019, Кредиторская задолженность, RUB                          3774 non-null   float64
#  50  2019, Прочие краткосрочные обязательства, RUB                  3774 non-null   float64
#  51  2019, Краткосрочные обязательства, RUB                         3774 non-null   float64
#  52  2019, Пассивы всего, RUB                                       3774 non-null   float64
#  53  2019, Совокупный долг, RUB                                     3774 non-null   float64
#  54  2019, Собственный капитал, RUB                                 3774 non-null   float64
#  55  2019, Выручка, RUB                                             3774 non-null   float64
#  56  2019, Коммерческие расходы, RUB                                3774 non-null   float64
#  57  2019, Управленческие расходы, RUB                              3774 non-null   float64
#  58  2019, Прибыль (убыток) от продажи, RUB                         3774 non-null   float64
#  59  2019, Проценты к уплате, RUB                                   3774 non-null   float64
#  60  2019, Прочие расходы, RUB                                      3774 non-null   float64
#  61  2019, Чистая прибыль (убыток), RUB                             3774 non-null   float64
#  62  2019, Получение кредитов и займов, RUB                         3774 non-null   float64
#  63  2019, Погашение векселей, возврат кредитов и займов, RUB       3774 non-null   float64
#  64  БГ                                                             3774 non-null   float64
# dtypes: datetime64[ns](1), float64(61), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ## Подготовка данных для задачи по классификации на компании пользующиеся услугами лизинга

# %%
# Для удобства работы решил разбить данные на отдельные части для каждой задачи
# данные для предсказания наличи у компании лизинга
lg = data[['Дата регистрации',
           'Код статистики',          
           'Отрасль',     
           'Форма собственности',      
           'Налоговый режим',
           'Код причины постановки на учет',
           '2018, Налоги, RUB',
           '2018, Налог на имущество, RUB',
           '2018, Транспортный налог, RUB',
           '2018, Активы  всего, RUB',
           '2018, Выручка, RUB',
           '2018, Основные средства , RUB',
           '2019, Основные средства , RUB',
           '2019, Долгосрочные финансовые вложения, RUB',
           '2019, Отложенные налоговые активы, RUB',
           '2019, Внеоборотные активы, RUB',
           '2019, Чистые активы, RUB',
           '2019, Запасы, RUB',
           '2019, НДС по приобретенным ценностям , RUB',
           '2019, Дебиторская задолженность, RUB',
           '2019, Краткосрочные финансовые вложения, RUB',
           '2019, Денежные средства и денежные эквиваленты, RUB',
           '2019, Прочие оборотные активы, RUB',
           '2019, Оборотные активы, RUB',
           '2019, Активы  всего, RUB',
           '2019, Уставный капитал , RUB',
           '2019, Добавочный капитал, RUB',
           '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
           '2019, Капитал и резервы, RUB',
           '2019, Собственный оборотный капитал, RUB',
           '2019, Себестоимость продаж, RUB',
           '2019, Валовая прибыль (убыток), RUB',
           '2019, Проценты к получению, RUB',
           '2019, Прочие доходы, RUB',
           '2019, Прибыль (убыток) до налогообложения , RUB',
           '2019, Текущий налог на прибыль, RUB',
           '2019, EBIT, RUB',
           '2019, Поступления от текущих операций, RUB',
           '2019, Поступления от продаж, RUB',
           '2019, Платежи по текущим операциям, RUB',
           '2019, Платежи поставщикам и подрядчикам, RUB',
           '2019, Оплата процентов по долговым обязательствам, RUB',
           '2019, Налог на прибыль, RUB',
           '2019, Сальдо денежных потоков от текущих операций, RUB',
           '2019, Платежи по инвестиционным операциям, RUB',
           '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
           '2019, Поступления от финансовых операций, RUB',
           '2019, Платежи по финансовым операциям, RUB',
           '2019, Сальдо денежных потоков от финансовых операций, RUB',
           '2019, Сальдо денежных потоков за отчетный период, RUB',
           '2019, Поступление денежных средств всего, RUB',
           '2019, Заёмные средства (долгосрочные), RUB',             
           '2019, Прочие долгосрочные обязательства, RUB',             
           '2019, Долгосрочные обязательства, RUB',             
           '2019, Заёмные средства (краткосрочные), RUB',             
           '2019, Кредиторская задолженность, RUB',             
           '2019, Прочие краткосрочные обязательства, RUB',            
           '2019, Краткосрочные обязательства, RUB',            
           '2019, Пассивы всего, RUB',          
           '2019, Совокупный долг, RUB',             
           '2019, Собственный капитал, RUB',            
           '2019, Выручка, RUB',             
           '2019, Коммерческие расходы, RUB',            
           '2019, Управленческие расходы, RUB',            
           '2019, Прибыль (убыток) от продажи, RUB',             
           '2019, Проценты к уплате, RUB',            
           '2019, Прочие расходы, RUB',            
           '2019, Чистая прибыль (убыток), RUB',           
           '2019, Получение кредитов и займов, RUB',             
           '2019, Погашение векселей, возврат кредитов и займов, RUB',            
           'Лизинг'
          ]].copy()

# %%
pd.isnull(lg).sum() #анализируем количество пропусков после частичного заполнения данных нулевыми значениями
# Out:
# Дата регистрации                                               17
# Код статистики                                                 57
# Отрасль                                                         0
# Форма собственности                                            41
# Налоговый режим                                              4482
#                                                             ...
# 2019, Прочие расходы, RUB                                    6849
# 2019, Чистая прибыль (убыток), RUB                           6196
# 2019, Получение кредитов и займов, RUB                      11868
# 2019, Погашение векселей, возврат кредитов и займов, RUB    11925
# Лизинг                                                          0
# Length: 71, dtype: int64

# %%
# обработка пропусков
# так как большая часть данных это финансовые показатели, то предположим что пропущенное значение эквивалентно нулю
lg[['2018, Налоги, RUB',
    '2018, Основные средства , RUB',
    '2018, Налог на имущество, RUB',
    '2018, Транспортный налог, RUB',         
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]] = lg[[
    '2018, Налоги, RUB',
    '2018, Основные средства , RUB',
    '2018, Налог на имущество, RUB',
    '2018, Транспортный налог, RUB',         
    '2019, Заёмные средства (долгосрочные), RUB',
    '2019, Прочие долгосрочные обязательства, RUB',
    '2019, Долгосрочные обязательства, RUB',
    '2019, Заёмные средства (краткосрочные), RUB',
    '2019, Кредиторская задолженность, RUB',
    '2019, Прочие краткосрочные обязательства, RUB',
    '2019, Краткосрочные обязательства, RUB',
    '2019, Совокупный долг, RUB',
    '2019, Коммерческие расходы, RUB',
    '2019, Управленческие расходы, RUB',
    '2019, Прибыль (убыток) от продажи, RUB',
    '2019, Проценты к уплате, RUB',
    '2019, Прочие расходы, RUB',
    '2019, Получение кредитов и займов, RUB',
    '2019, Погашение векселей, возврат кредитов и займов, RUB',
    '2019, Основные средства , RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Долгосрочные финансовые вложения, RUB',
    '2019, Отложенные налоговые активы, RUB',
    '2019, Внеоборотные активы, RUB',
    '2019, Чистые активы, RUB',
    '2019, Запасы, RUB',
    '2019, НДС по приобретенным ценностям , RUB',
    '2019, Дебиторская задолженность, RUB',
    '2019, Краткосрочные финансовые вложения, RUB',
    '2019, Денежные средства и денежные эквиваленты, RUB',
    '2019, Прочие оборотные активы, RUB',
    '2019, Оборотные активы, RUB',
    '2019, Активы  всего, RUB',
    '2019, Уставный капитал , RUB',
    '2019, Добавочный капитал, RUB',
    '2019, Нераспределенная прибыль (непокрытый убыток), RUB',
    '2019, Капитал и резервы, RUB',
    '2019, Собственный оборотный капитал, RUB',
    '2019, Себестоимость продаж, RUB',
    '2019, Валовая прибыль (убыток), RUB',
    '2019, Проценты к получению, RUB',
    '2019, Прочие доходы, RUB',
    '2019, Прибыль (убыток) до налогообложения , RUB',
    '2019, Текущий налог на прибыль, RUB',
    '2019, EBIT, RUB',
    '2019, Поступления от текущих операций, RUB',
    '2019, Поступления от продаж, RUB',
    '2019, Платежи по текущим операциям, RUB',
    '2019, Платежи поставщикам и подрядчикам, RUB',
    '2019, Оплата процентов по долговым обязательствам, RUB',
    '2019, Налог на прибыль, RUB',
    '2019, Сальдо денежных потоков от текущих операций, RUB',
    '2019, Платежи по инвестиционным операциям, RUB',
    '2019, Сальдо денежных потоков от инвестиционных операций, RUB',
    '2019, Поступления от финансовых операций, RUB',
    '2019, Платежи по финансовым операциям, RUB',
    '2019, Сальдо денежных потоков от финансовых операций, RUB',
    '2019, Сальдо денежных потоков за отчетный период, RUB',
    '2019, Поступление денежных средств всего, RUB'
]].fillna(0)

# %%
lg = lg.dropna() #удаляем пропущенные значения

# %%
lg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3216 entries, 4283790 to 5297219
# Data columns (total 71 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Дата регистрации                                               3216 non-null   datetime64[ns]
#  1   Код статистики                                                 3216 non-null   float64
#  2   Отрасль                                                        3216 non-null   object
#  3   Форма собственности                                            3216 non-null   object
#  4   Налоговый режим                                                3216 non-null   object
#  5   Код причины постановки на учет                                 3216 non-null   float64
#  6   2018, Налоги, RUB                                              3216 non-null   float64
#  7   2018, Налог на имущество, RUB                                  3216 non-null   float64
#  8   2018, Транспортный налог, RUB                                  3216 non-null   float64
#  9   2018, Активы  всего, RUB                                       3216 non-null   float64
#  10  2018, Выручка, RUB                                             3216 non-null   float64
#  11  2018, Основные средства , RUB                                  3216 non-null   float64
#  12  2019, Основные средства , RUB                                  3216 non-null   float64
#  13  2019, Долгосрочные финансовые вложения, RUB                    3216 non-null   float64
#  14  2019, Отложенные налоговые активы, RUB                         3216 non-null   float64
#  15  2019, Внеоборотные активы, RUB                                 3216 non-null   float64
#  16  2019, Чистые активы, RUB                                       3216 non-null   float64
#  17  2019, Запасы, RUB                                              3216 non-null   float64
#  18  2019, НДС по приобретенным ценностям , RUB                     3216 non-null   float64
#  19  2019, Дебиторская задолженность, RUB                           3216 non-null   float64
#  20  2019, Краткосрочные финансовые вложения, RUB                   3216 non-null   float64
#  21  2019, Денежные средства и денежные эквиваленты, RUB            3216 non-null   float64
#  22  2019, Прочие оборотные активы, RUB                             3216 non-null   float64
#  23  2019, Оборотные активы, RUB                                    3216 non-null   float64
#  24  2019, Активы  всего, RUB                                       3216 non-null   float64
#  25  2019, Уставный капитал , RUB                                   3216 non-null   float64
#  26  2019, Добавочный капитал, RUB                                  3216 non-null   float64
#  27  2019, Нераспределенная прибыль (непокрытый убыток), RUB        3216 non-null   float64
#  28  2019, Капитал и резервы, RUB                                   3216 non-null   float64
#  29  2019, Собственный оборотный капитал, RUB                       3216 non-null   float64
#  30  2019, Себестоимость продаж, RUB                                3216 non-null   float64
#  31  2019, Валовая прибыль (убыток), RUB                            3216 non-null   float64
#  32  2019, Проценты к получению, RUB                                3216 non-null   float64
#  33  2019, Прочие доходы, RUB                                       3216 non-null   float64
#  34  2019, Прибыль (убыток) до налогообложения , RUB                3216 non-null   float64
#  35  2019, Текущий налог на прибыль, RUB                            3216 non-null   float64
#  36  2019, EBIT, RUB                                                3216 non-null   float64
#  37  2019, Поступления от текущих операций, RUB                     3216 non-null   float64
#  38  2019, Поступления от продаж, RUB                               3216 non-null   float64
#  39  2019, Платежи по текущим операциям, RUB                        3216 non-null   float64
#  40  2019, Платежи поставщикам и подрядчикам, RUB                   3216 non-null   float64
#  41  2019, Оплата процентов по долговым обязательствам, RUB         3216 non-null   float64
#  42  2019, Налог на прибыль, RUB                                    3216 non-null   float64
#  43  2019, Сальдо денежных потоков от текущих операций, RUB         3216 non-null   float64
#  44  2019, Платежи по инвестиционным операциям, RUB                 3216 non-null   float64
#  45  2019, Сальдо денежных потоков от инвестиционных операций, RUB  3216 non-null   float64
#  46  2019, Поступления от финансовых операций, RUB                  3216 non-null   float64
#  47  2019, Платежи по финансовым операциям, RUB                     3216 non-null   float64
#  48  2019, Сальдо денежных потоков от финансовых операций, RUB      3216 non-null   float64
#  49  2019, Сальдо денежных потоков за отчетный период, RUB          3216 non-null   float64
#  50  2019, Поступление денежных средств всего, RUB                  3216 non-null   float64
#  51  2019, Заёмные средства (долгосрочные), RUB                     3216 non-null   float64
#  52  2019, Прочие долгосрочные обязательства, RUB                   3216 non-null   float64
#  53  2019, Долгосрочные обязательства, RUB                          3216 non-null   float64
#  54  2019, Заёмные средства (краткосрочные), RUB                    3216 non-null   float64
#  55  2019, Кредиторская задолженность, RUB                          3216 non-null   float64
#  56  2019, Прочие краткосрочные обязательства, RUB                  3216 non-null   float64
#  57  2019, Краткосрочные обязательства, RUB                         3216 non-null   float64
#  58  2019, Пассивы всего, RUB                                       3216 non-null   float64
#  59  2019, Совокупный долг, RUB                                     3216 non-null   float64
#  60  2019, Собственный капитал, RUB                                 3216 non-null   float64
#  61  2019, Выручка, RUB                                             3216 non-null   float64
#  62  2019, Коммерческие расходы, RUB                                3216 non-null   float64
#  63  2019, Управленческие расходы, RUB                              3216 non-null   float64
#  64  2019, Прибыль (убыток) от продажи, RUB                         3216 non-null   float64
#  65  2019, Проценты к уплате, RUB                                   3216 non-null   float64
#  66  2019, Прочие расходы, RUB                                      3216 non-null   float64
#  67  2019, Чистая прибыль (убыток), RUB                             3216 non-null   float64
#  68  2019, Получение кредитов и займов, RUB                         3216 non-null   float64
#  69  2019, Погашение векселей, возврат кредитов и займов, RUB       3216 non-null   float64
#  70  Лизинг                                                         3216 non-null   float64
# dtypes: datetime64[ns](1), float64(67), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# #  Задача 1

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 1

# %% [markdown]
# Задача поиска потенциальных клиентов для банка с целью продажи услуги "Зарплатный проект"(суть услуги -компания заключает с банком договор по которому заработная плата выплачивается на банковские карты данного банка). Для банка данный сервис интересен как минимум по 2 причинам: получение новых клиентов -физических лиц(держателей карт, сотрудников компаний), получение доходов от услуги(коммисионные платежи, доходы от пассивов).
# Необходимо построить модель по предсказанию объемов фонда оплаты труда(ФОТ)

# %%
zp.head()
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 889841         1998-07-01      48748392.0  Производство
# 11837132       2018-03-05      26713625.0  Производство
# 4061478        2001-05-17      56107052.0  Производство
# 9259386        2014-04-07      32759979.0  Производство
# 8699220        2013-01-17      16646709.0  Производство
#
#             Форма собственности Налоговый режим  2018, Доходы, RUB  \
# ID
# 889841    Частная собственность             УСН         73499000.0
# 11837132  Частная собственность             УСН           161000.0
# 4061478   Частная собственность             УСН         39984000.0
# 9259386   Частная собственность             УСН         10374000.0
# 8699220   Частная собственность             УСН          4919000.0
#
#           2018, Расходы, RUB  2018, Налоги, RUB  \
# ID
# 889841            69853000.0          1437425.0
# 11837132           2140000.0           131775.0
# 4061478           47328000.0          1453480.0
# 9259386            4453000.0           705754.0
# 8699220            4192000.0           222746.0
#
#           2018, Страховые взносы в ПФР, RUB  \
# ID
# 889841                             863696.0
# 11837132                            96976.0
# 4061478                            694124.0
# 9259386                            158791.0
# 8699220                            129314.0
#
#           2018, Страховые взносы в ФОМС, RUB  \
# ID
# 889841                              200551.0
# 11837132                             22481.0
# 4061478                             160911.0
# 9259386                              35945.0
# 8699220                              29977.0
#
#           2018, Страховые взносы в ФСС, RUB  2018, Активы  всего, RUB  \
# ID
# 889841                             113900.0               173043000.0
# 11837132                            12318.0                   96000.0
# 4061478                             91498.0                40077000.0
# 9259386                             20932.0                 7704000.0
# 8699220                             16965.0                 2441000.0
#
#           2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# ID
# 889841                        23437000.0          70617000.0
# 11837132                      -1972000.0            160000.0
# 4061478                       34713000.0          38949000.0
# 9259386                        7490000.0          10234000.0
# 8699220                         973000.0           4917000.0
#
#           2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# ID
# 889841                            1520000.0                  3378000.0
# 11837132                                0.0                    43000.0
# 4061478                           4197000.0                  6781000.0
# 9259386                                 0.0                   268000.0
# 8699220                                 0.0                   110000.0
#
#           2018, Чистая прибыль (убыток), RUB  \
# ID
# 889841                             2710000.0
# 11837132                          -1981000.0
# 4061478                           -7718000.0
# 9259386                            5516000.0
# 8699220                             684000.0
#
#           2018, Среднесписочная численность работников     2018, ФОТ
# ID
# 889841                                            30.0  3.033000e+06
# 11837132                                           4.0  1.622705e+06
# 4061478                                           20.0  2.611000e+06
# 9259386                                            8.0  3.245411e+06
# 8699220                                            6.0  2.434058e+06

# %%
zp.describe()
# Out:
#        Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count    2.329000e+03       2.329000e+03        2.329000e+03
# mean     4.744277e+07       2.674662e+07        2.395457e+07
# std      2.943254e+07       5.260392e+07        4.847739e+07
# min      4.716000e+04       7.000000e+03        1.100000e+04
# 25%      2.288334e+07       2.600000e+06        2.372000e+06
# 50%      3.961997e+07       9.107000e+06        8.239000e+06
# 75%      7.371489e+07       2.957000e+07        2.673200e+07
# max      9.889218e+07       9.741350e+08        9.114010e+08
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       2.329000e+03                       2.329000e+03
# mean        8.416640e+05                       3.091735e+05
# std         1.704217e+06                       6.931296e+05
# min         1.125000e+03                       7.700000e+02
# 25%         1.109000e+05                       3.168000e+04
# 50%         2.874400e+05                       9.201700e+04
# 75%         8.352720e+05                       2.632840e+05
# max         1.965756e+07                       8.624314e+06
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        2.329000e+03                       2.329000e+03
# mean                         7.033305e+04                       3.987860e+04
# std                          1.727410e+05                       9.773644e+04
# min                          0.000000e+00                       0.000000e+00
# 25%                          7.140000e+03                       4.060000e+03
# 50%                          2.024700e+04                       1.151300e+04
# 75%                          5.806300e+04                       3.303300e+04
# max                          3.433002e+06                       1.948714e+06
#
#        2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# count              2.329000e+03                    2.329000e+03
# mean               2.712576e+07                    1.007499e+07
# std                1.053201e+08                    2.863169e+07
# min                1.000000e+03                   -1.573660e+08
# 25%                1.482000e+06                    1.590000e+05
# 50%                5.978000e+06                    2.053000e+06
# 75%                2.287100e+07                    9.866000e+06
# max                4.131432e+09                    3.879670e+08
#
#        2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# count        2.329000e+03                       2.329000e+03
# mean         2.480086e+07                       7.900614e+05
# std          4.900495e+07                       4.937101e+06
# min          4.000000e+03                       0.000000e+00
# 25%          2.466000e+06                       0.000000e+00
# 50%          8.385000e+06                       0.000000e+00
# 75%          2.707200e+07                       0.000000e+00
# max          9.158050e+08                       7.983300e+07
#
#        2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# count               2.329000e+03                        2.329000e+03
# mean                2.348637e+06                        2.497702e+06
# std                 8.945511e+06                        1.122827e+07
# min                -4.800000e+04                       -1.078890e+08
# 25%                 4.000000e+04                       -5.100000e+04
# 50%                 1.600000e+05                        3.590000e+05
# 75%                 9.610000e+05                        2.190000e+06
# max                 1.448910e+08                        1.856900e+08
#
#        2018, Среднесписочная численность работников     2018, ФОТ
# count                                   2329.000000  2.329000e+03
# mean                                       6.864319  2.688451e+06
# std                                       11.272307  4.410553e+06
# min                                        1.000000  1.200000e+04
# 25%                                        1.000000  4.056763e+05
# 50%                                        3.000000  1.217029e+06
# 75%                                        7.000000  2.839734e+06
# max                                       89.000000  3.448249e+07

# %%
zp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 889841 to 5297219
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Дата регистрации                              2329 non-null   datetime64[ns]
#  1   Код статистики                                2329 non-null   float64
#  2   Отрасль                                       2329 non-null   object
#  3   Форма собственности                           2329 non-null   object
#  4   Налоговый режим                               2329 non-null   object
#  5   2018, Доходы, RUB                             2329 non-null   float64
#  6   2018, Расходы, RUB                            2329 non-null   float64
#  7   2018, Налоги, RUB                             2329 non-null   float64
#  8   2018, Страховые взносы в ПФР, RUB             2329 non-null   float64
#  9   2018, Страховые взносы в ФОМС, RUB            2329 non-null   float64
#  10  2018, Страховые взносы в ФСС, RUB             2329 non-null   float64
#  11  2018, Активы  всего, RUB                      2329 non-null   float64
#  12  2018, Собственный капитал, RUB                2329 non-null   float64
#  13  2018, Выручка, RUB                            2329 non-null   float64
#  14  2018, Управленческие расходы, RUB             2329 non-null   float64
#  15  2018, Прочие расходы, RUB                     2329 non-null   float64
#  16  2018, Чистая прибыль (убыток), RUB            2329 non-null   float64
#  17  2018, Среднесписочная численность работников  2329 non-null   float64
#  18  2018, ФОТ                                     2329 non-null   float64
# dtypes: datetime64[ns](1), float64(15), object(3)
# memory usage: 363.9+ KB

# %% [markdown]
# # Задача 2

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 2

# %% [markdown]
# Задача поиска потенциальных клиентов для банка для привлечения на услуги "Зарплатный проект" и услуги по страхованию сотрудников.
# Суть услуги "Зарплатный роект"- компания заключает с банком договор по которому заработная плата выплачивается на банковские карты данного банка). Для банка данный сервис интересен как минимум по 2 причинам: получение новых клиентов -физических лиц(держателей карт, сотрудников компаний), получение доходов от услуги(коммисионные платежи, доходы от пассивов).
# Под услугами страхования в данной задаче подразумеваются услуги корплративного страхования, такие как Добровольное медицинское страхование, страхование от несчастных случаев и болезней.
# Необходимо построить модель по предсказанию среднесписочной численности работников

# %%
zp.head()
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 889841         1998-07-01      48748392.0  Производство
# 11837132       2018-03-05      26713625.0  Производство
# 4061478        2001-05-17      56107052.0  Производство
# 9259386        2014-04-07      32759979.0  Производство
# 8699220        2013-01-17      16646709.0  Производство
#
#             Форма собственности Налоговый режим  2018, Доходы, RUB  \
# ID
# 889841    Частная собственность             УСН         73499000.0
# 11837132  Частная собственность             УСН           161000.0
# 4061478   Частная собственность             УСН         39984000.0
# 9259386   Частная собственность             УСН         10374000.0
# 8699220   Частная собственность             УСН          4919000.0
#
#           2018, Расходы, RUB  2018, Налоги, RUB  \
# ID
# 889841            69853000.0          1437425.0
# 11837132           2140000.0           131775.0
# 4061478           47328000.0          1453480.0
# 9259386            4453000.0           705754.0
# 8699220            4192000.0           222746.0
#
#           2018, Страховые взносы в ПФР, RUB  \
# ID
# 889841                             863696.0
# 11837132                            96976.0
# 4061478                            694124.0
# 9259386                            158791.0
# 8699220                            129314.0
#
#           2018, Страховые взносы в ФОМС, RUB  \
# ID
# 889841                              200551.0
# 11837132                             22481.0
# 4061478                             160911.0
# 9259386                              35945.0
# 8699220                              29977.0
#
#           2018, Страховые взносы в ФСС, RUB  2018, Активы  всего, RUB  \
# ID
# 889841                             113900.0               173043000.0
# 11837132                            12318.0                   96000.0
# 4061478                             91498.0                40077000.0
# 9259386                             20932.0                 7704000.0
# 8699220                             16965.0                 2441000.0
#
#           2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# ID
# 889841                        23437000.0          70617000.0
# 11837132                      -1972000.0            160000.0
# 4061478                       34713000.0          38949000.0
# 9259386                        7490000.0          10234000.0
# 8699220                         973000.0           4917000.0
#
#           2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# ID
# 889841                            1520000.0                  3378000.0
# 11837132                                0.0                    43000.0
# 4061478                           4197000.0                  6781000.0
# 9259386                                 0.0                   268000.0
# 8699220                                 0.0                   110000.0
#
#           2018, Чистая прибыль (убыток), RUB  \
# ID
# 889841                             2710000.0
# 11837132                          -1981000.0
# 4061478                           -7718000.0
# 9259386                            5516000.0
# 8699220                             684000.0
#
#           2018, Среднесписочная численность работников     2018, ФОТ
# ID
# 889841                                            30.0  3.033000e+06
# 11837132                                           4.0  1.622705e+06
# 4061478                                           20.0  2.611000e+06
# 9259386                                            8.0  3.245411e+06
# 8699220                                            6.0  2.434058e+06

# %% [markdown]
# ## Решение

# %%
#удалим ФОТ -целевая переменная в другой задаче
del zp['2018, ФОТ']

# %%
zp['Дата регистрации'] = zp['Дата регистрации'].dt.year

# %%
#выведем информацию о количестве данных
zp.shape
# Out:
# (2329, 18)

# %%
#получим иформацию о данных
zp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 889841 to 5297219
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Дата регистрации                              2329 non-null   int64
#  1   Код статистики                                2329 non-null   float64
#  2   Отрасль                                       2329 non-null   object
#  3   Форма собственности                           2329 non-null   object
#  4   Налоговый режим                               2329 non-null   object
#  5   2018, Доходы, RUB                             2329 non-null   float64
#  6   2018, Расходы, RUB                            2329 non-null   float64
#  7   2018, Налоги, RUB                             2329 non-null   float64
#  8   2018, Страховые взносы в ПФР, RUB             2329 non-null   float64
#  9   2018, Страховые взносы в ФОМС, RUB            2329 non-null   float64
#  10  2018, Страховые взносы в ФСС, RUB             2329 non-null   float64
#  11  2018, Активы  всего, RUB                      2329 non-null   float64
#  12  2018, Собственный капитал, RUB                2329 non-null   float64
#  13  2018, Выручка, RUB                            2329 non-null   float64
#  14  2018, Управленческие расходы, RUB             2329 non-null   float64
#  15  2018, Прочие расходы, RUB                     2329 non-null   float64
#  16  2018, Чистая прибыль (убыток), RUB            2329 non-null   float64
#  17  2018, Среднесписочная численность работников  2329 non-null   float64
# dtypes: float64(14), int64(1), object(3)
# memory usage: 345.7+ KB

# %%
'''
#проверим тип данных целефой переменной
zp["2018, Среднесписочная численность работников"].dtypes
#преобразуем его в число
zp["2018, Среднесписочная численность работников"] = zp["2018, Среднесписочная численность работников"].astype(int)
'''
# Out:
# '\n#проверим тип данных целефой переменной\nzp["2018, Среднесписочная численность работников"].dtypes\n#преобразуем его в число\nzp["2018, Среднесписочная численность работников"] = zp["2018, Среднесписочная численность работников"].astype(int)\n'

# %%
#выведем информацию о количестве столбцов в разрезе типов данных
zp.dtypes.value_counts()
# Out:
# float64    14
# object      3
# int64       1
# dtype: int64

# %%
zp.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# Отрасль                5
# Форма собственности    8
# Налоговый режим        3
# dtype: int64

# %%
# one-hot encoding категориальных признаков
zp = pd.get_dummies(zp)
print('Размер данных: ', zp.shape)
# Out:
# Размер данных:  (2329, 31)

# %%
zp.hist(figsize=(20, 30), layout=(11,3), bins=30)
margin = 0.5

# %%
#построим матрицу корреляции
plt.subplots(figsize=(10,10))
sns.heatmap(zp.corr(), square=True)
plt.show()

# %%
#отобразим зависимость численности сотрудников от взносов в ФОМС
zp.plot(x='2018, Страховые взносы в ФОМС, RUB', y='2018, Среднесписочная численность работников', style='o')  
plt.title('Взносы в ФОМС vs Численность')  
plt.xlabel('Взносы в ФОМС')  
plt.ylabel('Численность')  
plt.show()

# %%
#отобразим зависимость численности сотрудников от взносов в ФОМС
zp.plot(x='2018, Страховые взносы в ПФР, RUB', y='2018, Среднесписочная численность работников', style='o')  
plt.title('Взносы в ФОМС vs Численность')  
plt.xlabel('Взносы в ФОМС')  
plt.ylabel('Численность')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
sns.distplot(zp["2018, Среднесписочная численность работников"])
print('Среднее количество сотрудников: ', zp["2018, Среднесписочная численность работников"].mean().round(), ' человек')
# Out:
# Среднее количество сотрудников:  7.0  человек

# %%
print('Среднее количество сотрудников: ', zp["2018, Среднесписочная численность работников"].mean().round())
print('Мода по значениям целевой переменной: ', zp["2018, Среднесписочная численность работников"].mode().values[0])
print('Медиана по значениям целевой переменной: ', zp["2018, Среднесписочная численность работников"].sort_values().median())
# Out:
# Среднее количество сотрудников:  7.0
# Мода по значениям целевой переменной:  1.0
# Медиана по значениям целевой переменной:  3.0

# %%
#Вывожу статистику по целевой переменной
plt.figure(figsize=(20,5))
sns.barplot(zp["2018, Среднесписочная численность работников"].value_counts().index, zp["2018, Среднесписочная численность работников"].value_counts().values)

# %%
zp["2018, Среднесписочная численность работников"]
# Out:
# ID
# 889841      30.0
# 11837132     4.0
# 4061478     20.0
# 9259386      8.0
# 8699220      6.0
#             ...
# 10538847    14.0
# 10826263     1.0
# 6404614      2.0
# 8538016      2.0
# 5297219      2.0
# Name: 2018, Среднесписочная численность работников, Length: 2329, dtype: float64

# %%
#для сглаживания данных применяю логарифмирование целевой переменной
y = np.log(zp["2018, Среднесписочная численность работников"])

# %%
X = zp.copy().drop(["2018, Среднесписочная численность работников"], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
import sklearn.linear_model as lm

# %%
# создаем пустую модель
skm = lm.LinearRegression(normalize = True)
# запускаем расчет параметров для указанных данных
skm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)

# %%
# создаем пустую модель
skm = lm.LinearRegression()
# запускаем расчет параметров для указанных данных
skm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coeff_df = pd.DataFrame(skm.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#                                                      Coefficient
# Дата регистрации                                   -1.501830e-02
# Код статистики                                      6.260738e-10
# 2018, Доходы, RUB                                  -2.149954e-08
# 2018, Расходы, RUB                                  9.846622e-09
# 2018, Налоги, RUB                                   3.757994e-08
# 2018, Страховые взносы в ПФР, RUB                   1.122373e-06
# 2018, Страховые взносы в ФОМС, RUB                 -2.955572e-06
# 2018, Страховые взносы в ФСС, RUB                   3.002550e-06
# 2018, Активы  всего, RUB                           -1.106163e-10
# 2018, Собственный капитал, RUB                      3.403479e-10
# 2018, Выручка, RUB                                  1.438859e-08
# 2018, Управленческие расходы, RUB                   6.880313e-09
# 2018, Прочие расходы, RUB                           1.581348e-08
# 2018, Чистая прибыль (убыток), RUB                  1.398445e-08
# Отрасль_Производство                                1.362685e-01
# Отрасль_Строительство                               4.514956e-03
# Отрасль_Торговля                                   -1.412957e-01
# Отрасль_Транспорт                                  -2.955617e-02
# Отрасль_Услуги                                      3.006837e-02
# Форма собственности_Иная смешанная российская с...  1.278117e-01
# Форма собственности_Муниципальная собственность     3.501682e-02
# Форма собственности_Смешанная иностранная собст... -3.369621e-01
# Форма собственности_Собственность иностранных г... -1.238271e-01
# Форма собственности_Собственность общественных ... -5.042464e-01
# Форма собственности_Совместная частная и иностр...  1.093179e-01
# Форма собственности_Федеральная собственность       6.976104e-01
# Форма собственности_Частная собственность          -4.721259e-03
# Налоговый режим_ЕНВД                                1.657357e-02
# Налоговый режим_УСН                                -2.434658e-01
# Налоговый режим_УСН, ЕНВД                           2.268923e-01

# %%
#получаем результаты предсказания
y_pred = skm.predict(X_test)

# %%
pred=np.exp(y_pred).astype(int)
pred
# Out:
# array([   11,     3,    21,     3,     3,     1,     5,     2,     1,
#            2,     4,     2,     4,     2,     2,     3,     2,     2,
#            4,     9,     3,     1,     1,     4,     4,     2,     1,
#            4,     2,     2,     2,     3,     4,     1,     3,    11,
#            2,     3,    10,     2,     3,     2,     1,     2,     3,
#            6,     2,     4,     2,     2,     2,    61,     1,     6,
#            3,     6,     3,     1,     2,     2,     2,    19,     2,
#            2,     3,     6,     2,     6,     2,    24,     6,     4,
#            2,     3,     1,     2,     3,     2,     4,     1,     3,
#            3,     1,     2,     2,     2,     3,     1,     2,     2,
#            2,     5,     2,     2,     2,     2,     1,     2,     3,
#            2,     7,     2,     1,    12,     2,     2,     2,     2,
#            2,     2,     2,     2,     3,     1,     4,     2,     3,
#            4,     3,     3,     5,     1,     1,     2,     2,     4,
#            2,     3,     2,     5,     2,     3,     2,     2,     2,
#            2,     2,     2,     2,     3,     3,     2,     2,     9,
#            1,     2,     3,     2,     2,     4,     1,     4,    23,
#            3,     1,     7,     4,     2,     4,     2,     2,     3,
#            3,     3,     3,     2,     2,     2,     1,     3,     2,
#            2,     2,     2,     4,     3,     1,     5,    76,     2,
#            1,     2,     3,    17,     2,     2,     2,     4,     3,
#            3,     2,     4,     1,     2,     2,     6,     2,     1,
#            1,     1,     2,     3,     2,     2,     3,     2,     2,
#            2,     2,     2,     3,     2,     3,     5,     2,     2,
#            2,     2,     3,    14,     3,     3,     2,     2,    14,
#            1,     3,     2,     3,     7,     4,     2,     2,     4,
#            2,     2,     2,     9,     3,     2,     5,     8,     2,
#            3,     4,     2,     1,     1,     2,     2,     4,     1,
#            2,     1,     3,     2,     1,     3,     2,     3,     5,
#            4,     3,     2,     2,     3,     5,     4,     2,     4,
#            3,     2,     1,     2,     3,     2,     3,     3,     3,
#            5,     2,     2,     1,     3,     2,     1,     1,     1,
#            2,     4,     4,     8,     2,     2,     2,     2,    20,
#            1,     2,     2,     2,     2,     7,     1,    11,     2,
#            2,    10,     1,     2,     2,     2,     1,     2,     2,
#            3,     2,     1,     2,     4,     2,     2,     2,     2,
#            7,     1,     3,     2,     2,     5,     2,     3,     3,
#            4,     3,     2,     2,    10,     1,     6,     6,     2,
#            2,   467,     4,     3,     2,    21,     4,     3,     1,
#            2,     2,     2,     3,     2,     3,     3,     4,     1,
#            4,     2,     3,     2,     2,     4,     2,     3,     2,
#        10348,     5,     1,     2,     2,     2,     4,     4,     1,
#            2,     2,     3,     3,     2,     3,     4,     3,     2,
#            8,     3,     2,     2,    38,     6,     2,     3,     8,
#            3,     2,     2,     1,     2,     2,     3,     2,     2,
#            2,     6,     3,     2,     2,     3,     1,     5,     3,
#            4,     3,     2,     1,     1,     4,     3,     2,     2,
#            1,     2,     2,     3,     2,    22,     2,    99,     5,
#            3,     3,     2,     2,     1,     2,     1,     2,     3,
#            2,     4,     6,     5,     1,     1,     3,     5,     5,
#            2,     2,     3,     5,     3,     2,     3,     2,     2,
#            2,     2,    17,     2,     2,     2,     4])

# %%
#сравним фактические данные с результатами предсказания
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(25)
df1
# Out:
#             Actual  Predicted
# ID
# 4865203   3.295837   2.440023
# 9568761   0.000000   1.129148
# 5049668   2.995732   3.068181
# 4281502   0.000000   1.298771
# 4288710   2.079442   1.205206
# 8956688   0.000000   0.631167
# 10196572  2.397895   1.632474
# 8812623   0.000000   0.713442
# 9858920   0.693147   0.572833
# 5926999   0.000000   0.695199
# 2064816   2.302585   1.406104
# 5925631   1.791759   0.961799
# 1565205   0.000000   1.406449
# 2291881   0.000000   0.940980
# 4283782   0.693147   1.031213
# 4044996   2.197225   1.183135
# 1131736   0.693147   0.955435
# 5926773   1.098612   1.042352
# 53667     2.944439   1.558088
# 6935494   3.555348   2.280042
# 937446    1.386294   1.295965
# 10740009  0.000000   0.649667
# 11982874  0.693147   0.495588
# 8518247   2.079442   1.387223
# 10597103  3.332205   1.495208

# %%
#построим график по результатам предсказания(сравнение фактических данных с предсказанными)
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn import metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.6614862313393068
# Mean Squared Error: 0.6625911895214955
# Root Mean Squared Error: 0.8139970451552607

# %% [markdown]
# # Задача 3

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3774 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о  финансовых показателях компани за 2019 год.

# %%
#to do: добавить ссылки с описанием фин показателей

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Задача поиска потенциалных клиентов банка для привлечение на услуги кредитование и имущественное страхование.
# Необходимо построить модель по предсказанию наличия действующего договора залога.
# Логика задачи: если компания предоставляла что-то в залог по кредитованию, то можно сделать вывод что в компании есть практика использования заёмных средств и они пользуются кредитами(потенциал по сотрудничеству в будущем либо по рефинансированию кредита). Данные клиенты интересны банку для кредитования поскольку у них имеется имущество, которое они предоставляют в залог (т. е. это потенциальные клиенты, которые готовы минимизировать риски банка, предоставив залог по кредиту).
# Дополнительно результаты этой модели могут быть использованы для привлечения новых корпоративных клиентов на сервисы страхования имущества(компания преоставляет залог, в 90% случаев этот залог необходимо страховать)

# %%
cred.head(3)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 10527024       2016-04-07       1811746.0  Производство
# 11837132       2018-03-05      26713625.0  Производство
#
#             Форма собственности Налоговый режим  \
# ID
# 4283790   Частная собственность             УСН
# 10527024  Частная собственность             УСН
# 11837132  Частная собственность             УСН
#
#           Код причины постановки на учет  2019, Основные средства , RUB  \
# ID
# 4283790                      390601001.0                       651000.0
# 10527024                     390601001.0                        36000.0
# 11837132                     390601001.0                            0.0
#
#           2019, Долгосрочные финансовые вложения, RUB  \
# ID
# 4283790                                           0.0
# 10527024                                          0.0
# 11837132                                          0.0
#
#           2019, Отложенные налоговые активы, RUB  \
# ID
# 4283790                                      0.0
# 10527024                                     0.0
# 11837132                                     0.0
#
#           2019, Внеоборотные активы, RUB  ...  2019, Выручка, RUB  \
# ID                                        ...
# 4283790                         651000.0  ...            909000.0
# 10527024                             0.0  ...            366000.0
# 11837132                             0.0  ...           7348000.0
#
#           2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# ID
# 4283790                               0.0                            47000.0
# 10527024                              0.0                                0.0
# 11837132                              0.0                                0.0
#
#           2019, Прибыль (убыток) от продажи, RUB  \
# ID
# 4283790                                -320000.0
# 10527024                               -854000.0
# 11837132                               1006000.0
#
#           2019, Проценты к уплате, RUB  2019, Прочие расходы, RUB  \
# ID
# 4283790                            0.0                    47000.0
# 10527024                           0.0                    20000.0
# 11837132                           0.0                    27000.0
#
#           2019, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                            -365000.0
# 10527024                           -874000.0
# 11837132                            922000.0
#
#           2019, Получение кредитов и займов, RUB  \
# ID
# 4283790                                      0.0
# 10527024                                     0.0
# 11837132                                     0.0
#
#           2019, Погашение векселей, возврат кредитов и займов, RUB  Залоги
# ID
# 4283790                                                 0.0            0.0
# 10527024                                                0.0            0.0
# 11837132                                                0.0            0.0
#
# [3 rows x 65 columns]

# %%
#проверяем насколько сбалансированны данные
print(cred["Залоги"].value_counts())
sns.barplot(cred["Залоги"].value_counts().index, cred["Залоги"].value_counts().values)
# Out:
# 0.0    3585
# 1.0     189
# Name: Залоги, dtype: int64

# %% [markdown]
# # Задача 4

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3774 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о финансовых показателях компани за 2019 год.

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Задача поиска потенциальных клиентов банка для реализации услуг по продаже банковских гарантий.
#
# Суть услуги "Банковская гарантия" - банк проводит проверку своего клиента (ЮЛ либо ИП) и предоставляет за него "поручительство" перед его контрагентом. Существует много видов гарантий, наиболее распространены гарантии исполнения обязательств по договору по которым банк гарантирует что его клиент выполнит свои обязательства по контракту, в случае неисполнения клиентом банка своих обязательств по договору банк оплачивает контрагенту своего клиента сумму указанную в банковской гарантии(происходит раскрытие гарантии).
# В случае раскрытия гарантии у клиента банка возникает обязательство по возврату средств в адрес банка(т. е. при раскрытии гарантии для компании банковскаягарантия превращается в кредит).
#
# Как правила по банковским гарантиям предусмотрено 2 вида плат - плата за выдачу гарантии и процент, который клиент уплачивает при раскрытии гарантии.
# Для банка банковские гарантии интересны как источник некредитных комиссий.
#
# Компании, которые используют банковские гарантии как правило нуждаются в них постоянно, поэтому признак наличия банковских гарантий говорит о высокой вероятности в потребности в гарантиях в будующем.
#
# Построить модель классификации клиентов по признаку "БГ" (определить компании, которые пользуются гарантиями).

# %%
bg.head(3)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 10527024       2016-04-07       1811746.0  Производство
# 11837132       2018-03-05      26713625.0  Производство
#
#             Форма собственности Налоговый режим  \
# ID
# 4283790   Частная собственность             УСН
# 10527024  Частная собственность             УСН
# 11837132  Частная собственность             УСН
#
#           Код причины постановки на учет  2019, Основные средства , RUB  \
# ID
# 4283790                      390601001.0                       651000.0
# 10527024                     390601001.0                        36000.0
# 11837132                     390601001.0                            0.0
#
#           2019, Долгосрочные финансовые вложения, RUB  \
# ID
# 4283790                                           0.0
# 10527024                                          0.0
# 11837132                                          0.0
#
#           2019, Отложенные налоговые активы, RUB  \
# ID
# 4283790                                      0.0
# 10527024                                     0.0
# 11837132                                     0.0
#
#           2019, Внеоборотные активы, RUB  ...  2019, Выручка, RUB  \
# ID                                        ...
# 4283790                         651000.0  ...            909000.0
# 10527024                             0.0  ...            366000.0
# 11837132                             0.0  ...           7348000.0
#
#           2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# ID
# 4283790                               0.0                            47000.0
# 10527024                              0.0                                0.0
# 11837132                              0.0                                0.0
#
#           2019, Прибыль (убыток) от продажи, RUB  \
# ID
# 4283790                                -320000.0
# 10527024                               -854000.0
# 11837132                               1006000.0
#
#           2019, Проценты к уплате, RUB  2019, Прочие расходы, RUB  \
# ID
# 4283790                            0.0                    47000.0
# 10527024                           0.0                    20000.0
# 11837132                           0.0                    27000.0
#
#           2019, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                            -365000.0
# 10527024                           -874000.0
# 11837132                            922000.0
#
#           2019, Получение кредитов и займов, RUB  \
# ID
# 4283790                                      0.0
# 10527024                                     0.0
# 11837132                                     0.0
#
#           2019, Погашение векселей, возврат кредитов и займов, RUB   БГ
# ID
# 4283790                                                 0.0         0.0
# 10527024                                                0.0         0.0
# 11837132                                                0.0         0.0
#
# [3 rows x 65 columns]

# %%
#проверяем насколько сбалансированны данные
print(bg["БГ"].value_counts())
sns.barplot(bg["БГ"].value_counts().index, bg["БГ"].value_counts().values)
# Out:
# 0.0    3595
# 1.0     179
# Name: БГ, dtype: int64

# %% [markdown]
# # Задача 5

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 3216 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о финансовых показателях компани за 2019 год и фин показателях за 2018 год.

# %% [markdown]
# ## Суть задачи

# %% [markdown]
# Поиск потенциальных клиентов банка для заключения договоров лизинга.
# Построить модель классификации на клиентов использующих лизинг и на компании не пользующиеся лизингом.

# %%
lg.head(3)
# Out:
#          Дата регистрации  Код статистики       Отрасль  \
# ID
# 4283790        2003-10-14      71115178.0  Производство
# 10527024       2016-04-07       1811746.0  Производство
# 11837132       2018-03-05      26713625.0  Производство
#
#             Форма собственности Налоговый режим  \
# ID
# 4283790   Частная собственность             УСН
# 10527024  Частная собственность             УСН
# 11837132  Частная собственность             УСН
#
#           Код причины постановки на учет  2018, Налоги, RUB  \
# ID
# 4283790                      390601001.0            16597.0
# 10527024                     390601001.0             5667.0
# 11837132                     390601001.0           131775.0
#
#           2018, Налог на имущество, RUB  2018, Транспортный налог, RUB  \
# ID
# 4283790                             0.0                            0.0
# 10527024                            0.0                            0.0
# 11837132                            0.0                            0.0
#
#           2018, Активы  всего, RUB  ...  2019, Выручка, RUB  \
# ID                                  ...
# 4283790                   725000.0  ...            909000.0
# 10527024                  910000.0  ...            366000.0
# 11837132                   96000.0  ...           7348000.0
#
#           2019, Коммерческие расходы, RUB  2019, Управленческие расходы, RUB  \
# ID
# 4283790                               0.0                            47000.0
# 10527024                              0.0                                0.0
# 11837132                              0.0                                0.0
#
#           2019, Прибыль (убыток) от продажи, RUB  \
# ID
# 4283790                                -320000.0
# 10527024                               -854000.0
# 11837132                               1006000.0
#
#           2019, Проценты к уплате, RUB  2019, Прочие расходы, RUB  \
# ID
# 4283790                            0.0                    47000.0
# 10527024                           0.0                    20000.0
# 11837132                           0.0                    27000.0
#
#           2019, Чистая прибыль (убыток), RUB  \
# ID
# 4283790                            -365000.0
# 10527024                           -874000.0
# 11837132                            922000.0
#
#           2019, Получение кредитов и займов, RUB  \
# ID
# 4283790                                      0.0
# 10527024                                     0.0
# 11837132                                     0.0
#
#           2019, Погашение векселей, возврат кредитов и займов, RUB  Лизинг
# ID
# 4283790                                                 0.0            0.0
# 10527024                                                0.0            0.0
# 11837132                                                0.0            0.0
#
# [3 rows x 71 columns]

# %%
#проверяем насколько сбалансированны данные
print(lg["Лизинг"].value_counts())
sns.barplot(lg["Лизинг"].value_counts().index, lg["Лизинг"].value_counts().values)
# Out:
# 0.0    3035
# 1.0     181
# Name: Лизинг, dtype: int64
