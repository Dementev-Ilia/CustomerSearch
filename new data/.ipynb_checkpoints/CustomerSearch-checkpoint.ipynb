# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Загрузка данных

# %%
company = pd.read_excel('./Компании.xlsx') #загружаю основной набор данных

# %%
company.head(3)
# Out:
#         Наименование Дата регистрации  Код статистики       Отрасль  \
# 0           033, ООО       2003-10-14      71115178.0  Производство
# 1        1 БЭЙК, ООО       2019-10-28      42006784.0  Производство
# 2  1-Я ЛИФТОВАЯ, ООО       2014-11-11      35394691.0  Производство
#
#      Форма собственности  Код причины постановки на учет  \
# 0  Частная собственность                     390601001.0
# 1  Частная собственность                     391401001.0
# 2  Частная собственность                     390601001.0
#
#          Органы власти и государственного управления  СПАРК код  \
# 0  Организации, учрежденные юридическими лицами и...    4283790
# 1  Организации, учрежденные юридическими лицами и...   12390280
# 2  Организации, учрежденные юридическими лицами и...    9603036
#
#     Размер компании  2018, Среднесписочная численность работников  ...  \
# 0  Микропредприятия                                           1.0  ...
# 1               NaN                                           NaN  ...
# 2               NaN                                           1.0  ...
#
#   2019, Сальдо денежных потоков за отчетный период, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Поступление денежных средств всего, RUB  2019, Платежей всего, RUB  \
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
#
#    2019, Прибыль от приносящей доход деятельности, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Всего поступило средств, RUB  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
#
#    2019, Расходы на целевые мероприятия, RUB  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#    2019, Расходы на содержание аппарата управления, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
#    2019, Всего использовано средств, RUB  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
#
#    2019, Остаток средств на конец отчетного года, RUB
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
#
# [3 rows x 145 columns]

# %%
bank_guarantees = pd.read_excel('./Банковские гарантии.xlsx') #данные о наличии банковских гарантий

# %%
leasing = pd.read_excel('./Лизинг.xlsx') #данные о наличии действующих договоров лизинга

# %%
security_loan = pd.read_excel('./Залоги.xlsx') #данные о заргестированных залогах(признак нличия залогового кредита)

# %% [markdown]
# ## Подготовка данных

# %%
data = pd.merge(company, bank_guarantees, how='left') #объединяю исседуемые данные с данными  гарантиях

# %%
data = pd.merge(data, leasing, how='left') #объединяю исседуемые данные с данными  лизинге

# %%
data = pd.merge(data, security_loan, how='left') #объединяю исседуемые данные с данными  кредитвании

# %%
pd.isnull(data).sum()
#после объединения данных получил большое количество пропусков в столбцах которые планирую использовать как данные для предсказания
# Out:
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
# Форма собственности                                      41
#                                                       ...
# 2019, Всего использовано средств, RUB                 11943
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                    11891
# Лизинг                                                11725
# Залоги                                                11844
# Length: 148, dtype: int64

# %%
data.info() #сводные данные теперь храняться в "data"
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12227 entries, 0 to 12226
# Columns: 148 entries, Наименование to Залоги
# dtypes: datetime64[ns](1), float64(140), int64(1), object(6)
# memory usage: 13.9+ MB

# %%
data[['БГ', 'Лизинг', 'Залоги']] = data[['БГ', 'Лизинг', 'Залоги']].fillna(value=0) #обрабатываем пропуски в столбцах,которые будут испоьзоваться при формировании целевых столбцов

# %%
pd.isnull(data).sum()
# Out:
# Наименование                                              0
# Дата регистрации                                         17
# Код статистики                                           57
# Отрасль                                                   0
# Форма собственности                                      41
#                                                       ...
# 2019, Всего использовано средств, RUB                 11943
# 2019, Остаток средств на конец отчетного года, RUB    12003
# БГ                                                        0
# Лизинг                                                    0
# Залоги                                                    0
# Length: 148, dtype: int64

# %%
data.describe()
# Out:
#        Код статистики  Код причины постановки на учет     СПАРК код  \
# count    1.217000e+04                    1.214500e+04  1.222700e+04
# mean     4.774692e+07                    3.909655e+08  7.363669e+06
# std      2.764807e+07                    5.449271e+06  3.404972e+06
# min      4.716000e+04                    3.901010e+08  1.536000e+03
# 25%      2.777519e+07                    3.906010e+08  5.049960e+06
# 50%      4.236241e+07                    3.906010e+08  7.886504e+06
# 75%      7.112371e+07                    3.912010e+08  1.002957e+07
# max      9.971510e+07                    7.708010e+08  1.254730e+07
#
#        2018, Среднесписочная численность работников  2017, Доходы, RUB  \
# count                                   7860.000000       6.529000e+03
# mean                                       8.708397       3.696273e+07
# std                                       57.392902       2.542989e+08
# min                                        1.000000       0.000000e+00
# 25%                                        1.000000       7.540000e+05
# 50%                                        1.000000       4.821000e+06
# 75%                                        5.000000       2.046200e+07
# max                                     4079.000000       1.062454e+10
#
#        2018, Доходы, RUB  2017, Расходы, RUB  2018, Расходы, RUB  \
# count       6.723000e+03        6.529000e+03        6.723000e+03
# mean        6.765525e+07        3.527823e+07        6.378047e+07
# std         7.662991e+08        2.496199e+08        7.547269e+08
# min        -1.194900e+07        0.000000e+00        0.000000e+00
# 25%         7.355000e+05        7.900000e+05        7.990000e+05
# 50%         5.002000e+06        4.444000e+06        4.695000e+06
# 75%         2.242800e+07        1.891800e+07        2.078800e+07
# max         5.336259e+10        1.061781e+10        5.322594e+10
#
#        2017, Налоги, RUB  2018, Налоги, RUB  ...  \
# count       6.556000e+03       6.916000e+03  ...
# mean        1.362677e+06       5.102139e+06  ...
# std         8.100416e+06       1.360288e+08  ...
# min         0.000000e+00       1.000000e+00  ...
# 25%         5.039400e+04       4.995900e+04  ...
# 50%         1.799070e+05       1.923335e+05  ...
# 75%         6.349650e+05       7.323502e+05  ...
# max         3.210900e+08       1.070500e+10  ...
#
#        2019, Прибыль от приносящей доход деятельности, RUB  \
# count                                       4.800000e+01
# mean                                        1.027950e+07
# std                                         5.182259e+07
# min                                        -2.091000e+06
# 25%                                         4.375000e+04
# 50%                                         3.965000e+05
# 75%                                         2.061500e+06
# max                                         3.553420e+08
#
#        2019, Всего поступило средств, RUB  \
# count                        2.800000e+02
# mean                         1.414192e+07
# std                          5.971516e+07
# min                         -2.041000e+06
# 25%                          2.520000e+05
# 50%                          1.130500e+06
# 75%                          4.454750e+06
# max                          6.939350e+08
#
#        2019, Расходы на целевые мероприятия, RUB  \
# count                               1.470000e+02
# mean                                8.093327e+06
# std                                 3.111108e+07
# min                                -6.000000e+03
# 25%                                 1.070000e+05
# 50%                                 4.260000e+05
# 75%                                 2.038000e+06
# max                                 2.043270e+08
#
#        2019, Расходы на содержание аппарата управления, RUB  \
# count                                       2.060000e+02
# mean                                        4.002796e+06
# std                                         2.250313e+07
# min                                        -1.163000e+06
# 25%                                         1.407500e+05
# 50%                                         6.005000e+05
# 75%                                         2.050750e+06
# max                                         3.110270e+08
#
#        2019, Приобретение основных средств, инвентаря и иного имущества, RUB  \
# count                                       5.100000e+01
# mean                                        6.244314e+05
# std                                         1.190632e+06
# min                                         1.000000e+03
# 25%                                         4.150000e+04
# 50%                                         1.610000e+05
# 75%                                         5.385000e+05
# max                                         6.589000e+06
#
#        2019, Всего использовано средств, RUB  \
# count                           2.840000e+02
# mean                            1.374354e+07
# std                             5.908279e+07
# min                            -4.382000e+06
# 25%                             2.125000e+05
# 50%                             9.745000e+05
# 75%                             4.080250e+06
# max                             7.052140e+08
#
#        2019, Остаток средств на конец отчетного года, RUB            БГ  \
# count                                       2.240000e+02   12227.000000
# mean                                        2.559946e+06       0.027480
# std                                         4.291811e+07       0.163485
# min                                        -4.208010e+08       0.000000
# 25%                                         1.000000e+04       0.000000
# 50%                                         9.250000e+04       0.000000
# 75%                                         6.530000e+05       0.000000
# max                                         4.644630e+08       1.000000
#
#              Лизинг        Залоги
# count  12227.000000  12227.000000
# mean       0.041057      0.031324
# std        0.198429      0.174199
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        1.000000      1.000000
#
# [8 rows x 141 columns]

# %% [markdown]
# ## Подготовка данных для задачи по предсказанию фонда оплаты труда и количества сотрудников:

# %%
#Для удобства работы решил разбить данные на отдельные части для каждой задачи
zp = data[['СПАРК код',
           'Дата регистрации',
           'Код статистики',
           'Отрасль',
           'Форма собственности',
           'Налоговый режим',
           '2018, Доходы, RUB',
           '2018, Расходы, RUB',
           '2018, Налоги, RUB',
           '2018, Страховые взносы в ПФР, RUB',
           '2018, Страховые взносы в ФОМС, RUB',
           '2018, Страховые взносы в ФСС, RUB',
           '2018, Основные средства , RUB',
           '2018, Активы  всего, RUB',
           '2018, Собственный капитал, RUB',
           '2018, Выручка, RUB',
           '2018, Управленческие расходы, RUB',
           '2018, Прочие расходы, RUB',
           '2018, Чистая прибыль (убыток), RUB',
           '2018, Оплата труда, RUB',
           '2018, Среднесписочная численность работников'
          ]].copy()

# %%
zp.head(3)
# Out:
#    СПАРК код Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 1   12390280       2019-10-28      42006784.0  Производство
# 2    9603036       2014-11-11      35394691.0  Производство
#
#      Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 0  Частная собственность             УСН          1211000.0
# 1  Частная собственность             NaN                NaN
# 2  Частная собственность             УСН                NaN
#
#    2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 0           1167000.0            16597.0                                NaN
# 1                 NaN                NaN                                NaN
# 2                 NaN                NaN                                NaN
#
#    ...  2018, Страховые взносы в ФСС, RUB  2018, Основные средства , RUB  \
# 0  ...                                NaN                       620000.0
# 1  ...                                NaN                            NaN
# 2  ...                                NaN                            NaN
#
#    2018, Активы  всего, RUB  2018, Собственный капитал, RUB  \
# 0                  725000.0                        600000.0
# 1                       NaN                             NaN
# 2                       NaN                             NaN
#
#    2018, Выручка, RUB  2018, Управленческие расходы, RUB  \
# 0           1211000.0                          1167000.0
# 1                 NaN                                NaN
# 2                 NaN                                NaN
#
#    2018, Прочие расходы, RUB  2018, Чистая прибыль (убыток), RUB  \
# 0                        NaN                             29000.0
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
#
#    2018, Оплата труда, RUB  2018, Среднесписочная численность работников
# 0                      NaN                                           1.0
# 1                      NaN                                           NaN
# 2                      NaN                                           1.0
#
# [3 rows x 21 columns]

# %%
zp.describe()
# Out:
#           СПАРК код  Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count  1.222700e+04    1.217000e+04       6.723000e+03        6.723000e+03
# mean   7.363669e+06    4.774692e+07       6.765525e+07        6.378047e+07
# std    3.404972e+06    2.764807e+07       7.662991e+08        7.547269e+08
# min    1.536000e+03    4.716000e+04      -1.194900e+07        0.000000e+00
# 25%    5.049960e+06    2.777519e+07       7.355000e+05        7.990000e+05
# 50%    7.886504e+06    4.236241e+07       5.002000e+06        4.695000e+06
# 75%    1.002957e+07    7.112371e+07       2.242800e+07        2.078800e+07
# max    1.254730e+07    9.971510e+07       5.336259e+10        5.322594e+10
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       6.916000e+03                       5.499000e+03
# mean        5.102139e+06                       7.388361e+05
# std         1.360288e+08                       3.978190e+06
# min         1.000000e+00                       0.000000e+00
# 25%         4.995900e+04                       2.965100e+04
# 50%         1.923335e+05                       8.936400e+04
# 75%         7.323502e+05                       2.944060e+05
# max         1.070500e+10                       1.115868e+08
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        4.744000e+03                       4.736000e+03
# mean                         1.751858e+05                       9.021046e+04
# std                          9.998552e+05                       4.713477e+05
# min                          0.000000e+00                       0.000000e+00
# 25%                          6.167000e+03                       3.480000e+03
# 50%                          1.744550e+04                       9.973500e+03
# 75%                          5.636650e+04                       3.213825e+04
# max                          2.868460e+07                       1.089792e+07
#
#        2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# count                   3.200000e+03              7.846000e+03
# mean                    2.299829e+07              5.023655e+07
# std                     1.615269e+08              8.387364e+08
# min                     1.000000e+03              1.000000e+03
# 25%                     1.710000e+05              2.200000e+05
# 50%                     1.086000e+06              2.501000e+06
# 75%                     5.895750e+06              1.492825e+07
# max                     5.718265e+09              7.070885e+10
#
#        2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# count                    7.861000e+03        5.425000e+03
# mean                     1.279608e+07        6.001181e+07
# std                      1.643961e+08        3.976602e+08
# min                     -2.577266e+09        1.000000e+03
# 25%                      1.000000e+04        1.506000e+06
# 50%                      3.160000e+05        6.569000e+06
# 75%                      4.209000e+06        2.688100e+07
# max                      8.765452e+09        1.426563e+10
#
#        2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# count                       1.057000e+03               5.447000e+03
# mean                        1.056397e+07               7.865489e+06
# std                         2.940112e+07               7.143855e+07
# min                        -1.182300e+07              -8.895000e+06
# 25%                         2.790000e+05               2.600000e+04
# 50%                         1.579000e+06               1.210000e+05
# 75%                         8.066000e+06               9.990000e+05
# max                         4.437720e+08               2.404268e+09
#
#        2018, Чистая прибыль (убыток), RUB  2018, Оплата труда, RUB  \
# count                        6.163000e+03             5.980000e+02
# mean                         2.957388e+06             2.301952e+07
# std                          4.580852e+07             6.359598e+07
# min                         -1.494500e+09            -2.861600e+07
# 25%                         -8.500000e+04             3.860000e+05
# 50%                          1.010000e+05             2.495500e+06
# 75%                          1.091500e+06             1.461550e+07
# max                          2.081940e+09             6.265480e+08
#
#        2018, Среднесписочная численность работников
# count                                   7860.000000
# mean                                       8.708397
# std                                       57.392902
# min                                        1.000000
# 25%                                        1.000000
# 50%                                        1.000000
# 75%                                        5.000000
# max                                     4079.000000

# %%
zp['2018, Средняя оплата труда сотрудника'] =  zp['2018, Оплата труда, RUB'] / zp['2018, Среднесписочная численность работников'].astype(float)

# %%
zp['2018, Средняя оплата труда сотрудника'] = zp['2018, Средняя оплата труда сотрудника'].fillna(zp['2018, Средняя оплата труда сотрудника'].mean())

# %%
zp['2018, ФОТ'] = zp['2018, Средняя оплата труда сотрудника'] * zp['2018, Среднесписочная численность работников'].astype(float)

# %%
del zp['2018, Оплата труда, RUB']

# %%
del zp[]'2018, Средняя оплата труда сотрудника']
# Out:
#   File "<ipython-input-75-e79a3c5f3277>", line 1
#     del zp[]'2018, Средняя оплата труда сотрудника']
#            ^
# SyntaxError: invalid syntax

# %%
zp['2018, Управленческие расходы, RUB'] = zp['2018, Управленческие расходы, RUB'].fillna(0)

# %%
pd.isnull(zp).sum()

# %%
zp = zp.dropna() #удаляем пропущенные значения

# %% [markdown]
# #  Задача 1

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 1

# %% [markdown]
# Необходимо построить модель по предсказанию объемов фонда оплаты труда(ФОТ)

# %%
zp.head()
# Out:
#    СПАРК код Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 1   12390280       2019-10-28      42006784.0  Производство
# 2    9603036       2014-11-11      35394691.0  Производство
# 3    5298659       2006-03-29      94037570.0  Производство
# 4    7128967       2009-07-28      60596246.0  Производство
#
#      Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 0  Частная собственность             УСН          1211000.0
# 1  Частная собственность             NaN                NaN
# 2  Частная собственность             УСН                NaN
# 3  Частная собственность             УСН                NaN
# 4  Частная собственность             УСН                NaN
#
#    2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 0           1167000.0            16597.0                                NaN
# 1                 NaN                NaN                                NaN
# 2                 NaN                NaN                                NaN
# 3                 NaN                NaN                                NaN
# 4                 NaN                NaN                                NaN
#
#    ...  2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# 0  ...                       620000.0                  725000.0
# 1  ...                            NaN                       NaN
# 2  ...                            NaN                       NaN
# 3  ...                            NaN                       NaN
# 4  ...                            NaN                   10000.0
#
#    2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# 0                        600000.0           1211000.0
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                         10000.0                 NaN
#
#    2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# 0                          1167000.0                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
#
#    2018, Чистая прибыль (убыток), RUB  \
# 0                             29000.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    2018, Среднесписочная численность работников  \
# 0                                           1.0
# 1                                           NaN
# 2                                           1.0
# 3                                           1.0
# 4                                           1.0
#
#    2018, Средняя оплата труда сотрудника      2018, ФОТ
# 0                          405676.325461  405676.325461
# 1                          405676.325461            NaN
# 2                          405676.325461  405676.325461
# 3                          405676.325461  405676.325461
# 4                          405676.325461  405676.325461
#
# [5 rows x 22 columns]

# %%
zp.describe()
# Out:
#           СПАРК код  Код статистики  2018, Доходы, RUB  2018, Расходы, RUB  \
# count  1.222700e+04    1.217000e+04       6.723000e+03        6.723000e+03
# mean   7.363669e+06    4.774692e+07       6.765525e+07        6.378047e+07
# std    3.404972e+06    2.764807e+07       7.662991e+08        7.547269e+08
# min    1.536000e+03    4.716000e+04      -1.194900e+07        0.000000e+00
# 25%    5.049960e+06    2.777519e+07       7.355000e+05        7.990000e+05
# 50%    7.886504e+06    4.236241e+07       5.002000e+06        4.695000e+06
# 75%    1.002957e+07    7.112371e+07       2.242800e+07        2.078800e+07
# max    1.254730e+07    9.971510e+07       5.336259e+10        5.322594e+10
#
#        2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# count       6.916000e+03                       5.499000e+03
# mean        5.102139e+06                       7.388361e+05
# std         1.360288e+08                       3.978190e+06
# min         1.000000e+00                       0.000000e+00
# 25%         4.995900e+04                       2.965100e+04
# 50%         1.923335e+05                       8.936400e+04
# 75%         7.323502e+05                       2.944060e+05
# max         1.070500e+10                       1.115868e+08
#
#        2018, Страховые взносы в ФОМС, RUB  2018, Страховые взносы в ФСС, RUB  \
# count                        4.744000e+03                       4.736000e+03
# mean                         1.751858e+05                       9.021046e+04
# std                          9.998552e+05                       4.713477e+05
# min                          0.000000e+00                       0.000000e+00
# 25%                          6.167000e+03                       3.480000e+03
# 50%                          1.744550e+04                       9.973500e+03
# 75%                          5.636650e+04                       3.213825e+04
# max                          2.868460e+07                       1.089792e+07
#
#        2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# count                   3.200000e+03              7.846000e+03
# mean                    2.299829e+07              5.023655e+07
# std                     1.615269e+08              8.387364e+08
# min                     1.000000e+03              1.000000e+03
# 25%                     1.710000e+05              2.200000e+05
# 50%                     1.086000e+06              2.501000e+06
# 75%                     5.895750e+06              1.492825e+07
# max                     5.718265e+09              7.070885e+10
#
#        2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# count                    7.861000e+03        5.425000e+03
# mean                     1.279608e+07        6.001181e+07
# std                      1.643961e+08        3.976602e+08
# min                     -2.577266e+09        1.000000e+03
# 25%                      1.000000e+04        1.506000e+06
# 50%                      3.160000e+05        6.569000e+06
# 75%                      4.209000e+06        2.688100e+07
# max                      8.765452e+09        1.426563e+10
#
#        2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# count                       1.057000e+03               5.447000e+03
# mean                        1.056397e+07               7.865489e+06
# std                         2.940112e+07               7.143855e+07
# min                        -1.182300e+07              -8.895000e+06
# 25%                         2.790000e+05               2.600000e+04
# 50%                         1.579000e+06               1.210000e+05
# 75%                         8.066000e+06               9.990000e+05
# max                         4.437720e+08               2.404268e+09
#
#        2018, Чистая прибыль (убыток), RUB  \
# count                        6.163000e+03
# mean                         2.957388e+06
# std                          4.580852e+07
# min                         -1.494500e+09
# 25%                         -8.500000e+04
# 50%                          1.010000e+05
# 75%                          1.091500e+06
# max                          2.081940e+09
#
#        2018, Среднесписочная численность работников  \
# count                                   7860.000000
# mean                                       8.708397
# std                                       57.392902
# min                                        1.000000
# 25%                                        1.000000
# 50%                                        1.000000
# 75%                                        5.000000
# max                                     4079.000000
#
#        2018, Средняя оплата труда сотрудника     2018, ФОТ
# count                           1.222700e+04  7.860000e+03
# mean                            4.056763e+05  3.811878e+06
# std                             9.031151e+04  2.659055e+07
# min                            -4.271045e+05 -2.861600e+07
# 25%                             4.056763e+05  4.056763e+05
# 50%                             4.056763e+05  4.056763e+05
# 75%                             4.056763e+05  1.670250e+06
# max                             4.274000e+06  1.654754e+09

# %%
zp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12227 entries, 0 to 12226
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   СПАРК код                                     12227 non-null  int64
#  1   Дата регистрации                              12210 non-null  datetime64[ns]
#  2   Код статистики                                12170 non-null  float64
#  3   Отрасль                                       12227 non-null  object
#  4   Форма собственности                           12186 non-null  object
#  5   Налоговый режим                               7745 non-null   object
#  6   2018, Доходы, RUB                             6723 non-null   float64
#  7   2018, Расходы, RUB                            6723 non-null   float64
#  8   2018, Налоги, RUB                             6916 non-null   float64
#  9   2018, Страховые взносы в ПФР, RUB             5499 non-null   float64
#  10  2018, Страховые взносы в ФОМС, RUB            4744 non-null   float64
#  11  2018, Страховые взносы в ФСС, RUB             4736 non-null   float64
#  12  2018, Основные средства , RUB                 3200 non-null   float64
#  13  2018, Активы  всего, RUB                      7846 non-null   float64
#  14  2018, Собственный капитал, RUB                7861 non-null   float64
#  15  2018, Выручка, RUB                            5425 non-null   float64
#  16  2018, Управленческие расходы, RUB             1057 non-null   float64
#  17  2018, Прочие расходы, RUB                     5447 non-null   float64
#  18  2018, Чистая прибыль (убыток), RUB            6163 non-null   float64
#  19  2018, Среднесписочная численность работников  7860 non-null   float64
#  20  2018, Средняя оплата труда сотрудника         12227 non-null  float64
#  21  2018, ФОТ                                     7860 non-null   float64
# dtypes: datetime64[ns](1), float64(17), int64(1), object(3)
# memory usage: 2.1+ MB

# %% [markdown]
# # Задача 2

# %% [markdown]
# ## Описание данных

# %% [markdown]
# Набор данных о 1214 российских компаний Калининградской области. Компании отобранны случайным образом из различных отраслей экономики. Данные содержат информацию о фонде оплаты труда(ФОТ), численности сотрудникв и финансовых показателях компани за 2018 год.

# %% [markdown]
# ## Суть задачи 2

# %% [markdown]
# Необходимо построить модель по предсказанию среднесписочной численности работников

# %%
zp.head()
# Out:
#    СПАРК код Дата регистрации  Код статистики       Отрасль  \
# 0    4283790       2003-10-14      71115178.0  Производство
# 1   12390280       2019-10-28      42006784.0  Производство
# 2    9603036       2014-11-11      35394691.0  Производство
# 3    5298659       2006-03-29      94037570.0  Производство
# 4    7128967       2009-07-28      60596246.0  Производство
#
#      Форма собственности Налоговый режим  2018, Доходы, RUB  \
# 0  Частная собственность             УСН          1211000.0
# 1  Частная собственность             NaN                NaN
# 2  Частная собственность             УСН                NaN
# 3  Частная собственность             УСН                NaN
# 4  Частная собственность             УСН                NaN
#
#    2018, Расходы, RUB  2018, Налоги, RUB  2018, Страховые взносы в ПФР, RUB  \
# 0           1167000.0            16597.0                                NaN
# 1                 NaN                NaN                                NaN
# 2                 NaN                NaN                                NaN
# 3                 NaN                NaN                                NaN
# 4                 NaN                NaN                                NaN
#
#    ...  2018, Основные средства , RUB  2018, Активы  всего, RUB  \
# 0  ...                       620000.0                  725000.0
# 1  ...                            NaN                       NaN
# 2  ...                            NaN                       NaN
# 3  ...                            NaN                       NaN
# 4  ...                            NaN                   10000.0
#
#    2018, Собственный капитал, RUB  2018, Выручка, RUB  \
# 0                        600000.0           1211000.0
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                         10000.0                 NaN
#
#    2018, Управленческие расходы, RUB  2018, Прочие расходы, RUB  \
# 0                          1167000.0                        NaN
# 1                                NaN                        NaN
# 2                                NaN                        NaN
# 3                                NaN                        NaN
# 4                                NaN                        NaN
#
#    2018, Чистая прибыль (убыток), RUB  \
# 0                             29000.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    2018, Среднесписочная численность работников  \
# 0                                           1.0
# 1                                           NaN
# 2                                           1.0
# 3                                           1.0
# 4                                           1.0
#
#    2018, Средняя оплата труда сотрудника      2018, ФОТ
# 0                          405676.325461  405676.325461
# 1                          405676.325461            NaN
# 2                          405676.325461  405676.325461
# 3                          405676.325461  405676.325461
# 4                          405676.325461  405676.325461
#
# [5 rows x 22 columns]
